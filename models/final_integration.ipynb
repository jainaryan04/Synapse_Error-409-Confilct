# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 830.2 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pydantic_core-2.27.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 311.4 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.7/412.7 kB 23.8 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.3/333.3 kB 561.9 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 717.0 kB/s eta 0:00:00a 0:00:01
# Using cached pydantic_core-2.27.2-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.5/249.5 kB 209.9 kB/s eta 0:00:00a 0:00:01
# ...

# %%
pip install langchain
# Out:
# ...
#   Using cached langchain-0.3.17-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached langchain_core-0.3.33-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached langchain_text_splitters-0.3.5-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached langsmith-0.3.4-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached orjson-3.10.15-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# ...
#   Using cached zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# ...
# Using cached langchain-0.3.17-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.33-py3-none-any.whl (412 kB)
# Using cached langchain_text_splitters-0.3.5-py3-none-any.whl (31 kB)
# Using cached langsmith-0.3.4-py3-none-any.whl (333 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 176.6 kB/s eta 0:00:0000:0100:01
# ...
