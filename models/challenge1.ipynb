# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (8.2.25)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (1.11.1)
# Requirement already satisfied: torch>=1.8.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.18.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (8.0.0)
# Requirement already satisfied: thop>=0.1.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Requirement already satisfied: filelock in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: six>=1.5 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
import cv2
from ultralytics import YOLO
import random

model = YOLO('../models/first_model.pt')
video_path = '../test_vids/enemy_soldier_challenge_2.mp4'
cap = cv2.VideoCapture(video_path)

LABEL_COLORS = {}

def get_label_color(label_id):
    if label_id not in LABEL_COLORS:
        LABEL_COLORS[label_id] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label_id]

middle_line_y = None
crossed_enemy = False
line_offset = 150  # Adjust this value to move the line further down

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    detections = results[0].boxes

    for box in detections:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        confidence = box.conf[0]
        label_id = int(box.cls[0])
        class_name = model.names[label_id]

        color = get_label_color(label_id)
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        text = f'{class_name} {confidence:.2f}'
        cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2
        cv2.circle(frame, (center_x, center_y), 10, color, -1)

        if class_name.lower() == "enemy" and middle_line_y is not None:
            if center_y < middle_line_y and not crossed_enemy:
                crossed_enemy = True
                cv2.putText(frame, 'Enemy crossed border', (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    middle_line_y = frame.shape[0] // 2 + line_offset
    cv2.line(frame, (0, middle_line_y), (frame.shape[1], middle_line_y), (0, 255, 0), 2)

    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    crossed_enemy = False  # Reset the flag so the message can be shown again next time an enemy crosses

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 enemy, 41.7ms
# Speed: 2.7ms preprocess, 41.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.0ms
# Speed: 1.3ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 56.5ms
# Speed: 1.1ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 54.3ms
# Speed: 1.1ms preprocess, 54.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.3ms
# Speed: 1.6ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.8ms
# Speed: 1.1ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# 2025-02-04 02:40:22.508 python[27043:534980] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-04 02:40:22.508 python[27043:534980] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 640x384 1 enemy, 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.5ms
# Speed: 1.3ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.6ms
# Speed: 1.4ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 115.7ms
# Speed: 1.4ms preprocess, 115.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 57.5ms
# Speed: 1.4ms preprocess, 57.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 63.9ms
# Speed: 1.1ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 67.2ms
# Speed: 3.1ms preprocess, 67.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 54.3ms
# Speed: 1.1ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.6ms
# Speed: 1.2ms preprocess, 36.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.8ms
# Speed: 1.1ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.5ms
# Speed: 1.1ms preprocess, 36.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.3ms
# Speed: 1.0ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.0ms
# Speed: 1.1ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.2ms
# Speed: 1.4ms preprocess, 45.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.7ms
# Speed: 1.2ms preprocess, 47.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 56.3ms
# Speed: 1.3ms preprocess, 56.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.5ms
# Speed: 1.8ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.3ms
# Speed: 1.2ms preprocess, 46.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.0ms
# Speed: 3.6ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.7ms
# Speed: 1.0ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.3ms
# Speed: 1.5ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.1ms
# Speed: 1.4ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 84.6ms
# Speed: 1.3ms preprocess, 84.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.1ms
# Speed: 1.3ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.9ms
# Speed: 1.2ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.4ms
# Speed: 1.4ms preprocess, 34.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 32.8ms
# Speed: 1.0ms preprocess, 32.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.2ms
# Speed: 1.1ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.4ms
# Speed: 1.2ms preprocess, 37.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.8ms
# Speed: 1.0ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.4ms
# Speed: 1.3ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.6ms
# Speed: 1.0ms preprocess, 36.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.6ms
# Speed: 1.1ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.3ms
# Speed: 1.5ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.1ms
# Speed: 1.4ms preprocess, 38.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.1ms
# Speed: 1.1ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.0ms
# Speed: 1.5ms preprocess, 41.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.8ms
# Speed: 1.3ms preprocess, 47.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.5ms
# Speed: 1.1ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.2ms
# Speed: 1.6ms preprocess, 37.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 35.1ms
# Speed: 1.2ms preprocess, 35.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.2ms
# Speed: 1.0ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 33.5ms
# Speed: 1.4ms preprocess, 33.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.2ms
# Speed: 1.4ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.8ms
# Speed: 1.2ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.3ms
# Speed: 1.1ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.5ms
# Speed: 1.0ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.6ms
# Speed: 1.3ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 49.1ms
# Speed: 1.6ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 31.9ms
# Speed: 1.0ms preprocess, 31.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.1ms
# Speed: 1.6ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.4ms
# Speed: 1.5ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.8ms
# Speed: 1.6ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.6ms
# Speed: 1.7ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 53.7ms
# Speed: 1.1ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.4ms
# Speed: 3.5ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 52.5ms
# Speed: 1.1ms preprocess, 52.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 55.1ms
# Speed: 1.1ms preprocess, 55.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 61.6ms
# Speed: 1.2ms preprocess, 61.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 73.6ms
# Speed: 2.9ms preprocess, 73.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 49.3ms
# Speed: 1.5ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 54.3ms
# Speed: 1.2ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 75.7ms
# Speed: 1.2ms preprocess, 75.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.9ms
# Speed: 1.2ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.1ms
# Speed: 1.1ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.3ms
# Speed: 1.6ms preprocess, 37.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.8ms
# Speed: 1.2ms preprocess, 37.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 71.7ms
# Speed: 1.1ms preprocess, 71.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.5ms
# Speed: 1.1ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.5ms
# Speed: 1.2ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.7ms
# Speed: 1.2ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.1ms
# Speed: 1.0ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 48.5ms
# Speed: 1.4ms preprocess, 48.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.5ms
# Speed: 1.1ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.3ms
# Speed: 1.6ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.7ms
# Speed: 1.1ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.6ms
# Speed: 1.1ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.1ms
# Speed: 1.2ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.0ms
# Speed: 1.7ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.3ms
# Speed: 1.3ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 33.3ms
# Speed: 1.2ms preprocess, 33.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.0ms
# Speed: 1.1ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.7ms
# Speed: 1.6ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.3ms
# Speed: 1.6ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.1ms
# Speed: 1.3ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.4ms
# Speed: 1.6ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.1ms
# Speed: 1.1ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.6ms
# Speed: 1.7ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.7ms
# Speed: 1.1ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 50.3ms
# Speed: 1.2ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.9ms
# Speed: 1.2ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.9ms
# Speed: 1.0ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.2ms
# Speed: 1.4ms preprocess, 47.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.0ms
# Speed: 1.6ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.6ms
# Speed: 2.2ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 75.7ms
# Speed: 1.5ms preprocess, 75.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.9ms
# Speed: 1.1ms preprocess, 47.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 48.0ms
# Speed: 1.8ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.8ms
# Speed: 1.2ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 48.4ms
# Speed: 1.2ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.6ms
# Speed: 1.1ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.8ms
# Speed: 1.3ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.2ms
# Speed: 1.1ms preprocess, 35.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.1ms
# Speed: 1.6ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.7ms
# Speed: 1.2ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.5ms
# Speed: 1.4ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.9ms
# Speed: 1.4ms preprocess, 36.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.8ms
# Speed: 1.4ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.9ms
# Speed: 1.2ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.2ms
# Speed: 1.5ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.9ms
# Speed: 1.2ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 31.2ms
# Speed: 1.0ms preprocess, 31.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 49.9ms
# Speed: 1.1ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.6ms
# Speed: 1.2ms preprocess, 36.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.1ms
# Speed: 1.1ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.0ms
# Speed: 1.2ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 33.2ms
# Speed: 1.1ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.7ms
# Speed: 1.1ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.1ms
# Speed: 1.4ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.3ms
# Speed: 1.0ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.3ms
# Speed: 1.4ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.9ms
# Speed: 1.1ms preprocess, 47.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.5ms
# Speed: 1.1ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.9ms
# Speed: 1.2ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.7ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 48.6ms
# Speed: 1.2ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.4ms
# Speed: 1.2ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 63.3ms
# Speed: 1.1ms preprocess, 63.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.8ms
# Speed: 1.0ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.7ms
# Speed: 1.2ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.9ms
# Speed: 1.1ms preprocess, 47.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.9ms
# Speed: 1.5ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.6ms
# Speed: 1.6ms preprocess, 34.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.9ms
# Speed: 1.5ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.8ms
# Speed: 1.4ms preprocess, 39.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.5ms
# Speed: 1.1ms preprocess, 36.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 48.6ms
# Speed: 1.1ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.5ms
# Speed: 1.3ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 37.1ms
# Speed: 1.1ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.3ms
# Speed: 1.3ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.2ms
# Speed: 1.2ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.7ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 57.7ms
# Speed: 1.1ms preprocess, 57.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 44.3ms
# Speed: 1.2ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 49.2ms
# Speed: 1.5ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 38.1ms
# Speed: 1.1ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 54.7ms
# Speed: 1.1ms preprocess, 54.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 33.8ms
# Speed: 1.0ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.7ms
# Speed: 1.1ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 52.4ms
# Speed: 1.2ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 39.7ms
# Speed: 1.1ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 enemy, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
