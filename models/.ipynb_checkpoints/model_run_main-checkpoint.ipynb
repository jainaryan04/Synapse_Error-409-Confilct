# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (8.2.25)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (1.11.1)
# Requirement already satisfied: torch>=1.8.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.18.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (8.0.0)
# Requirement already satisfied: thop>=0.1.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Requirement already satisfied: filelock in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: six>=1.5 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/vishwajithp/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
# Object naming correct. JSON not
import cv2
import math
import random
from ultralytics import YOLO
from collections import defaultdict

# Load the YOLO model
model = YOLO('../models/first_model.pt')  # Change to your model path

# Open the video file
video_path = '../test_vids/battlefield-1.mp4'
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"

# Define a dictionary to store unique colors for each label
LABEL_COLORS = {}

# Function to generate random colors for labels
def get_label_color(label):
    if label not in LABEL_COLORS:
        LABEL_COLORS[label] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label]

# Track the count of each object type
object_counters = defaultdict(int)

# Define the allowed object pairs for distance calculation
allowed_pairs = {
    ("tank", "friend"),
    ("enemy", "friend"),
    ("enemy", "wall"),
    ("friend", "wall")
}

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Video processing completed.")
        break
    
    # Perform object detection
    results = model(frame)
    detections = results[0].boxes
    
    # Reset object counters for this frame
    object_counters.clear()
    
    centers = [] 
    
    # Draw bounding boxes, labels, and store centers
    for box in detections:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  
        confidence = box.conf[0]  
        label_id = int(box.cls[0])  
        
        # Get the class name from the model
        class_name = model.names[label_id]
        
        # Increment and get the unique instance number for this object type
        object_counters[class_name] += 1
        unique_label = f"{class_name} {object_counters[class_name]}"
        
        
        class_name_lower = class_name.lower()
        
        
        color = get_label_color(class_name)
        
        # Draw bounding box
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        
        # Draw the label and confidence score
        text = f'{unique_label} {confidence:.2f}'
        cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        
        # Calculate the center point
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2
        centers.append((center_x, center_y, class_name_lower, unique_label))
        
        # Draw the center point with the same label color
        cv2.circle(frame, (center_x, center_y), 5, color, -1)
        
        # Print the uniquely labeled detection
        print(f"Detected: {unique_label}")
    
    # Calculate distances only for the allowed object pairs
    for i in range(len(centers)):
        for j in range(i + 1, len(centers)):
            p1_x, p1_y, label1, name1 = centers[i]
            p2_x, p2_y, label2, name2 = centers[j]
            
            # Check if the pair is in the allowed set (both converted to lowercase)
            if (label1, label2) in allowed_pairs or (label2, label1) in allowed_pairs:
                distance_pixels = int(math.dist((p1_x, p1_y), (p2_x, p2_y)))
                
                # Draw line between allowed pairs
                cv2.line(frame, (p1_x, p1_y), (p2_x, p2_y), (255, 255, 0), 2)  # Yellow line
                
                
                midpoint = ((p1_x + p2_x) // 2, (p1_y + p2_y) // 2)
                cv2.putText(frame, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)
    

    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 57.6ms
# Speed: 3.8ms preprocess, 57.6ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.0ms
# Speed: 1.3ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 48.7ms
# Speed: 1.4ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 68.1ms
# Speed: 1.4ms preprocess, 68.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 61.7ms
# Speed: 3.1ms preprocess, 61.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.1ms
# Speed: 4.2ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 57.7ms
# Speed: 1.3ms preprocess, 57.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# 2025-02-04 11:59:04.467 python[29064:574211] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-04 11:59:04.467 python[29064:574211] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 107.0ms
# Speed: 1.2ms preprocess, 107.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.4ms
# Speed: 1.3ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Dead soldier -frd- 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.2ms
# Speed: 1.1ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -frd- 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 48.4ms
# Speed: 1.0ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -frd- 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 47.4ms
# Speed: 1.0ms preprocess, 47.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.5ms
# Speed: 1.1ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 49.2ms
# Speed: 1.2ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.3ms
# Speed: 1.1ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.3ms
# Speed: 1.2ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.2ms
# Speed: 1.4ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.5ms
# Speed: 1.4ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.1ms
# Speed: 1.5ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.2ms
# Speed: 1.0ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 37.7ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 40.7ms
# Speed: 1.2ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -enemy- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 36.1ms
# Speed: 0.9ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 34.3ms
# Speed: 1.0ms preprocess, 34.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.4ms
# Speed: 1.1ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 95.8ms
# Speed: 1.1ms preprocess, 95.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 48.0ms
# Speed: 1.2ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 45.7ms
# Speed: 1.3ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 46.7ms
# Speed: 1.3ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Dead soldier -frd- 1
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Dead soldier -enemy- 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 45.7ms
# Speed: 1.2ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -enemy- 1
# Detected: Dead soldier -enemy- 2
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 47.1ms
# Speed: 1.4ms preprocess, 47.1ms inference, 9.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Dead soldier -enemy- 1
# Detected: Dead soldier -enemy- 2
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 2
# Detected: Dead soldier -enemy- 2
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 55.2ms
# Speed: 1.2ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Dead soldier -enemy- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 54.7ms
# Speed: 1.1ms preprocess, 54.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.5ms
# Speed: 1.7ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
# Detected: Dead soldier -enemy- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.7ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Dead soldier -enemy- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.4ms
# Speed: 1.4ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Dead soldier -enemy- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 79.5ms
# Speed: 1.0ms preprocess, 79.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 2
# Detected: Dead soldier -enemy- 1
# Detected: Dead soldier -frd- 1
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 2
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -enemy- 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 57.6ms
# Speed: 1.3ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: enemy 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.4ms
# Speed: 1.4ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.9ms
# Speed: 1.2ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.4ms
# Speed: 1.6ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.3ms
# Speed: 1.2ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 47.7ms
# Speed: 1.1ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 65.3ms
# Speed: 1.6ms preprocess, 65.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 46.5ms
# Speed: 1.4ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 47.6ms
# Speed: 1.3ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 61.5ms
# Speed: 1.5ms preprocess, 61.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 53.1ms
# Speed: 1.3ms preprocess, 53.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.2ms
# Speed: 1.1ms preprocess, 38.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.0ms
# Speed: 1.7ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 82.1ms
# Speed: 1.3ms preprocess, 82.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 56.3ms
# Speed: 6.8ms preprocess, 56.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 54.2ms
# Speed: 1.8ms preprocess, 54.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 47.7ms
# Speed: 1.1ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 48.0ms
# Speed: 8.1ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 54.5ms
# Speed: 1.6ms preprocess, 54.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 60.5ms
# Speed: 1.2ms preprocess, 60.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -frd- 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 59.9ms
# Speed: 1.5ms preprocess, 59.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -frd- 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 50.7ms
# Speed: 1.4ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.3ms
# Speed: 1.2ms preprocess, 37.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.8ms
# Speed: 1.1ms preprocess, 37.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 1 enemy, 1 friend, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 46.5ms
# Speed: 1.1ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 52.9ms
# Speed: 1.2ms preprocess, 52.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.8ms
# Speed: 1.1ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Dead soldier -frd- 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 57.7ms
# Speed: 1.2ms preprocess, 57.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.3ms
# Speed: 1.0ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.2ms
# Speed: 1.2ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 47.0ms
# Speed: 1.4ms preprocess, 47.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: friend 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: enemy 2
# Detected: Dead soldier -frd- 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Dead soldier -frd- 2
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 2
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 53.7ms
# Speed: 1.2ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 52.6ms
# Speed: 1.1ms preprocess, 52.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.4ms
# Speed: 1.6ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 33.0ms
# Speed: 1.1ms preprocess, 33.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: enemy 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 50.5ms
# Speed: 1.3ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: enemy 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.7ms
# Speed: 1.2ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 71.4ms
# Speed: 3.0ms preprocess, 71.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.5ms
# Speed: 1.7ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 47.6ms
# Speed: 1.1ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.8ms
# Speed: 1.4ms preprocess, 39.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 62.8ms
# Speed: 5.3ms preprocess, 62.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 70.2ms
# Speed: 1.3ms preprocess, 70.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: enemy 2
# Detected: Wall 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 50.9ms
# Speed: 1.4ms preprocess, 50.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 58.1ms
# Speed: 1.4ms preprocess, 58.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.2ms
# Speed: 1.2ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.3ms
# Speed: 1.3ms preprocess, 40.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 41.6ms
# Speed: 1.2ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 70.3ms
# Speed: 1.2ms preprocess, 70.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 47.4ms
# Speed: 1.1ms preprocess, 47.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 40.2ms
# Speed: 1.7ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 40.6ms
# Speed: 1.3ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 39.8ms
# Speed: 1.0ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.6ms
# Speed: 1.2ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.1ms
# Speed: 1.2ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
# Detected: friend 1
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 39.0ms
# Speed: 1.1ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 44.8ms
# Speed: 1.6ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 66.9ms
# Speed: 1.5ms preprocess, 66.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 2
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -frd- 2
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 3 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 2
# Detected: Wall 2
# Detected: Dead soldier -frd- 3
# Detected: enemy 2
#
# 0: 640x384 3 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 37.7ms
# Speed: 1.4ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -frd- 2
# Detected: Dead soldier -frd- 3
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 3 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 38.9ms
# Speed: 1.3ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 1
# Detected: Dead soldier -frd- 3
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 1
# Detected: Wall 2
# Detected: enemy 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Dead soldier -frd- 1
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 1
# Detected: enemy 2
# Detected: Wall 2
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# Detected: Dead soldier -frd- 1
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -frd- 2
# Detected: enemy 1
# Detected: enemy 2
# Detected: Wall 2

# %%
import cv2
import math
import random
import json
from collections import defaultdict
from scipy.spatial import distance
from ultralytics import YOLO  

model = YOLO('../models/first_model.pt')  

video_path = '../test_vids/2_frnds_together.mp4'
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"

LABEL_COLORS = {}

def get_label_color(label):
    if label not in LABEL_COLORS:
        LABEL_COLORS[label] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label]

allowed_pairs = {
    ("tank", "friend"),
    ("enemy", "friend"),
    ("enemy", "wall"),
    ("friend", "wall")
}

centers = []

class ObjectTracker:
    def __init__(self):
        self.objects = {}
        self.next_id = 1
        self.type_counters = defaultdict(int)
    
    def get_unique_name(self, class_name_lower):
        self.type_counters[class_name_lower] += 1
        return f"{class_name_lower.capitalize()}{self.type_counters[class_name_lower]}"
    
    def track_object(self, center_x, center_y, class_name_lower, frame_counter):
        for obj_id, obj_info in self.objects.items():
            if (obj_info['type'] == class_name_lower and 
                distance.euclidean((obj_info['last_x'], obj_info['last_y']), (center_x, center_y)) < 50):
                obj_info.update({
                    'last_x': center_x,
                    'last_y': center_y,
                    'last_seen': frame_counter,
                    'status': 'Active'
                })
                return obj_id
        
        unique_name = self.get_unique_name(class_name_lower)
        new_id = unique_name
        
        self.objects[new_id] = {
            'type': class_name_lower,
            'last_x': center_x,
            'last_y': center_y,
            'last_seen': frame_counter,
            'status': 'Active'
        }
        
        return new_id

    def clean_old_objects(self, frame_counter):
        for obj_id, obj_info in list(self.objects.items()):
            if frame_counter - obj_info['last_seen'] > 10:
                obj_info['status'] = 'Dead'

    def calculate_distances(self, frame_counter):
        distance_data = {}
        active_objects = [
            (obj_id, info['last_x'], info['last_y']) 
            for obj_id, info in self.objects.items() 
            if info['status'] == 'Active'
        ]
        
        for friend_id, friend_x, friend_y in [
            obj for obj in active_objects 
            if self.objects[obj[0]]['type'] == 'friend'
        ]:
            friend_distances = {}
            
            for other_id, other_x, other_y in active_objects:
                if other_id == friend_id:
                    continue
                
                dist_pixels = int(math.dist((friend_x, friend_y), (other_x, other_y)))
                friend_distances[other_id] = f"{dist_pixels}px"
            
            dead_objects = [
                obj_id for obj_id, info in self.objects.items() 
                if info['status'] == 'Dead'
            ]
            
            for dead_id in dead_objects:
                friend_distances[dead_id] = "Dead"
            
            distance_data[friend_id] = friend_distances if friend_distances else "lonely"
        
        return distance_data

object_tracker = ObjectTracker()

frame_counter = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Video processing completed.")
        break

    frame_counter += 1
    centers = []

    results = model(frame)
    detections = results[0].boxes  

    for box in detections:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        label_id = int(box.cls[0])
        class_name = model.names[label_id]
        class_name_lower = class_name.lower()

        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2

        obj_id = object_tracker.track_object(center_x, center_y, class_name_lower, frame_counter)

        color = get_label_color(label_id)
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        
        status_text = obj_id
        if object_tracker.objects[obj_id]['status'] == 'Dead':
            status_text = f"Dead {class_name} -{class_name_lower}- {status_text.split(class_name_lower.capitalize())[1]}"
        
        cv2.putText(frame, str(status_text), (x1, y1 - 10), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        centers.append((center_x, center_y, class_name_lower, obj_id))

    for i in range(len(centers)):
        for j in range(i + 1, len(centers)):
            p1_x, p1_y, label1, name1 = centers[i]
            p2_x, p2_y, label2, name2 = centers[j]
            
            if (label1, label2) in allowed_pairs or (label2, label1) in allowed_pairs:
                distance_pixels = int(math.dist((p1_x, p1_y), (p2_x, p2_y)))
                
                cv2.line(frame, (p1_x, p1_y), (p2_x, p2_y), (255, 255, 0), 2)
                
                midpoint = ((p1_x + p2_x) // 2, (p1_y + p2_y) // 2)
                cv2.putText(frame, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

    object_tracker.clean_old_objects(frame_counter)

    distance_data = object_tracker.calculate_distances(frame_counter)
    print(json.dumps(distance_data, indent=4))

    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 47.8ms
# Speed: 1.5ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "281px",
#         "Enemy1": "217px",
#         "Enemy2": "396px",
#         "Wall2": "313px",
#         "Friend2": "300px"
#     },
#     "Friend2": {
#         "Wall1": "304px",
#         "Tank1": "236px",
#         "Enemy1": "392px",
#         "Enemy2": "262px",
#         "Wall2": "103px",
#         "Friend1": "300px"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 48.1ms
# Speed: 1.7ms preprocess, 48.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "281px",
#         "Enemy1": "217px",
#         "Enemy2": "397px",
#         "Wall2": "314px",
#         "Friend2": "301px"
#     },
#     "Friend2": {
#         "Wall1": "304px",
#         "Tank1": "235px",
#         "Enemy1": "393px",
#         "Enemy2": "262px",
#         "Wall2": "103px",
#         "Friend1": "301px"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 49.0ms
# Speed: 1.2ms preprocess, 49.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "106px",
#         "Tank1": "282px",
#         "Enemy1": "217px",
#         "Enemy2": "397px",
#         "Wall2": "314px",
#         "Friend2": "302px"
#     },
#     "Friend2": {
#         "Wall1": "304px",
#         "Tank1": "234px",
#         "Enemy1": "393px",
#         "Enemy2": "261px",
#         "Wall2": "103px",
#         "Friend1": "302px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.0ms
# Speed: 1.1ms preprocess, 41.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "282px",
#         "Enemy1": "217px",
#         "Enemy2": "398px",
#         "Wall2": "314px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "363px"
#     },
#     "Friend2": {
#         "Wall1": "306px",
#         "Tank1": "236px",
#         "Enemy1": "393px",
#         "Enemy2": "262px",
#         "Wall2": "103px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "508px"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 3 enemys, 2 friends, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "283px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "315px",
#         "Friend2": "303px",
#         "Dead soldier -enemy-1": "363px",
#         "Enemy3": "366px"
#     },
#     "Friend2": {
#         "Wall1": "306px",
#         "Tank1": "236px",
#         "Enemy1": "394px",
#         "Enemy2": "263px",
#         "Wall2": "104px",
#         "Friend1": "303px",
#         "Dead soldier -enemy-1": "510px",
#         "Enemy3": "507px"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 61.3ms
# Speed: 1.1ms preprocess, 61.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "105px",
#         "Tank1": "282px",
#         "Enemy1": "216px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "303px",
#         "Dead soldier -enemy-1": "362px",
#         "Enemy3": "365px"
#     },
#     "Friend2": {
#         "Wall1": "305px",
#         "Tank1": "236px",
#         "Enemy1": "394px",
#         "Enemy2": "262px",
#         "Wall2": "103px",
#         "Friend1": "303px",
#         "Dead soldier -enemy-1": "510px",
#         "Enemy3": "507px"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.7ms
# Speed: 1.1ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "106px",
#         "Tank1": "283px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "363px",
#         "Enemy3": "367px"
#     },
#     "Friend2": {
#         "Wall1": "304px",
#         "Tank1": "236px",
#         "Enemy1": "394px",
#         "Enemy2": "262px",
#         "Wall2": "103px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "511px",
#         "Enemy3": "508px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 2 enemys, 2 friends, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "106px",
#         "Tank1": "283px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "316px",
#         "Friend2": "303px",
#         "Dead soldier -enemy-1": "381px",
#         "Enemy3": "367px"
#     },
#     "Friend2": {
#         "Wall1": "304px",
#         "Tank1": "236px",
#         "Enemy1": "394px",
#         "Enemy2": "263px",
#         "Wall2": "105px",
#         "Friend1": "303px",
#         "Dead soldier -enemy-1": "511px",
#         "Enemy3": "509px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 2 enemys, 2 friends, 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "106px",
#         "Tank1": "283px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "315px",
#         "Friend2": "303px",
#         "Dead soldier -enemy-1": "381px",
#         "Enemy3": "367px"
#     },
#     "Friend2": {
#         "Wall1": "305px",
#         "Tank1": "236px",
#         "Enemy1": "394px",
#         "Enemy2": "262px",
#         "Wall2": "105px",
#         "Friend1": "303px",
#         "Dead soldier -enemy-1": "511px",
#         "Enemy3": "510px"
#     }
# }
# 2025-02-04 12:51:09.918 python[35845:1047704] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-04 12:51:09.918 python[35845:1047704] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.9ms
# Speed: 1.0ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "283px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "315px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "374px",
#         "Enemy3": "367px"
#     },
#     "Friend2": {
#         "Wall1": "304px",
#         "Tank1": "236px",
#         "Enemy1": "393px",
#         "Enemy2": "262px",
#         "Wall2": "105px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "503px",
#         "Enemy3": "510px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 2 enemys, 2 friends, 48.0ms
# Speed: 1.5ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "282px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "315px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "371px",
#         "Enemy3": "367px"
#     },
#     "Friend2": {
#         "Wall1": "304px",
#         "Tank1": "235px",
#         "Enemy1": "394px",
#         "Enemy2": "262px",
#         "Wall2": "105px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "503px",
#         "Enemy3": "511px"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "218px",
#         "Enemy2": "400px",
#         "Wall2": "314px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "373px",
#         "Enemy3": "369px"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "235px",
#         "Enemy1": "393px",
#         "Enemy2": "261px",
#         "Wall2": "105px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "504px",
#         "Enemy3": "511px"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.3ms
# Speed: 1.2ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "284px",
#         "Enemy1": "219px",
#         "Enemy2": "401px",
#         "Wall2": "314px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "374px",
#         "Enemy3": "370px"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "234px",
#         "Enemy1": "393px",
#         "Enemy2": "261px",
#         "Wall2": "104px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "504px",
#         "Enemy3": "511px"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "284px",
#         "Enemy1": "219px",
#         "Enemy2": "400px",
#         "Wall2": "315px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "375px",
#         "Enemy3": "371px"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "233px",
#         "Enemy1": "392px",
#         "Enemy2": "260px",
#         "Wall2": "104px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "504px",
#         "Enemy3": "511px"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.5ms
# Speed: 1.1ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "219px",
#         "Enemy2": "400px",
#         "Wall2": "314px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "375px",
#         "Enemy3": "371px"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "234px",
#         "Enemy1": "393px",
#         "Enemy2": "261px",
#         "Wall2": "104px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "504px",
#         "Enemy3": "512px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 2 enemys, 2 friends, 46.2ms
# Speed: 1.0ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "285px",
#         "Enemy1": "219px",
#         "Enemy2": "400px",
#         "Wall2": "315px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "371px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "234px",
#         "Enemy1": "392px",
#         "Enemy2": "261px",
#         "Wall2": "104px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "501px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 2 enemys, 2 friends, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "285px",
#         "Enemy1": "219px",
#         "Enemy2": "400px",
#         "Wall2": "315px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "372px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "234px",
#         "Enemy1": "392px",
#         "Enemy2": "261px",
#         "Wall2": "104px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "503px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 69.7ms
# Speed: 2.9ms preprocess, 69.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "283px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "371px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "234px",
#         "Enemy1": "392px",
#         "Enemy2": "261px",
#         "Wall2": "104px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "503px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "315px",
#         "Friend2": "303px",
#         "Dead soldier -enemy-1": "371px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "234px",
#         "Enemy1": "393px",
#         "Enemy2": "261px",
#         "Wall2": "104px",
#         "Friend1": "303px",
#         "Dead soldier -enemy-1": "503px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "218px",
#         "Enemy2": "400px",
#         "Wall2": "316px",
#         "Friend2": "303px",
#         "Dead soldier -enemy-1": "372px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "235px",
#         "Enemy1": "393px",
#         "Enemy2": "261px",
#         "Wall2": "104px",
#         "Friend1": "303px",
#         "Dead soldier -enemy-1": "503px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "315px",
#         "Friend2": "303px",
#         "Dead soldier -enemy-1": "371px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "302px",
#         "Tank1": "234px",
#         "Enemy1": "392px",
#         "Enemy2": "260px",
#         "Wall2": "103px",
#         "Friend1": "303px",
#         "Dead soldier -enemy-1": "502px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.0ms
# Speed: 1.0ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "218px",
#         "Enemy2": "399px",
#         "Wall2": "315px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "372px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "234px",
#         "Enemy1": "392px",
#         "Enemy2": "261px",
#         "Wall2": "104px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "502px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.8ms
# Speed: 1.3ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "285px",
#         "Enemy1": "218px",
#         "Enemy2": "399px",
#         "Wall2": "316px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "372px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "233px",
#         "Enemy1": "392px",
#         "Enemy2": "261px",
#         "Wall2": "105px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "502px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 38.7ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "285px",
#         "Enemy1": "218px",
#         "Enemy2": "400px",
#         "Wall2": "316px",
#         "Friend2": "303px",
#         "Dead soldier -enemy-1": "372px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "302px",
#         "Tank1": "234px",
#         "Enemy1": "392px",
#         "Enemy2": "261px",
#         "Wall2": "105px",
#         "Friend1": "303px",
#         "Dead soldier -enemy-1": "503px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "316px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "372px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "234px",
#         "Enemy1": "391px",
#         "Enemy2": "261px",
#         "Wall2": "104px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "503px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 43.7ms
# Speed: 1.6ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "285px",
#         "Enemy1": "218px",
#         "Enemy2": "401px",
#         "Wall2": "317px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "373px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "232px",
#         "Enemy1": "391px",
#         "Enemy2": "261px",
#         "Wall2": "105px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "503px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.5ms
# Speed: 1.1ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "218px",
#         "Enemy2": "399px",
#         "Wall2": "315px",
#         "Friend2": "301px",
#         "Dead soldier -enemy-1": "373px",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "303px",
#         "Tank1": "233px",
#         "Enemy1": "392px",
#         "Enemy2": "261px",
#         "Wall2": "105px",
#         "Friend1": "301px",
#         "Dead soldier -enemy-1": "504px",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.0ms
# Speed: 1.1ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "283px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "301px",
#         "Tank1": "232px",
#         "Enemy1": "390px",
#         "Enemy2": "260px",
#         "Wall2": "102px",
#         "Friend1": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.0ms
# Speed: 1.3ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "216px",
#         "Enemy2": "399px",
#         "Wall2": "313px",
#         "Friend2": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "301px",
#         "Tank1": "231px",
#         "Enemy1": "390px",
#         "Enemy2": "259px",
#         "Wall2": "102px",
#         "Friend1": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "283px",
#         "Enemy1": "216px",
#         "Enemy2": "399px",
#         "Wall2": "313px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "300px",
#         "Tank1": "230px",
#         "Enemy1": "388px",
#         "Enemy2": "259px",
#         "Wall2": "102px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 37.6ms
# Speed: 1.2ms preprocess, 37.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "282px",
#         "Enemy1": "215px",
#         "Enemy2": "399px",
#         "Wall2": "313px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "229px",
#         "Enemy1": "388px",
#         "Enemy2": "258px",
#         "Wall2": "102px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "283px",
#         "Enemy1": "215px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "230px",
#         "Enemy1": "388px",
#         "Enemy2": "258px",
#         "Wall2": "102px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.6ms
# Speed: 1.2ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "282px",
#         "Enemy1": "215px",
#         "Enemy2": "398px",
#         "Wall2": "313px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "231px",
#         "Enemy1": "388px",
#         "Enemy2": "259px",
#         "Wall2": "102px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "282px",
#         "Enemy1": "214px",
#         "Enemy2": "398px",
#         "Wall2": "313px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "231px",
#         "Enemy1": "387px",
#         "Enemy2": "259px",
#         "Wall2": "103px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 44.7ms
# Speed: 1.2ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "282px",
#         "Enemy1": "215px",
#         "Enemy2": "398px",
#         "Wall2": "312px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "231px",
#         "Enemy1": "386px",
#         "Enemy2": "259px",
#         "Wall2": "102px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 36.2ms
# Speed: 1.0ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "282px",
#         "Enemy1": "214px",
#         "Enemy2": "398px",
#         "Wall2": "312px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "230px",
#         "Enemy1": "386px",
#         "Enemy2": "259px",
#         "Wall2": "102px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 39.0ms
# Speed: 1.1ms preprocess, 39.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "282px",
#         "Enemy1": "214px",
#         "Enemy2": "398px",
#         "Wall2": "312px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "230px",
#         "Enemy1": "386px",
#         "Enemy2": "258px",
#         "Wall2": "101px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "282px",
#         "Enemy1": "215px",
#         "Enemy2": "397px",
#         "Wall2": "313px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "230px",
#         "Enemy1": "386px",
#         "Enemy2": "258px",
#         "Wall2": "102px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 39.7ms
# Speed: 1.1ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "283px",
#         "Enemy1": "215px",
#         "Enemy2": "397px",
#         "Wall2": "313px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "297px",
#         "Tank1": "229px",
#         "Enemy1": "386px",
#         "Enemy2": "258px",
#         "Wall2": "102px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "282px",
#         "Enemy1": "215px",
#         "Enemy2": "397px",
#         "Wall2": "312px",
#         "Friend2": "298px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "297px",
#         "Tank1": "229px",
#         "Enemy1": "386px",
#         "Enemy2": "258px",
#         "Wall2": "103px",
#         "Friend1": "298px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 46.0ms
# Speed: 1.1ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "282px",
#         "Enemy1": "215px",
#         "Enemy2": "397px",
#         "Wall2": "312px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "231px",
#         "Enemy1": "387px",
#         "Enemy2": "259px",
#         "Wall2": "103px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "283px",
#         "Enemy1": "216px",
#         "Enemy2": "398px",
#         "Wall2": "313px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "231px",
#         "Enemy1": "387px",
#         "Enemy2": "259px",
#         "Wall2": "103px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "282px",
#         "Enemy1": "215px",
#         "Enemy2": "398px",
#         "Wall2": "313px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "230px",
#         "Enemy1": "386px",
#         "Enemy2": "259px",
#         "Wall2": "103px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 45.0ms
# Speed: 1.2ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "283px",
#         "Enemy1": "216px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "230px",
#         "Enemy1": "387px",
#         "Enemy2": "259px",
#         "Wall2": "103px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "283px",
#         "Enemy1": "215px",
#         "Enemy2": "399px",
#         "Wall2": "313px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "231px",
#         "Enemy1": "387px",
#         "Enemy2": "260px",
#         "Wall2": "103px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "216px",
#         "Enemy2": "399px",
#         "Wall2": "313px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "300px",
#         "Tank1": "231px",
#         "Enemy1": "388px",
#         "Enemy2": "259px",
#         "Wall2": "102px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 49.7ms
# Speed: 1.1ms preprocess, 49.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "283px",
#         "Enemy1": "216px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "300px",
#         "Tank1": "232px",
#         "Enemy1": "388px",
#         "Enemy2": "260px",
#         "Wall2": "103px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "284px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "231px",
#         "Enemy1": "388px",
#         "Enemy2": "260px",
#         "Wall2": "102px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 38.8ms
# Speed: 1.1ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "283px",
#         "Enemy1": "217px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "231px",
#         "Enemy1": "388px",
#         "Enemy2": "260px",
#         "Wall2": "103px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 37.0ms
# Speed: 1.4ms preprocess, 37.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "283px",
#         "Enemy1": "216px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "230px",
#         "Enemy1": "387px",
#         "Enemy2": "260px",
#         "Wall2": "102px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 49.7ms
# Speed: 1.2ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "283px",
#         "Enemy1": "215px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "230px",
#         "Enemy1": "387px",
#         "Enemy2": "259px",
#         "Wall2": "102px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "109px",
#         "Tank1": "283px",
#         "Enemy1": "213px",
#         "Enemy2": "398px",
#         "Wall2": "313px",
#         "Friend2": "298px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "231px",
#         "Enemy1": "386px",
#         "Enemy2": "260px",
#         "Wall2": "102px",
#         "Friend1": "298px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 52.0ms
# Speed: 1.3ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "283px",
#         "Enemy1": "212px",
#         "Enemy2": "398px",
#         "Wall2": "313px",
#         "Friend2": "298px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "232px",
#         "Enemy1": "386px",
#         "Enemy2": "260px",
#         "Wall2": "104px",
#         "Friend1": "298px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.7ms
# Speed: 1.2ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "211px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "231px",
#         "Enemy1": "385px",
#         "Enemy2": "260px",
#         "Wall2": "103px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "210px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "230px",
#         "Enemy1": "386px",
#         "Enemy2": "260px",
#         "Wall2": "102px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 44.2ms
# Speed: 1.2ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "283px",
#         "Enemy1": "207px",
#         "Enemy2": "398px",
#         "Wall2": "314px",
#         "Friend2": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "231px",
#         "Enemy1": "384px",
#         "Enemy2": "260px",
#         "Wall2": "103px",
#         "Friend1": "299px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 49.3ms
# Speed: 1.1ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "207px",
#         "Enemy2": "399px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "298px",
#         "Tank1": "230px",
#         "Enemy1": "384px",
#         "Enemy2": "260px",
#         "Wall2": "103px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 51.3ms
# Speed: 1.5ms preprocess, 51.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "283px",
#         "Enemy1": "206px",
#         "Enemy2": "400px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "231px",
#         "Enemy1": "383px",
#         "Enemy2": "260px",
#         "Wall2": "102px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 44.4ms
# Speed: 1.7ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "106px",
#         "Tank1": "284px",
#         "Enemy1": "205px",
#         "Enemy2": "399px",
#         "Wall2": "313px",
#         "Friend2": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "232px",
#         "Enemy1": "384px",
#         "Enemy2": "260px",
#         "Wall2": "102px",
#         "Friend1": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 47.2ms
# Speed: 1.4ms preprocess, 47.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "204px",
#         "Enemy2": "400px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "231px",
#         "Enemy1": "384px",
#         "Enemy2": "261px",
#         "Wall2": "103px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 48.7ms
# Speed: 1.5ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "285px",
#         "Enemy1": "203px",
#         "Enemy2": "401px",
#         "Wall2": "315px",
#         "Friend2": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "231px",
#         "Enemy1": "383px",
#         "Enemy2": "261px",
#         "Wall2": "103px",
#         "Friend1": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "202px",
#         "Enemy2": "401px",
#         "Wall2": "314px",
#         "Friend2": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "300px",
#         "Tank1": "232px",
#         "Enemy1": "384px",
#         "Enemy2": "262px",
#         "Wall2": "103px",
#         "Friend1": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "202px",
#         "Enemy2": "400px",
#         "Wall2": "314px",
#         "Friend2": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "300px",
#         "Tank1": "232px",
#         "Enemy1": "384px",
#         "Enemy2": "262px",
#         "Wall2": "103px",
#         "Friend1": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 51.7ms
# Speed: 1.2ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "284px",
#         "Enemy1": "202px",
#         "Enemy2": "401px",
#         "Wall2": "314px",
#         "Friend2": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "300px",
#         "Tank1": "232px",
#         "Enemy1": "385px",
#         "Enemy2": "263px",
#         "Wall2": "104px",
#         "Friend1": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 47.6ms
# Speed: 1.1ms preprocess, 47.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "200px",
#         "Enemy2": "401px",
#         "Wall2": "315px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "300px",
#         "Tank1": "231px",
#         "Enemy1": "384px",
#         "Enemy2": "262px",
#         "Wall2": "103px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 48.8ms
# Speed: 1.1ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "108px",
#         "Tank1": "283px",
#         "Enemy1": "200px",
#         "Enemy2": "400px",
#         "Wall2": "315px",
#         "Friend2": "302px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "300px",
#         "Tank1": "232px",
#         "Enemy1": "384px",
#         "Enemy2": "262px",
#         "Wall2": "103px",
#         "Friend1": "302px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "283px",
#         "Enemy1": "198px",
#         "Enemy2": "400px",
#         "Wall2": "315px",
#         "Friend2": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "300px",
#         "Tank1": "232px",
#         "Enemy1": "383px",
#         "Enemy2": "262px",
#         "Wall2": "104px",
#         "Friend1": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 46.8ms
# Speed: 1.2ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "197px",
#         "Enemy2": "400px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "233px",
#         "Enemy1": "382px",
#         "Enemy2": "263px",
#         "Wall2": "104px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 50.7ms
# Speed: 1.5ms preprocess, 50.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "197px",
#         "Enemy2": "400px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "233px",
#         "Enemy1": "382px",
#         "Enemy2": "262px",
#         "Wall2": "104px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 46.9ms
# Speed: 1.5ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "196px",
#         "Enemy2": "400px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "233px",
#         "Enemy1": "381px",
#         "Enemy2": "263px",
#         "Wall2": "104px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 47.3ms
# Speed: 1.3ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "196px",
#         "Enemy2": "400px",
#         "Wall2": "314px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "233px",
#         "Enemy1": "381px",
#         "Enemy2": "263px",
#         "Wall2": "104px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 39.4ms
# Speed: 1.1ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "195px",
#         "Enemy2": "400px",
#         "Wall2": "315px",
#         "Friend2": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "300px",
#         "Tank1": "233px",
#         "Enemy1": "381px",
#         "Enemy2": "263px",
#         "Wall2": "104px",
#         "Friend1": "301px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "107px",
#         "Tank1": "284px",
#         "Enemy1": "195px",
#         "Enemy2": "400px",
#         "Wall2": "315px",
#         "Friend2": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "299px",
#         "Tank1": "231px",
#         "Enemy1": "379px",
#         "Enemy2": "262px",
#         "Wall2": "103px",
#         "Friend1": "300px",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead"
#     }
# }
#
# 0: 640x384 1 Tank, 2 Walls, 2 enemys, 2 friends, 46.0ms
# ...
#         "Enemy5": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "269px",
#         "Tank1": "204px",
#         "Enemy2": "232px",
#         "Wall2": "91px",
#         "Friend1": "271px",
#         "Enemy6": "341px",
#         "Dead soldier -enemy-2": "341px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 47.7ms
# Speed: 1.3ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "256px",
#         "Enemy2": "362px",
#         "Wall2": "284px",
#         "Friend2": "273px",
#         "Enemy6": "84px",
#         "Dead soldier -enemy-2": "83px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "269px",
#         "Tank1": "205px",
#         "Enemy2": "231px",
#         "Wall2": "91px",
#         "Friend1": "273px",
#         "Enemy6": "343px",
#         "Dead soldier -enemy-2": "343px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "255px",
#         "Enemy2": "362px",
#         "Wall2": "284px",
#         "Friend2": "272px",
#         "Enemy6": "85px",
#         "Dead soldier -enemy-2": "83px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "268px",
#         "Tank1": "204px",
#         "Enemy2": "231px",
#         "Wall2": "91px",
#         "Friend1": "272px",
#         "Enemy6": "343px",
#         "Dead soldier -enemy-2": "343px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "97px",
#         "Tank1": "256px",
#         "Enemy2": "363px",
#         "Wall2": "286px",
#         "Friend2": "273px",
#         "Enemy6": "85px",
#         "Dead soldier -enemy-2": "83px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "270px",
#         "Tank1": "205px",
#         "Enemy2": "232px",
#         "Wall2": "92px",
#         "Friend1": "273px",
#         "Enemy6": "344px",
#         "Dead soldier -enemy-2": "344px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "255px",
#         "Enemy2": "363px",
#         "Wall2": "285px",
#         "Friend2": "272px",
#         "Enemy6": "86px",
#         "Dead soldier -enemy-2": "84px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "269px",
#         "Tank1": "204px",
#         "Enemy2": "232px",
#         "Wall2": "92px",
#         "Friend1": "272px",
#         "Enemy6": "344px",
#         "Dead soldier -enemy-2": "344px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "255px",
#         "Enemy2": "364px",
#         "Wall2": "285px",
#         "Friend2": "273px",
#         "Dead soldier -enemy-2": "84px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "270px",
#         "Tank1": "204px",
#         "Enemy2": "233px",
#         "Wall2": "92px",
#         "Friend1": "273px",
#         "Dead soldier -enemy-2": "345px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 47.4ms
# Speed: 1.5ms preprocess, 47.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "256px",
#         "Enemy2": "363px",
#         "Wall2": "285px",
#         "Friend2": "272px",
#         "Dead soldier -enemy-2": "84px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "269px",
#         "Tank1": "205px",
#         "Enemy2": "233px",
#         "Wall2": "92px",
#         "Friend1": "272px",
#         "Dead soldier -enemy-2": "344px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 49.2ms
# Speed: 1.2ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "95px",
#         "Tank1": "255px",
#         "Enemy2": "363px",
#         "Wall2": "285px",
#         "Friend2": "273px",
#         "Dead soldier -enemy-2": "84px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "271px",
#         "Tank1": "205px",
#         "Enemy2": "233px",
#         "Wall2": "92px",
#         "Friend1": "273px",
#         "Dead soldier -enemy-2": "345px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 39.9ms
# Speed: 1.4ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "256px",
#         "Enemy2": "363px",
#         "Wall2": "285px",
#         "Friend2": "273px",
#         "Dead soldier -enemy-2": "84px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "271px",
#         "Tank1": "206px",
#         "Enemy2": "234px",
#         "Wall2": "92px",
#         "Friend1": "273px",
#         "Dead soldier -enemy-2": "345px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 44.6ms
# Speed: 1.6ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "95px",
#         "Tank1": "255px",
#         "Enemy2": "363px",
#         "Wall2": "285px",
#         "Friend2": "273px",
#         "Dead soldier -enemy-2": "84px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "272px",
#         "Tank1": "206px",
#         "Enemy2": "233px",
#         "Wall2": "91px",
#         "Friend1": "273px",
#         "Dead soldier -enemy-2": "345px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "97px",
#         "Tank1": "256px",
#         "Enemy2": "364px",
#         "Wall2": "285px",
#         "Friend2": "273px",
#         "Dead soldier -enemy-2": "83px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "270px",
#         "Tank1": "205px",
#         "Enemy2": "233px",
#         "Wall2": "91px",
#         "Friend1": "273px",
#         "Dead soldier -enemy-2": "344px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "256px",
#         "Enemy2": "363px",
#         "Wall2": "285px",
#         "Friend2": "273px",
#         "Dead soldier -enemy-2": "84px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "269px",
#         "Tank1": "204px",
#         "Enemy2": "233px",
#         "Wall2": "92px",
#         "Friend1": "273px",
#         "Dead soldier -enemy-2": "344px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 46.5ms
# Speed: 1.6ms preprocess, 46.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "256px",
#         "Enemy2": "363px",
#         "Wall2": "285px",
#         "Friend2": "272px",
#         "Dead soldier -enemy-2": "85px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "269px",
#         "Tank1": "204px",
#         "Enemy2": "233px",
#         "Wall2": "92px",
#         "Friend1": "272px",
#         "Dead soldier -enemy-2": "344px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 51.4ms
# Speed: 1.2ms preprocess, 51.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "255px",
#         "Enemy2": "362px",
#         "Wall2": "284px",
#         "Friend2": "271px",
#         "Dead soldier -enemy-2": "87px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "270px",
#         "Tank1": "205px",
#         "Enemy2": "233px",
#         "Wall2": "92px",
#         "Friend1": "271px",
#         "Dead soldier -enemy-2": "345px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 44.8ms
# Speed: 1.3ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "95px",
#         "Tank1": "254px",
#         "Enemy2": "363px",
#         "Wall2": "284px",
#         "Friend2": "273px",
#         "Dead soldier -enemy-2": "86px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "270px",
#         "Tank1": "205px",
#         "Enemy2": "234px",
#         "Wall2": "92px",
#         "Friend1": "273px",
#         "Dead soldier -enemy-2": "347px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "253px",
#         "Enemy2": "362px",
#         "Wall2": "284px",
#         "Friend2": "271px",
#         "Dead soldier -enemy-2": "88px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "269px",
#         "Tank1": "204px",
#         "Enemy2": "233px",
#         "Wall2": "92px",
#         "Friend1": "271px",
#         "Dead soldier -enemy-2": "347px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 41.7ms
# Speed: 1.1ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "254px",
#         "Enemy2": "363px",
#         "Wall2": "285px",
#         "Friend2": "272px",
#         "Dead soldier -enemy-2": "87px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "270px",
#         "Tank1": "204px",
#         "Enemy2": "233px",
#         "Wall2": "91px",
#         "Friend1": "272px",
#         "Dead soldier -enemy-2": "346px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 49.4ms
# Speed: 1.1ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "Friend1": {
#         "Wall1": "96px",
#         "Tank1": "254px",
#         "Enemy2": "362px",
#         "Wall2": "286px",
#         "Friend2": "272px",
#         "Dead soldier -enemy-2": "87px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     },
#     "Friend2": {
#         "Wall1": "270px",
#         "Tank1": "205px",
#         "Enemy2": "233px",
#         "Wall2": "91px",
#         "Friend1": "272px",
#         "Dead soldier -enemy-2": "346px",
#         "Enemy1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy3": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Enemy6": "Dead"
#     }
# }
# Video processing completed.

# %%
# JSON Correct. Object name not
import cv2
import math
import random
import json
from collections import defaultdict
from scipy.spatial import distance
from ultralytics import YOLO  

# Load the YOLO model
model = YOLO('../models/first_model.pt')  # Change to your model path

# Open the video file
video_path = '../test_vids/battlefield-1.mp4'
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"

# Store previous object locations for tracking
object_tracker = {}

# Maximum distance to consider an object as the same across frames
MAX_TRACKING_DISTANCE = 50

# Frame counter to remove old objects
frame_counter = 0
MAX_FRAMES_MISSING = 10  # If an object disappears for this many frames, we remove it

def calculate_distances(friends, other_objects):
    """
    Calculate distances between friends and all other objects
    
    Args:
    friends (list): List of (name, x, y) for friend objects
    other_objects (list): List of (name, x, y) for other objects
    
    Returns:
    dict: Distance data between friends and other objects
    """
    distance_data = {}
    
    # For each friend
    for friend_name, friend_x, friend_y in friends:
        friend_distances = {}
        
        # Calculate distance to each other object
        for obj_name, obj_x, obj_y in other_objects:
            # Avoid calculating distance to self
            if friend_name != obj_name:
                dist_pixels = int(math.dist((friend_x, friend_y), (obj_x, obj_y)))
                friend_distances[obj_name] = f"{dist_pixels}px"
        
        # If no other objects, mark friend lonely
        if not friend_distances:
            friend_distances = "lonely"
        
        distance_data[friend_name] = friend_distances
    
    return distance_data

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Video processing completed.")
        break

    frame_counter += 1

    # Perform object detection
    results = model(frame)
    detections = results[0].boxes  

    friends = []  # Track friends
    other_objects = []  # Track other objects

    # Draw bounding boxes, labels, and store centers
    for box in detections:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Extract box coordinates
        confidence = box.conf[0]  # Extract confidence score
        label_id = int(box.cls[0])  # Extract class label ID

        # Get the class name from the model
        class_name = model.names[label_id]  
        class_name_lower = class_name.lower()

        # Calculate the center point
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2

        # Try to match with existing tracked objects
        assigned_id = None
        for obj_id, (prev_x, prev_y, prev_label, last_seen) in object_tracker.items():
            if prev_label == class_name_lower and distance.euclidean((prev_x, prev_y), (center_x, center_y)) < MAX_TRACKING_DISTANCE:
                assigned_id = obj_id
                break

        # If no match found, assign a new ID
        if assigned_id is None:
            assigned_id = len(object_tracker) + 1

        # Create unique name
        unique_name = f"{class_name} {assigned_id}"

        # Store object for the next frame
        object_tracker[assigned_id] = (center_x, center_y, class_name_lower, frame_counter)

        # Separate friends from other objects
        if class_name_lower == 'friend':
            friends.append((unique_name, center_x, center_y))
        else:
            other_objects.append((unique_name, center_x, center_y))

    # Remove old objects that haven't been seen for a while
    object_tracker = {obj_id: data for obj_id, data in object_tracker.items() 
                      if frame_counter - data[3] < MAX_FRAMES_MISSING}

    # Calculate distances if friends exist
    if friends:
        distance_data = calculate_distances(friends, other_objects)
        
        # Print the current distance data
        print(json.dumps(distance_data, indent=4))

    # Display the frame (optional, can be removed)
    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.7ms
# Speed: 2.8ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "193px",
#         "Tank 2": "367px",
#         "Wall 3": "228px",
#         "enemy 5": "291px",
#         "Dead soldier -frd- 6": "352px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.5ms
# Speed: 1.2ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "193px",
#         "Tank 2": "368px",
#         "Wall 3": "228px",
#         "enemy 5": "292px",
#         "Dead soldier -frd- 6": "354px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 53.0ms
# Speed: 1.3ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "193px",
#         "Tank 2": "367px",
#         "Wall 3": "228px",
#         "enemy 5": "292px",
#         "Dead soldier -frd- 6": "355px",
#         "enemy 7": "314px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.6ms
# Speed: 1.5ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "368px",
#         "Wall 1": "193px",
#         "Wall 3": "227px",
#         "enemy 5": "293px",
#         "Dead soldier -frd- 6": "355px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.8ms
# Speed: 1.4ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "194px",
#         "Tank 2": "369px",
#         "Wall 3": "229px",
#         "Dead soldier -frd- 6": "355px",
#         "enemy 5": "292px",
#         "enemy 7": "316px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.6ms
# Speed: 1.4ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "194px",
#         "Tank 2": "369px",
#         "Wall 3": "229px",
#         "enemy 5": "292px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "316px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "369px",
#         "Wall 1": "195px",
#         "Wall 3": "230px",
#         "enemy 5": "293px",
#         "Dead soldier -frd- 6": "357px",
#         "enemy 7": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "369px",
#         "Wall 1": "195px",
#         "Wall 3": "230px",
#         "enemy 5": "292px",
#         "Dead soldier -frd- 6": "357px",
#         "enemy 7": "317px"
#     }
# }
# 2025-02-04 02:22:14.599 python[27501:543975] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-04 02:22:14.599 python[27501:543975] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 49.7ms
# Speed: 1.2ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "369px",
#         "Wall 1": "194px",
#         "Wall 3": "228px",
#         "enemy 5": "292px",
#         "Dead soldier -frd- 6": "345px",
#         "enemy 7": "316px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "369px",
#         "Wall 3": "230px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "343px",
#         "enemy 7": "318px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "368px",
#         "Wall 3": "228px",
#         "enemy 5": "293px",
#         "Dead soldier -frd- 6": "347px",
#         "enemy 7": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "369px",
#         "Wall 3": "231px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "346px",
#         "enemy 7": "318px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "370px",
#         "Wall 3": "232px",
#         "enemy 5": "296px",
#         "Dead soldier -frd- 6": "342px",
#         "enemy 7": "320px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.1ms
# Speed: 1.2ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "368px",
#         "Wall 3": "231px",
#         "enemy 5": "295px",
#         "Dead soldier -frd- 6": "346px",
#         "enemy 7": "319px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.3ms
# Speed: 1.8ms preprocess, 36.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "368px",
#         "Wall 3": "231px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "319px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "369px",
#         "Wall 3": "230px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "319px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.5ms
# Speed: 0.9ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "197px",
#         "Tank 2": "369px",
#         "Wall 3": "231px",
#         "enemy 5": "295px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "318px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "368px",
#         "Wall 3": "229px",
#         "enemy 5": "293px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "318px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "197px",
#         "Tank 2": "369px",
#         "Wall 3": "230px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.9ms
# Speed: 1.1ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "368px",
#         "Wall 3": "231px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 5": "294px",
#         "enemy 7": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "197px",
#         "Tank 2": "367px",
#         "Wall 3": "230px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "316px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 52.7ms
# Speed: 3.0ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "367px",
#         "Wall 3": "229px",
#         "Dead soldier -frd- 6": "355px",
#         "enemy 5": "292px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "367px",
#         "Wall 3": "229px",
#         "Dead soldier -frd- 6": "355px",
#         "enemy 5": "292px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "367px",
#         "Wall 3": "229px",
#         "Dead soldier -frd- 6": "354px",
#         "enemy 5": "293px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.8ms
# Speed: 1.1ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "367px",
#         "Wall 3": "230px",
#         "Dead soldier -frd- 6": "354px",
#         "enemy 5": "292px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.0ms
# Speed: 1.2ms preprocess, 38.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "194px",
#         "Tank 2": "365px",
#         "Wall 3": "228px",
#         "Dead soldier -frd- 6": "352px",
#         "enemy 5": "291px",
#         "enemy 7": "313px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "194px",
#         "Tank 2": "364px",
#         "Wall 3": "228px",
#         "Dead soldier -frd- 6": "351px",
#         "enemy 5": "290px",
#         "enemy 7": "313px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.5ms
# Speed: 1.1ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "193px",
#         "Tank 2": "364px",
#         "Wall 3": "228px",
#         "Dead soldier -frd- 6": "352px",
#         "enemy 5": "290px",
#         "enemy 7": "312px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.8ms
# Speed: 1.1ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "193px",
#         "Tank 2": "364px",
#         "Wall 3": "227px",
#         "Dead soldier -frd- 6": "351px",
#         "enemy 5": "289px",
#         "enemy 7": "311px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "191px",
#         "Tank 2": "362px",
#         "Wall 3": "226px",
#         "Dead soldier -frd- 6": "350px",
#         "enemy 5": "288px",
#         "enemy 7": "310px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "190px",
#         "Tank 2": "360px",
#         "Wall 3": "225px",
#         "Dead soldier -frd- 6": "349px",
#         "enemy 5": "286px",
#         "enemy 7": "309px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 32.8ms
# Speed: 1.1ms preprocess, 32.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "189px",
#         "Tank 2": "360px",
#         "Wall 3": "224px",
#         "Dead soldier -frd- 6": "348px",
#         "enemy 5": "285px",
#         "enemy 7": "308px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.2ms
# Speed: 1.1ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "188px",
#         "Tank 2": "360px",
#         "Wall 3": "222px",
#         "Dead soldier -frd- 6": "347px",
#         "enemy 5": "284px",
#         "enemy 7": "307px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "188px",
#         "Tank 2": "360px",
#         "Wall 3": "222px",
#         "Dead soldier -frd- 6": "346px",
#         "enemy 5": "283px",
#         "enemy 7": "308px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 34.2ms
# Speed: 0.9ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "187px",
#         "Tank 2": "359px",
#         "Wall 3": "221px",
#         "Dead soldier -frd- 6": "345px",
#         "enemy 5": "283px",
#         "enemy 7": "306px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "185px",
#         "Tank 2": "356px",
#         "Wall 3": "217px",
#         "Dead soldier -frd- 6": "341px",
#         "enemy 5": "279px",
#         "enemy 7": "303px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "182px",
#         "Tank 2": "353px",
#         "Wall 3": "215px",
#         "Dead soldier -frd- 6": "339px",
#         "enemy 5": "277px",
#         "enemy 7": "300px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "181px",
#         "Tank 2": "351px",
#         "Wall 3": "215px",
#         "Dead soldier -frd- 6": "338px",
#         "enemy 5": "275px",
#         "enemy 7": "299px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 37.2ms
# Speed: 1.1ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "180px",
#         "Tank 2": "350px",
#         "Wall 3": "214px",
#         "enemy 5": "274px",
#         "Dead soldier -frd- 6": "336px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.7ms
# Speed: 1.2ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "180px",
#         "Tank 2": "349px",
#         "Wall 3": "212px",
#         "enemy 5": "272px",
#         "Dead soldier -frd- 6": "333px",
#         "Dead soldier -enemy- 8": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.6ms
# Speed: 1.1ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "348px",
#         "Wall 1": "178px",
#         "Wall 3": "212px",
#         "enemy 5": "272px",
#         "Dead soldier -enemy- 8": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "348px",
#         "Wall 1": "177px",
#         "Wall 3": "212px",
#         "Dead soldier -enemy- 8": "317px",
#         "enemy 5": "272px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.5ms
# Speed: 1.3ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "177px",
#         "Tank 2": "347px",
#         "Wall 3": "210px",
#         "Dead soldier -enemy- 8": "315px",
#         "enemy 5": "270px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 43.8ms
# Speed: 1.2ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "345px",
#         "Wall 1": "176px",
#         "Wall 3": "208px",
#         "Dead soldier -enemy- 8": "313px",
#         "enemy 5": "269px",
#         "Dead soldier -frd- 6": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "344px",
#         "Wall 1": "175px",
#         "Wall 3": "207px",
#         "Dead soldier -enemy- 8": "312px",
#         "enemy 5": "267px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 33.4ms
# Speed: 1.3ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "342px",
#         "Wall 1": "174px",
#         "Wall 3": "207px",
#         "Dead soldier -enemy- 8": "310px",
#         "enemy 5": "266px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "341px",
#         "Wall 1": "174px",
#         "Wall 3": "203px",
#         "Dead soldier -enemy- 8": "309px",
#         "enemy 5": "264px",
#         "Dead soldier -frd- 6": "311px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "341px",
#         "Wall 1": "174px",
#         "Wall 3": "202px",
#         "enemy 5": "262px",
#         "Dead soldier -enemy- 8": "307px",
#         "Dead soldier -frd- 6": "308px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "340px",
#         "Wall 1": "174px",
#         "Wall 3": "200px",
#         "enemy 5": "261px",
#         "Dead soldier -enemy- 8": "304px",
#         "Dead soldier -frd- 6": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "174px",
#         "Tank 2": "339px",
#         "Wall 3": "199px",
#         "enemy 5": "260px",
#         "Dead soldier -enemy- 8": "303px",
#         "Dead soldier -frd- 6": "313px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 36.1ms
# Speed: 1.2ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "338px",
#         "Wall 1": "173px",
#         "Wall 3": "197px",
#         "enemy 5": "259px",
#         "Dead soldier -enemy- 8": "302px",
#         "Dead soldier -frd- 6": "316px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.8ms
# Speed: 1.1ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "172px",
#         "Tank 2": "337px",
#         "Wall 3": "196px",
#         "enemy 5": "258px",
#         "Dead soldier -enemy- 8": "300px",
#         "Dead soldier -frd- 6": "316px",
#         "enemy 8": "279px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 37.6ms
# Speed: 1.1ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "170px",
#         "Tank 2": "336px",
#         "Wall 3": "196px",
#         "enemy 5": "257px",
#         "Dead soldier -frd- 6": "317px",
#         "Dead soldier -enemy- 8": "315px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "334px",
#         "Wall 1": "168px",
#         "Wall 3": "197px",
#         "enemy 5": "256px",
#         "Dead soldier -frd- 6": "317px",
#         "enemy 8": "277px",
#         "Dead soldier -enemy- 8": "301px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "167px",
#         "Tank 2": "332px",
#         "Wall 3": "195px",
#         "enemy 5": "253px",
#         "Dead soldier -frd- 6": "315px",
#         "Dead soldier -enemy- 8": "302px",
#         "enemy 8": "275px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "329px",
#         "Wall 1": "165px",
#         "Wall 3": "193px",
#         "enemy 5": "251px",
#         "Dead soldier -frd- 6": "312px",
#         "enemy 8": "273px",
#         "Dead soldier -enemy- 8": "313px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.7ms
# Speed: 1.2ms preprocess, 36.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "327px",
#         "Wall 1": "163px",
#         "Wall 3": "191px",
#         "enemy 5": "248px",
#         "Dead soldier -frd- 6": "309px",
#         "Dead soldier -enemy- 8": "306px",
#         "enemy 8": "270px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "326px",
#         "Wall 1": "162px",
#         "Wall 3": "191px",
#         "enemy 5": "247px",
#         "Dead soldier -frd- 6": "307px",
#         "enemy 8": "269px",
#         "Dead soldier -enemy- 8": "307px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "324px",
#         "Wall 1": "160px",
#         "Wall 3": "189px",
#         "enemy 5": "245px",
#         "Dead soldier -frd- 6": "305px",
#         "enemy 8": "268px",
#         "Dead soldier -enemy- 8": "305px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "322px",
#         "Wall 1": "161px",
#         "Wall 3": "187px",
#         "enemy 5": "243px",
#         "Dead soldier -enemy- 8": "304px",
#         "Dead soldier -frd- 6": "304px",
#         "enemy 8": "266px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.2ms
# Speed: 1.1ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "322px",
#         "Wall 3": "185px",
#         "enemy 5": "243px",
#         "Wall 1": "160px",
#         "Dead soldier -frd- 6": "302px",
#         "enemy 8": "266px",
#         "Dead soldier -enemy- 8": "303px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.7ms
# Speed: 1.1ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "322px",
#         "Wall 3": "183px",
#         "enemy 5": "242px",
#         "Wall 1": "161px",
#         "enemy 8": "264px",
#         "Dead soldier -enemy- 8": "302px",
#         "Dead soldier -frd- 6": "301px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 65.7ms
# Speed: 1.5ms preprocess, 65.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 3": "183px",
#         "Tank 2": "321px",
#         "enemy 5": "241px",
#         "Wall 1": "161px",
#         "enemy 8": "263px",
#         "Dead soldier -frd- 6": "302px",
#         "Dead soldier -enemy- 8": "302px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "321px",
#         "Wall 3": "182px",
#         "enemy 5": "241px",
#         "Wall 1": "161px",
#         "Dead soldier -frd- 6": "301px",
#         "enemy 8": "262px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.0ms
# Speed: 1.2ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "321px",
#         "enemy 5": "239px",
#         "Wall 3": "177px",
#         "Wall 1": "161px",
#         "Dead soldier -frd- 6": "299px",
#         "enemy 8": "261px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "322px",
#         "Wall 3": "175px",
#         "Wall 1": "164px",
#         "enemy 5": "239px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 8": "260px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "322px",
#         "Wall 3": "174px",
#         "Wall 1": "164px",
#         "enemy 5": "239px",
#         "Dead soldier -frd- 6": "297px",
#         "enemy 8": "259px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "323px",
#         "Wall 3": "173px",
#         "Wall 1": "166px",
#         "enemy 5": "239px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 8": "258px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.6ms
# Speed: 1.1ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "324px",
#         "Wall 3": "171px",
#         "Wall 1": "167px",
#         "enemy 5": "239px",
#         "Dead soldier -frd- 6": "296px",
#         "enemy 8": "257px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.2ms
# Speed: 1.2ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "325px",
#         "Wall 3": "169px",
#         "Wall 1": "170px",
#         "Dead soldier -frd- 6": "296px",
#         "enemy 5": "240px",
#         "enemy 8": "257px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 81.8ms
# Speed: 6.0ms preprocess, 81.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "329px",
#         "Wall 3": "167px",
#         "Wall 1": "175px",
#         "Dead soldier -frd- 6": "297px",
#         "enemy 5": "241px",
#         "enemy 8": "257px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 42.6ms
# Speed: 1.2ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "332px",
#         "Wall 1": "180px",
#         "Wall 3": "164px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 5": "244px",
#         "enemy 8": "256px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.2ms
# Speed: 1.1ms preprocess, 36.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "331px",
#         "Wall 1": "180px",
#         "Wall 3": "160px",
#         "Dead soldier -frd- 6": "296px",
#         "enemy 5": "242px",
#         "enemy 8": "254px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 33.7ms
# Speed: 1.2ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "334px",
#         "Wall 1": "182px",
#         "Wall 3": "162px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 5": "244px",
#         "enemy 8": "255px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "337px",
#         "Wall 1": "187px",
#         "Wall 3": "158px",
#         "Dead soldier -frd- 6": "299px",
#         "enemy 5": "247px",
#         "enemy 8": "255px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.8ms
# Speed: 1.3ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "337px",
#         "Wall 1": "189px",
#         "Wall 3": "156px",
#         "Dead soldier -frd- 6": "297px",
#         "enemy 5": "246px",
#         "enemy 8": "254px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "337px",
#         "Wall 1": "189px",
#         "Wall 3": "156px",
#         "Dead soldier -frd- 6": "297px",
#         "enemy 5": "246px",
#         "enemy 8": "253px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.2ms
# Speed: 5.5ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "340px",
#         "Wall 1": "192px",
#         "Wall 3": "156px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 5": "248px",
#         "enemy 8": "254px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.0ms
# Speed: 1.2ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "342px",
#         "Wall 1": "195px",
#         "Wall 3": "153px",
#         "Dead soldier -frd- 6": "299px",
#         "enemy 5": "248px",
#         "enemy 8": "254px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.6ms
# Speed: 1.2ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "343px",
#         "Wall 1": "196px",
#         "Wall 3": "153px",
#         "enemy 5": "250px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 8": "255px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.5ms
# Speed: 1.2ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "343px",
#         "Wall 1": "194px",
#         "Wall 3": "152px",
#         "Dead soldier -frd- 6": "297px",
#         "enemy 5": "249px",
#         "enemy 8": "254px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.5ms
# Speed: 1.2ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "343px",
#         "Wall 1": "194px",
#         "Dead soldier -frd- 6": "296px",
#         "Wall 3": "150px",
#         "enemy 5": "248px",
#         "enemy 8": "253px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.8ms
# Speed: 1.2ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "342px",
#         "Wall 1": "194px",
#         "Dead soldier -frd- 6": "295px",
#         "Wall 3": "149px",
#         "enemy 5": "247px",
#         "enemy 8": "252px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.2ms
# Speed: 1.3ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "343px",
#         "Dead soldier -frd- 6": "296px",
#         "Wall 3": "148px",
#         "enemy 5": "247px",
#         "enemy 8": "251px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.1ms
# Speed: 12.4ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "198px",
#         "Tank 2": "344px",
#         "Dead soldier -frd- 6": "295px",
#         "Wall 3": "146px",
#         "enemy 5": "247px",
#         "enemy 8": "251px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.6ms
# Speed: 1.1ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "199px",
#         "Tank 2": "346px",
#         "Wall 3": "144px",
#         "Dead soldier -frd- 6": "296px",
#         "enemy 5": "248px",
#         "enemy 8": "252px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "199px",
#         "Tank 2": "347px",
#         "Wall 3": "143px",
#         "Dead soldier -frd- 6": "295px",
#         "enemy 5": "248px",
#         "enemy 8": "250px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "348px",
#         "Wall 1": "201px",
#         "Wall 3": "142px",
#         "Dead soldier -frd- 6": "276px",
#         "enemy 5": "250px",
#         "enemy 8": "251px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 1": "204px",
#         "Wall 3": "141px",
#         "Dead soldier -frd- 6": "278px",
#         "enemy 5": "252px",
#         "enemy 8": "253px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 59.1ms
# Speed: 1.0ms preprocess, 59.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "354px",
#         "Wall 1": "209px",
#         "Wall 3": "139px",
#         "Dead soldier -frd- 6": "279px",
#         "enemy 5": "254px",
#         "enemy 8": "252px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.0ms
# Speed: 1.2ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "355px",
#         "Wall 1": "210px",
#         "Wall 3": "137px",
#         "Dead soldier -frd- 6": "277px",
#         "enemy 5": "253px",
#         "enemy 8": "251px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.1ms
# Speed: 1.2ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "353px",
#         "Wall 1": "210px",
#         "Wall 3": "135px",
#         "enemy 5": "252px",
#         "Dead soldier -frd- 6": "276px",
#         "enemy 8": "249px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.1ms
# Speed: 1.3ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "355px",
#         "Wall 1": "212px",
#         "Wall 3": "135px",
#         "enemy 5": "253px",
#         "Dead soldier -frd- 6": "277px",
#         "enemy 8": "250px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "356px",
#         "Wall 1": "213px",
#         "Wall 3": "133px",
#         "Dead soldier -frd- 6": "277px",
#         "enemy 5": "253px",
#         "enemy 8": "249px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 61.7ms
# Speed: 1.2ms preprocess, 61.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "355px",
#         "Wall 1": "214px",
#         "Wall 3": "132px",
#         "Dead soldier -frd- 6": "277px",
#         "enemy 5": "254px",
#         "enemy 8": "248px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "354px",
#         "Wall 3": "131px",
#         "Wall 1": "214px",
#         "Dead soldier -frd- 6": "274px",
#         "enemy 5": "252px",
#         "enemy 8": "248px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "355px",
#         "Wall 3": "129px",
#         "Wall 1": "215px",
#         "Dead soldier -frd- 6": "276px",
#         "enemy 5": "253px",
#         "enemy 8": "246px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.0ms
# Speed: 1.1ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "353px",
#         "Wall 3": "128px",
#         "Wall 1": "213px",
#         "Dead soldier -frd- 6": "274px",
#         "enemy 5": "252px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "353px",
#         "Wall 3": "127px",
#         "Dead soldier -frd- 6": "291px",
#         "enemy 5": "251px",
#         "Wall 1": "212px",
#         "enemy 8": "244px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.6ms
# Speed: 1.3ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "350px",
#         "Wall 3": "125px",
#         "Dead soldier -frd- 6": "289px",
#         "Wall 1": "210px",
#         "enemy 5": "249px",
#         "enemy 8": "243px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.5ms
# Speed: 4.3ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "348px",
#         "Wall 3": "124px",
#         "Dead soldier -frd- 6": "271px",
#         "Wall 1": "208px",
#         "enemy 5": "246px",
#         "enemy 8": "240px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "124px",
#         "Dead soldier -frd- 6": "276px",
#         "Wall 1": "211px",
#         "enemy 5": "249px",
#         "enemy 8": "243px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.1ms
# Speed: 1.1ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "352px",
#         "Wall 3": "124px",
#         "enemy 5": "249px",
#         "Wall 1": "212px",
#         "Dead soldier -frd- 6": "281px",
#         "enemy 8": "242px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "352px",
#         "Wall 3": "121px",
#         "enemy 5": "249px",
#         "Wall 1": "212px",
#         "Dead soldier -frd- 6": "278px",
#         "enemy 8": "240px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "121px",
#         "enemy 5": "248px",
#         "Wall 1": "212px",
#         "Dead soldier -frd- 6": "287px",
#         "enemy 8": "240px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 57.8ms
# Speed: 1.0ms preprocess, 57.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "120px",
#         "enemy 5": "249px",
#         "Wall 1": "213px",
#         "Dead soldier -frd- 6": "273px",
#         "enemy 8": "240px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.8ms
# Speed: 1.2ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "352px",
#         "Wall 3": "120px",
#         "enemy 5": "251px",
#         "Dead soldier -frd- 6": "270px",
#         "Wall 1": "215px",
#         "enemy 8": "240px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "119px",
#         "Dead soldier -frd- 6": "273px",
#         "enemy 5": "250px",
#         "Wall 1": "215px",
#         "enemy 8": "239px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.2ms
# Speed: 1.1ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "117px",
#         "Dead soldier -frd- 6": "269px",
#         "enemy 5": "249px",
#         "Wall 1": "216px",
#         "enemy 8": "238px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "358px",
#         "Wall 3": "118px",
#         "enemy 5": "255px",
#         "Dead soldier -frd- 6": "274px",
#         "Wall 1": "224px",
#         "enemy 8": "241px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "361px",
#         "Wall 3": "117px",
#         "enemy 5": "258px",
#         "Wall 1": "226px",
#         "Dead soldier -frd- 6": "272px",
#         "enemy 8": "243px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.6ms
# Speed: 10.2ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "360px",
#         "Wall 3": "118px",
#         "enemy 5": "258px",
#         "Wall 1": "226px",
#         "Dead soldier -frd- 6": "272px",
#         "enemy 8": "243px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.7ms
# Speed: 1.3ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "358px",
#         "Wall 3": "115px",
#         "enemy 5": "256px",
#         "Dead soldier -frd- 6": "273px",
#         "enemy 8": "240px",
#         "Wall 1": "223px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "349px",
#         "Wall 3": "111px",
#         "enemy 5": "246px",
#         "Dead soldier -frd- 6": "269px",
#         "enemy 8": "233px",
#         "Wall 1": "214px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "345px",
#         "Wall 3": "110px",
#         "enemy 5": "243px",
#         "Dead soldier -frd- 6": "279px",
#         "enemy 8": "232px",
#         "Wall 1": "211px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.3ms
# Speed: 1.0ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "346px",
#         "Wall 3": "110px",
#         "enemy 5": "244px",
#         "enemy 8": "232px",
#         "Dead soldier -frd- 6": "279px",
#         "Wall 1": "212px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 51.9ms
# Speed: 4.6ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "112px",
#         "enemy 5": "249px",
#         "Dead soldier -frd- 6": "283px",
#         "enemy 8": "236px",
#         "Wall 1": "217px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "356px",
#         "Wall 3": "112px",
#         "enemy 5": "253px",
#         "enemy 8": "238px",
#         "Dead soldier -frd- 6": "287px",
#         "Wall 1": "222px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.8ms
# Speed: 1.1ms preprocess, 39.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "353px",
#         "Wall 3": "110px",
#         "enemy 5": "251px",
#         "Dead soldier -frd- 6": "285px",
#         "enemy 8": "235px",
#         "Wall 1": "221px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "347px",
#         "Wall 3": "108px",
#         "enemy 5": "246px",
#         "Dead soldier -frd- 6": "280px",
#         "enemy 8": "231px",
#         "Wall 1": "215px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 60.6ms
# Speed: 1.3ms preprocess, 60.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "345px",
#         "Wall 3": "106px",
#         "enemy 5": "243px",
#         "Dead soldier -frd- 6": "278px",
#         "Wall 1": "213px",
#         "enemy 8": "229px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "344px",
#         "Wall 3": "105px",
#         "enemy 5": "243px",
#         "Dead soldier -frd- 6": "277px",
#         "Wall 1": "213px",
#         "enemy 8": "228px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 41.2ms
# Speed: 1.2ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.2ms
# Speed: 1.2ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "348px",
# ...
#         "Dead soldier -enemy- 6": "328px",
#         "enemy 5": "346px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "144px",
#         "Tank 2": "185px",
#         "Dead soldier -enemy- 6": "328px",
#         "Dead soldier -frd- 6": "209px",
#         "Wall 3": "292px",
#         "enemy 5": "345px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "143px",
#         "Tank 2": "185px",
#         "Dead soldier -enemy- 6": "327px",
#         "Dead soldier -frd- 6": "209px",
#         "Wall 3": "291px",
#         "enemy 5": "343px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 51.0ms
# Speed: 1.3ms preprocess, 51.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "143px",
#         "Tank 2": "185px",
#         "Dead soldier -enemy- 6": "327px",
#         "Dead soldier -frd- 6": "209px",
#         "Wall 3": "292px",
#         "enemy 5": "345px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 47.3ms
# Speed: 1.1ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "141px",
#         "Tank 2": "184px",
#         "Wall 3": "290px",
#         "enemy 5": "344px",
#         "Dead soldier -frd- 6": "208px",
#         "Dead soldier -enemy- 6": "325px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "141px",
#         "Tank 2": "185px",
#         "Wall 3": "290px",
#         "Dead soldier -frd- 6": "208px",
#         "enemy 5": "344px",
#         "Dead soldier -enemy- 6": "325px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.8ms
# Speed: 1.3ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "142px",
#         "Tank 2": "184px",
#         "Dead soldier -frd- 6": "208px",
#         "Wall 3": "290px",
#         "Dead soldier -enemy- 6": "325px",
#         "enemy 5": "343px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "143px",
#         "Tank 2": "184px",
#         "Dead soldier -frd- 6": "207px",
#         "Wall 3": "290px",
#         "enemy 5": "342px",
#         "Dead soldier -enemy- 6": "325px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "143px",
#         "Tank 2": "184px",
#         "Dead soldier -frd- 6": "206px",
#         "Wall 3": "289px",
#         "Dead soldier -enemy- 6": "324px",
#         "enemy 5": "343px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "144px",
#         "Tank 2": "185px",
#         "Dead soldier -frd- 6": "207px",
#         "Dead soldier -enemy- 6": "326px",
#         "Wall 3": "289px",
#         "enemy 5": "344px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "143px",
#         "Tank 2": "184px",
#         "Dead soldier -enemy- 6": "324px",
#         "Dead soldier -frd- 6": "205px",
#         "Wall 3": "287px",
#         "enemy 5": "343px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 52.6ms
# Speed: 1.1ms preprocess, 52.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "142px",
#         "Dead soldier -enemy- 6": "323px",
#         "Tank 2": "183px",
#         "Dead soldier -frd- 6": "206px",
#         "Wall 3": "289px",
#         "enemy 5": "343px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 51.2ms
# Speed: 1.1ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "323px",
#         "Wall 1": "142px",
#         "Tank 2": "182px",
#         "Dead soldier -frd- 6": "205px",
#         "Wall 3": "289px",
#         "enemy 5": "342px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 56.0ms
# Speed: 1.1ms preprocess, 56.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "322px",
#         "Wall 1": "142px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "182px",
#         "Wall 3": "288px",
#         "enemy 5": "342px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 86.9ms
# Speed: 1.0ms preprocess, 86.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "322px",
#         "Dead soldier -frd- 6": "205px",
#         "Wall 1": "141px",
#         "Tank 2": "182px",
#         "Wall 3": "287px",
#         "enemy 5": "342px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "322px",
#         "Dead soldier -frd- 6": "205px",
#         "Wall 1": "142px",
#         "Tank 2": "182px",
#         "Wall 3": "288px",
#         "enemy 5": "342px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "322px",
#         "Dead soldier -frd- 6": "205px",
#         "Wall 1": "142px",
#         "Tank 2": "182px",
#         "Wall 3": "288px",
#         "enemy 5": "342px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "182px",
#         "Wall 3": "287px",
#         "enemy 5": "341px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 54.2ms
# Speed: 1.2ms preprocess, 54.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "341px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 101.9ms
# Speed: 1.4ms preprocess, 101.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "341px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "320px",
#         "Wall 1": "140px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "339px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "340px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 46.7ms
# Speed: 1.0ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "340px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 48.1ms
# Speed: 1.1ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "203px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "340px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "320px",
#         "Wall 1": "140px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "339px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 57.2ms
# Speed: 1.1ms preprocess, 57.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "319px",
#         "Wall 1": "139px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "338px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 56.4ms
# Speed: 1.2ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -enemy- 6": "319px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "338px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 56.1ms
# Speed: 1.5ms preprocess, 56.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "319px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "339px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 51.0ms
# Speed: 1.2ms preprocess, 51.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "337px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 59.7ms
# Speed: 1.3ms preprocess, 59.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "319px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "337px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 75.8ms
# Speed: 1.3ms preprocess, 75.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -enemy- 6": "319px",
#         "Tank 2": "182px",
#         "Dead soldier -frd- 6": "203px",
#         "Wall 3": "282px",
#         "enemy 5": "338px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 54.8ms
# Speed: 1.7ms preprocess, 54.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Wall 3": "283px",
#         "enemy 5": "338px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 53.7ms
# Speed: 1.2ms preprocess, 53.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Wall 3": "284px",
#         "enemy 5": "338px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Dead soldier -enemy- 6": "318px",
#         "Wall 3": "284px",
#         "enemy 5": "335px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -frd- 6": "203px",
#         "Tank 2": "181px",
#         "Dead soldier -enemy- 6": "318px",
#         "Wall 3": "285px",
#         "enemy 5": "336px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 54.8ms
# Speed: 1.3ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "203px",
#         "Tank 2": "181px",
#         "Wall 3": "284px",
#         "enemy 5": "336px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 47.9ms
# Speed: 1.2ms preprocess, 47.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "202px",
#         "Tank 2": "181px",
#         "Wall 3": "284px",
#         "enemy 5": "336px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 52.8ms
# Speed: 1.2ms preprocess, 52.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "203px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "337px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "337px"
#     }
# }
# Video processing completed.

# %%
import cv2
import math
import random
import json
from collections import defaultdict
from scipy.spatial import distance
from ultralytics import YOLO  

# Load the YOLO model
model = YOLO('../models/first_model.pt')  # Change to your model path

# Open the video file
video_path = '../test_vids/battlefield-1.mp4'
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"

# Define a dictionary to store unique colors for each label
LABEL_COLORS = {}

# Function to generate random colors for labels
def get_label_color(label_id):
    if label_id not in LABEL_COLORS:
        LABEL_COLORS[label_id] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label_id]

# Define the allowed object pairs for distance calculation
allowed_pairs = {
    ("tank", "friend"),
    ("enemy", "friend"),
    ("enemy", "wall"),
    ("friend", "wall")
}

# Store previous object locations for tracking
object_tracker = {}

# Maximum distance to consider an object as the same across frames
MAX_TRACKING_DISTANCE = 50

# Frame counter to remove old objects
frame_counter = 0
MAX_FRAMES_MISSING = 10  # If an object disappears for this many frames, we remove it

# Dictionary to store distance data
distance_data = {}

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Video processing completed.")
        break

    frame_counter += 1

    # Perform object detection
    results = model(frame)
    detections = results[0].boxes  

    new_objects = []  # Store new detections in this frame

    # Draw bounding boxes, labels, and store centers
    for box in detections:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Extract box coordinates
        confidence = box.conf[0]  # Extract confidence score
        label_id = int(box.cls[0])  # Extract class label ID

        # Get the class name from the model
        class_name = model.names[label_id]  
        class_name_lower = class_name.lower()

        # Calculate the center point
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2

        # Try to match with existing objects
        assigned_id = None
        for obj_id, (prev_x, prev_y, prev_label, last_seen) in object_tracker.items():
            if prev_label == class_name_lower and distance.euclidean((prev_x, prev_y), (center_x, center_y)) < MAX_TRACKING_DISTANCE:
                assigned_id = obj_id
                break

        # If no match found, assign a new ID
        if assigned_id is None:
            assigned_id = len(object_tracker) + 1

        # Store object for the next frame
        object_tracker[assigned_id] = (center_x, center_y, class_name_lower, frame_counter)
        unique_name = f"{class_name} {assigned_id}"  # E.g., "Friend 1", "Tank 2"

        # Debugging: Print detected object names
        print(f"Detected: {unique_name}")

        # Assign a unique color to this label
        color = get_label_color(label_id)

        # Draw bounding box
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

        # Draw the label and confidence score
        text = f'{unique_name} {confidence:.2f}'
        cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        # Draw the center point with the same label color
        cv2.circle(frame, (center_x, center_y), 5, color, -1)

        # Store for distance calculation
        new_objects.append((center_x, center_y, class_name_lower, unique_name))

    # Remove old objects that haven't been seen for a while (consider them "dead")
    object_tracker = {obj_id: data for obj_id, data in object_tracker.items() if frame_counter - data[3] < MAX_FRAMES_MISSING}

    # Calculate distances only for the allowed object pairs
    for i in range(len(new_objects)):
        for j in range(i + 1, len(new_objects)):
            p1_x, p1_y, label1, name1 = new_objects[i]
            p2_x, p2_y, label2, name2 = new_objects[j]

            # Check if the pair is in the allowed set (both converted to lowercase)
            if (label1, label2) in allowed_pairs or (label2, label1) in allowed_pairs:
                distance_pixels = int(math.dist((p1_x, p1_y), (p2_x, p2_y)))

                # Add the distance to the JSON-like dictionary, only if the objects are "alive"
                if label1 != label2:  # To avoid self-distances
                    if name1 not in distance_data:
                        distance_data[name1] = {}
                    distance_data[name1][name2] = f"{distance_pixels}px"

                # Draw line between allowed pairs
                cv2.line(frame, (p1_x, p1_y), (p2_x, p2_y), (255, 255, 0), 2)  # Yellow line

                # Display distance at the midpoint of the line
                midpoint = ((p1_x + p2_x) // 2, (p1_y + p2_y) // 2)
                cv2.putText(frame, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

    # Print the current distance data (for debugging purposes)
    print(json.dumps(distance_data, indent=4))

    # Display the frame
    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture
cap.release()
cv2.destroyAllWindows()

# %%
#only with distance between labels
import cv2
import math
import random
from ultralytics import YOLO  

# Load the YOLO model
model = YOLO('../models/first_model.pt')  # Change to your model path

# Open the video file
video_path = '../test_vids/battlefield-1.mp4'
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"

# Define a dictionary to store unique colors for each label
LABEL_COLORS = {}

# Function to generate random colors for labels
def get_label_color(label_id):
    if label_id not in LABEL_COLORS:
        LABEL_COLORS[label_id] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label_id]

# Define the allowed object pairs for distance calculation
allowed_pairs = {
    ("tank", "friend"),
    ("enemy", "friend"),
    ("enemy", "wall"),
    ("friend", "wall")
}

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Video processing completed.")
        break

    # Perform object detection
    results = model(frame)
    detections = results[0].boxes  

    centers = []  # Store center points of detected objects along with their labels

    # Draw bounding boxes, labels, and store centers
    for box in detections:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Extract box coordinates
        confidence = box.conf[0]  # Extract confidence score
        label_id = int(box.cls[0])  # Extract class label ID

        # Get the class name from the model
        class_name = model.names[label_id]  # Keep original detected name
        class_name_lower = class_name.lower()  # Convert to lowercase for matching

        # Debugging: Print detected object names
        print(f"Detected: {class_name}")

        # Assign a unique color to this label
        color = get_label_color(label_id)

        # Draw bounding box
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

        # Draw the label and confidence score
        text = f'{class_name} {confidence:.2f}'
        cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        # Calculate the center point
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2
        centers.append((center_x, center_y, class_name_lower))  # Store lowercase name

        # Draw the center point with the same label color
        cv2.circle(frame, (center_x, center_y), 5, color, -1)

    # Calculate distances only for the allowed object pairs
    for i in range(len(centers)):
        for j in range(i + 1, len(centers)):
            p1_x, p1_y, label1 = centers[i]
            p2_x, p2_y, label2 = centers[j]

            # Check if the pair is in the allowed set (both converted to lowercase)
            if (label1, label2) in allowed_pairs or (label2, label1) in allowed_pairs:
                distance_pixels = int(math.dist((p1_x, p1_y), (p2_x, p2_y)))

                # Draw line between allowed pairs
                cv2.line(frame, (p1_x, p1_y), (p2_x, p2_y), (255, 255, 0), 2)  # Yellow line

                # Display distance at the midpoint of the line
                midpoint = ((p1_x + p2_x) // 2, (p1_y + p2_y) // 2)
                cv2.putText(frame, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

    # Display the frame
    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture
cap.release()
cv2.destroyAllWindows()
