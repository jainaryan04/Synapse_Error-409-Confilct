# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from IPython.display import Image,display
from IPython import display

# %%
import cv2

from ultralytics import solutions

cap = cv2.VideoCapture("Path/to/video/file.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("distance_calculationss.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Init distance-calculation obj
distance = solutions.DistanceCalculation(model="yolo11n.pt", show=True)

# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    im0 = distance.calculate(im0)
    video_writer.write(im0)
    cv2.imshow('Distance Calculation', im0)
    if cv2.waitKey(1) == ord('q'):  # Press 'q' to quit
        break

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Ultralytics Solutions: ✅ {'region': None, 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'model': '../models/yolo11n.pt', 'show': True}
#
# 0: 384x640 18 persons, 57.1ms
# Speed: 4.8ms preprocess, 57.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 51.8ms
# Speed: 1.4ms preprocess, 51.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.1ms
# Speed: 1.3ms preprocess, 41.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.5ms
# Speed: 1.3ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 2025-02-03 12:18:23.081 python[6811:155491] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-03 12:18:23.081 python[6811:155491] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# ...

# %%
from ultralytics import YOLO
from ultralytics.solutions import distance_calculation
import cv2

# Load model
model = YOLO("../models/yolov8n.pt")

# Initialize video
cap = cv2.VideoCapture("../test_vids/people_Walking.mp4")
assert cap.isOpened(), "Error opening video file"

# Init distance calculation object
dist_calc = distance_calculation.DistanceCalculation()

while cap.isOpened():
    success, frame = cap.read()
    if not success: break

    # Perform tracking
    tracks = model.track(frame, persist=True, show=False)
    
    # Calculate and draw distances
    frame = dist_calc.start_process(frame, tracks)
    
    # Optional: Display the frame
    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) == ord('q'): break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 100%|██████████████████████████████████████| 6.25M/6.25M [00:05<00:00, 1.25MB/s]
# Ultralytics Solutions: ✅ {'region': None, 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5}
#
# 0: 384x640 39 persons, 2 birds, 67.0ms
# Speed: 3.8ms preprocess, 67.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 23
#      20 tracks = model.track(frame, persist=True, show=False)
#      22 # Calculate and draw distances
# ---> 23 frame = dist_calc.start_process(frame, tracks)
#      25 # Optional: Display the frame
#      26 cv2.imshow('Frame', frame)
#
# AttributeError: 'DistanceCalculation' object has no attribute 'start_process'
