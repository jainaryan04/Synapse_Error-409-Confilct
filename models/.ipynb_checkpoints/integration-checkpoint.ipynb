# %%
from fastapi import FastAPI
from starlette.responses import StreamingResponse, JSONResponse
import cv2
import math
import random
import json
from collections import defaultdict
from scipy.spatial import distance
from ultralytics import YOLO
import uvicorn
import nest_asyncio

nest_asyncio.apply()

app = FastAPI()

video_url = "http://192.168.69.91:8080/video"
cap = cv2.VideoCapture(video_url)

model = YOLO("../models/first_model.pt")
LABEL_COLORS = {}
allowed_pairs = {
    ("tank", "friend"),
    ("enemy", "friend"),
    ("enemy", "wall"),
    ("friend", "wall")
}
distance_data_store = {}  # Global variable to store JSON data
centers=[]


class ObjectTracker:
    def __init__(self):
        self.objects = {}
        self.next_id = 1
        self.type_counters = defaultdict(int)
    
    def get_unique_name(self, class_name_lower):
        self.type_counters[class_name_lower] += 1
        return f"{class_name_lower.capitalize()}{self.type_counters[class_name_lower]}"
    
    def track_object(self, center_x, center_y, class_name_lower, frame_counter):
        for obj_id, obj_info in self.objects.items():
            if (obj_info['type'] == class_name_lower and 
                distance.euclidean((obj_info['last_x'], obj_info['last_y']), (center_x, center_y)) < 50):
                obj_info.update({
                    'last_x': center_x,
                    'last_y': center_y,
                    'last_seen': frame_counter,
                    'status': 'Active'
                })
                return obj_id
        
        unique_name = self.get_unique_name(class_name_lower)
        new_id = unique_name
        
        self.objects[new_id] = {
            'type': class_name_lower,
            'last_x': center_x,
            'last_y': center_y,
            'last_seen': frame_counter,
            'status': 'Active'
        }
        
        return new_id

    def clean_old_objects(self, frame_counter):
        for obj_id, obj_info in list(self.objects.items()):
            if frame_counter - obj_info['last_seen'] > 10:
                obj_info['status'] = 'Dead'

    def calculate_distances(self, frame_counter):
        distance_data = {}
        active_objects = [
            (obj_id, info['last_x'], info['last_y']) 
            for obj_id, info in self.objects.items() 
            if info['status'] == 'Active'
        ]
        
        for friend_id, friend_x, friend_y in [
            obj for obj in active_objects 
            if self.objects[obj[0]]['type'] == 'friend'
        ]:
            friend_distances = {}
            
            for other_id, other_x, other_y in active_objects:
                if other_id == friend_id:
                    continue
                
                dist_pixels = int(math.dist((friend_x, friend_y), (other_x, other_y)))
                friend_distances[other_id] = f"{dist_pixels}px"
            
            dead_objects = [
                obj_id for obj_id, info in self.objects.items() 
                if info['status'] == 'Dead'
            ]
            
            for dead_id in dead_objects:
                friend_distances[dead_id] = "Dead"
            
            distance_data[friend_id] = friend_distances if friend_distances else "lonely"
        
        return distance_data

object_tracker = ObjectTracker()


def get_label_color(label):
    if label not in LABEL_COLORS:
        LABEL_COLORS[label] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label]

def generate_frames():
    global distance_data_store  # Store JSON data globally
    frame_counter = 0
    while True:
        success, frame = cap.read()
        if not success:
            break

        frame_counter += 1
        centers = []
        results = model(frame)
        detections = results[0].boxes  

        for box in detections:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            label_id = int(box.cls[0])
            class_name = model.names[label_id].lower()
            center_x, center_y = (x1 + x2) // 2, (y1 + y2) // 2
            obj_id = object_tracker.track_object(center_x, center_y, class_name, frame_counter)

            color = get_label_color(label_id)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, obj_id, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            centers.append((center_x, center_y, class_name, obj_id))

        for i in range(len(centers)):
            for j in range(i + 1, len(centers)):
                p1_x, p1_y, label1, name1 = centers[i]
                p2_x, p2_y, label2, name2 = centers[j]
                if (label1, label2) in allowed_pairs or (label2, label1) in allowed_pairs:
                    distance_pixels = int(math.dist((p1_x, p1_y), (p2_x, p2_y)))
                    cv2.line(frame, (p1_x, p1_y), (p2_x, p2_y), (255, 255, 0), 2)
                    midpoint = ((p1_x + p2_x) // 2, (p1_y + p2_y) // 2)
                    cv2.putText(frame, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)


        
        object_tracker.clean_old_objects(frame_counter)

        distance_data_store = object_tracker.calculate_distances(frame_counter) 

        _, buffer = cv2.imencode(".jpg", frame)
        frame_bytes = buffer.tobytes()

        yield (b"--frame\r\n"
               b"Content-Type: image/jpeg\r\n\r\n" + frame_bytes + b"\r\n")

@app.get("/video_feed")
def video_feed():
    return StreamingResponse(generate_frames(), media_type="multipart/x-mixed-replace; boundary=frame")



if __name__ == "__main__":
    uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# INFO:     Started server process [43032]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:65468 - "GET /video_feed?t=1738659036716 HTTP/1.1" 200 OK
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 37.5ms
# Speed: 1.7ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "756px",
#         "Wall1": "407px",
#         "Dead soldier -enemy-1": "733px",
#         "Enemy1": "781px",
#         "Friend2": "303px",
#         "Enemy2": "732px"
#     },
#     "Friend2": {
#         "Tank1": "452px",
#         "Wall1": "215px",
#         "Dead soldier -enemy-1": "491px",
#         "Enemy1": "487px",
#         "Friend1": "303px",
#         "Enemy2": "491px"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "755px",
#         "Wall1": "405px",
#         "Dead soldier -enemy-1": "737px",
#         "Enemy1": "777px",
#         "Friend2": "305px",
#         "Enemy2": "732px"
#     },
#     "Friend2": {
#         "Tank1": "450px",
#         "Wall1": "208px",
#         "Dead soldier -enemy-1": "502px",
#         "Enemy1": "482px",
#         "Friend1": "305px",
#         "Enemy2": "491px"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 64.3ms
# Speed: 1.5ms preprocess, 64.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "751px",
#         "Wall1": "409px",
#         "Dead soldier -enemy-1": "734px",
#         "Enemy1": "774px",
#         "Friend2": "307px",
#         "Enemy2": "733px"
#     },
#     "Friend2": {
#         "Tank1": "443px",
#         "Wall1": "210px",
#         "Dead soldier -enemy-1": "496px",
#         "Enemy1": "475px",
#         "Friend1": "307px",
#         "Enemy2": "487px"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "746px",
#         "Wall1": "407px",
#         "Dead soldier -enemy-1": "727px",
#         "Enemy1": "769px",
#         "Friend2": "305px",
#         "Enemy2": "726px"
#     },
#     "Friend2": {
#         "Tank1": "440px",
#         "Wall1": "214px",
#         "Dead soldier -enemy-1": "493px",
#         "Enemy1": "472px",
#         "Friend1": "305px",
#         "Enemy2": "485px"
#     }
# }
#
# 0: 384x640 2 Tanks, 1 Wall, 2 enemys, 2 friends, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "743px",
#         "Wall1": "406px",
#         "Dead soldier -enemy-1": "719px",
#         "Enemy1": "763px",
#         "Friend2": "304px",
#         "Enemy2": "721px",
#         "Tank2": "305px"
#     },
#     "Friend2": {
#         "Tank1": "439px",
#         "Wall1": "219px",
#         "Dead soldier -enemy-1": "489px",
#         "Enemy1": "470px",
#         "Friend1": "304px",
#         "Enemy2": "484px",
#         "Tank2": "1px"
#     }
# }
#
# 0: 384x640 2 Tanks, 1 Wall, 2 enemys, 2 friends, 40.5ms
# Speed: 1.5ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "738px",
#         "Wall1": "403px",
#         "Dead soldier -enemy-1": "712px",
#         "Enemy1": "758px",
#         "Friend2": "302px",
#         "Enemy2": "716px",
#         "Tank2": "302px"
#     },
#     "Friend2": {
#         "Tank1": "435px",
#         "Wall1": "215px",
#         "Dead soldier -enemy-1": "479px",
#         "Enemy1": "465px",
#         "Friend1": "302px",
#         "Enemy2": "478px",
#         "Tank2": "2px"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 2 enemys, 2 friends, 40.5ms
# Speed: 1.2ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "736px",
#         "Wall1": "402px",
#         "Dead soldier -enemy-1": "715px",
#         "Enemy1": "754px",
#         "Friend2": "300px",
#         "Enemy2": "714px",
#         "Tank2": "301px"
#     },
#     "Friend2": {
#         "Tank1": "436px",
#         "Wall1": "210px",
#         "Dead soldier -enemy-1": "477px",
#         "Enemy1": "461px",
#         "Friend1": "300px",
#         "Enemy2": "476px",
#         "Tank2": "1px"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 36.5ms
# Speed: 1.6ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "734px",
#         "Wall1": "400px",
#         "Dead soldier -enemy-1": "709px",
#         "Enemy1": "751px",
#         "Friend2": "301px",
#         "Enemy2": "710px",
#         "Tank2": "299px"
#     },
#     "Friend2": {
#         "Tank1": "433px",
#         "Wall1": "209px",
#         "Dead soldier -enemy-1": "471px",
#         "Enemy1": "458px",
#         "Friend1": "301px",
#         "Enemy2": "472px",
#         "Tank2": "12px"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 2 friends, 38.7ms
# Speed: 1.6ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "732px",
#         "Wall1": "397px",
#         "Dead soldier -enemy-1": "707px",
#         "Enemy1": "749px",
#         "Friend2": "299px",
#         "Enemy2": "708px",
#         "Tank2": "296px",
#         "Dead soldier -frd-1": "298px",
#         "Wall2": "541px"
#     },
#     "Friend2": {
#         "Tank1": "433px",
#         "Wall1": "206px",
#         "Dead soldier -enemy-1": "471px",
#         "Enemy1": "458px",
#         "Friend1": "299px",
#         "Enemy2": "472px",
#         "Tank2": "20px",
#         "Dead soldier -frd-1": "1px",
#         "Wall2": "314px"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 37.7ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "730px",
#         "Wall1": "395px",
#         "Dead soldier -enemy-1": "706px",
#         "Enemy1": "748px",
#         "Friend2": "299px",
#         "Enemy2": "707px",
#         "Tank2": "294px",
#         "Dead soldier -frd-1": "296px",
#         "Wall2": "543px"
#     },
#     "Friend2": {
#         "Tank1": "431px",
#         "Wall1": "209px",
#         "Dead soldier -enemy-1": "471px",
#         "Enemy1": "457px",
#         "Friend1": "299px",
#         "Enemy2": "472px",
#         "Tank2": "27px",
#         "Dead soldier -frd-1": "8px",
#         "Wall2": "318px"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 35.3ms
# Speed: 1.3ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "732px",
#         "Wall1": "398px",
#         "Dead soldier -enemy-1": "706px",
#         "Enemy1": "749px",
#         "Friend2": "300px",
#         "Enemy2": "707px",
#         "Tank2": "293px",
#         "Dead soldier -frd-1": "294px",
#         "Wall2": "545px"
#     },
#     "Friend2": {
#         "Tank1": "431px",
#         "Wall1": "215px",
#         "Dead soldier -enemy-1": "472px",
#         "Enemy1": "457px",
#         "Friend1": "300px",
#         "Enemy2": "473px",
#         "Tank2": "32px",
#         "Dead soldier -frd-1": "13px",
#         "Wall2": "321px"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 36.0ms
# Speed: 1.5ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "728px",
#         "Wall1": "396px",
#         "Dead soldier -enemy-1": "704px",
#         "Enemy1": "745px",
#         "Friend2": "297px",
#         "Enemy2": "705px",
#         "Tank2": "290px",
#         "Dead soldier -frd-1": "290px",
#         "Wall2": "545px"
#     },
#     "Friend2": {
#         "Tank1": "432px",
#         "Wall1": "210px",
#         "Dead soldier -enemy-1": "468px",
#         "Enemy1": "455px",
#         "Friend1": "297px",
#         "Enemy2": "469px",
#         "Tank2": "47px",
#         "Dead soldier -frd-1": "28px",
#         "Wall2": "333px"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 35.2ms
# Speed: 1.5ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "725px",
#         "Wall1": "393px",
#         "Dead soldier -enemy-1": "702px",
#         "Enemy1": "743px",
#         "Friend2": "296px",
#         "Enemy2": "702px",
#         "Tank2": "289px",
#         "Dead soldier -frd-1": "289px",
#         "Wall2": "548px"
#     },
#     "Friend2": {
#         "Tank1": "429px",
#         "Wall1": "211px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "296px",
#         "Enemy2": "470px",
#         "Tank2": "53px",
#         "Dead soldier -frd-1": "33px",
#         "Wall2": "337px"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 38.1ms
# Speed: 1.3ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "724px",
#         "Wall1": "393px",
#         "Dead soldier -enemy-1": "697px",
#         "Enemy1": "744px",
#         "Friend2": "293px",
#         "Enemy2": "703px",
#         "Tank2": "287px",
#         "Dead soldier -frd-1": "287px",
#         "Wall2": "548px"
#     },
#     "Friend2": {
#         "Tank1": "431px",
#         "Wall1": "214px",
#         "Dead soldier -enemy-1": "467px",
#         "Enemy1": "460px",
#         "Friend1": "293px",
#         "Enemy2": "474px",
#         "Tank2": "57px",
#         "Dead soldier -frd-1": "38px",
#         "Wall2": "341px"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "724px",
#         "Wall1": "391px",
#         "Dead soldier -enemy-1": "698px",
#         "Enemy1": "741px",
#         "Friend2": "293px",
#         "Enemy2": "700px",
#         "Tank2": "286px",
#         "Dead soldier -frd-1": "285px",
#         "Wall2": "551px"
#     },
#     "Friend2": {
#         "Tank1": "431px",
#         "Wall1": "213px",
#         "Dead soldier -enemy-1": "471px",
#         "Enemy1": "457px",
#         "Friend1": "293px",
#         "Enemy2": "473px",
#         "Tank2": "63px",
#         "Dead soldier -frd-1": "44px",
#         "Wall2": "344px"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 38.4ms
# Speed: 1.3ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "724px",
#         "Wall1": "390px",
#         "Dead soldier -enemy-1": "693px",
#         "Enemy1": "740px",
#         "Friend2": "294px",
#         "Enemy2": "697px",
#         "Tank2": "285px",
#         "Dead soldier -frd-1": "284px",
#         "Wall2": "551px"
#     },
#     "Friend2": {
#         "Tank1": "429px",
#         "Wall1": "213px",
#         "Dead soldier -enemy-1": "466px",
#         "Enemy1": "455px",
#         "Friend1": "294px",
#         "Enemy2": "471px",
#         "Tank2": "68px",
#         "Dead soldier -frd-1": "49px",
#         "Wall2": "346px"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 37.9ms
# Speed: 1.4ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "724px",
#         "Wall1": "391px",
#         "Dead soldier -enemy-1": "690px",
#         "Enemy1": "740px",
#         "Friend2": "293px",
#         "Enemy2": "699px",
#         "Tank2": "285px",
#         "Dead soldier -frd-1": "284px",
#         "Wall2": "553px"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "211px",
#         "Dead soldier -enemy-1": "461px",
#         "Enemy1": "455px",
#         "Friend1": "293px",
#         "Enemy2": "470px",
#         "Tank2": "74px",
#         "Dead soldier -frd-1": "55px",
#         "Wall2": "352px"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 38.1ms
# Speed: 1.3ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "725px",
#         "Wall1": "391px",
#         "Dead soldier -enemy-1": "698px",
#         "Enemy1": "741px",
#         "Friend2": "292px",
#         "Enemy2": "697px",
#         "Dead soldier -frd-1": "284px",
#         "Wall2": "555px",
#         "Tank2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "432px",
#         "Wall1": "213px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "457px",
#         "Friend1": "292px",
#         "Enemy2": "470px",
#         "Dead soldier -frd-1": "57px",
#         "Wall2": "355px",
#         "Tank2": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 37.4ms
# Speed: 1.5ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "721px",
#         "Wall1": "388px",
#         "Dead soldier -enemy-1": "693px",
#         "Enemy1": "740px",
#         "Friend2": "290px",
#         "Enemy2": "696px",
#         "Dead soldier -frd-1": "282px",
#         "Wall2": "555px",
#         "Tank2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "431px",
#         "Wall1": "210px",
#         "Dead soldier -enemy-1": "468px",
#         "Enemy1": "458px",
#         "Friend1": "290px",
#         "Enemy2": "471px",
#         "Dead soldier -frd-1": "61px",
#         "Wall2": "357px",
#         "Tank2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 39.7ms
# Speed: 3.8ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "723px",
#         "Wall1": "389px",
#         "Dead soldier -enemy-1": "697px",
#         "Enemy1": "738px",
#         "Friend2": "292px",
#         "Enemy2": "697px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "431px",
#         "Wall1": "211px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "292px",
#         "Enemy2": "471px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 37.8ms
# Speed: 1.4ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "724px",
#         "Wall1": "385px",
#         "Dead soldier -enemy-1": "694px",
#         "Enemy1": "739px",
#         "Friend2": "293px",
#         "Enemy2": "696px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "204px",
#         "Dead soldier -enemy-1": "466px",
#         "Enemy1": "454px",
#         "Friend1": "293px",
#         "Enemy2": "469px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 39.1ms
# Speed: 1.4ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "724px",
#         "Wall1": "383px",
#         "Dead soldier -enemy-1": "699px",
#         "Enemy1": "739px",
#         "Friend2": "293px",
#         "Enemy2": "700px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "197px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "454px",
#         "Friend1": "293px",
#         "Enemy2": "472px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 38.0ms
# Speed: 1.3ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "725px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "699px",
#         "Enemy1": "739px",
#         "Friend2": "293px",
#         "Enemy2": "700px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "431px",
#         "Wall1": "208px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "454px",
#         "Friend1": "293px",
#         "Enemy2": "472px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 40.2ms
# Speed: 2.1ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "723px",
#         "Wall1": "384px",
#         "Dead soldier -enemy-1": "697px",
#         "Enemy1": "739px",
#         "Friend2": "294px",
#         "Enemy2": "699px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "429px",
#         "Wall1": "202px",
#         "Dead soldier -enemy-1": "469px",
#         "Enemy1": "454px",
#         "Friend1": "294px",
#         "Enemy2": "472px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 2 enemys, 1 friend, 38.8ms
# Speed: 1.3ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "725px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "699px",
#         "Enemy1": "741px",
#         "Friend2": "295px",
#         "Enemy2": "700px",
#         "Tank3": "295px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "208px",
#         "Dead soldier -enemy-1": "472px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 38.5ms
# Speed: 1.4ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank3": "296px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 2 enemys, 1 friend, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank3": "296px",
#         "Tank4": "1052px",
#         "Wall3": "676px",
#         "Enemy3": "1083px",
#         "Friend3": "303px",
#         "Tank5": "593px",
#         "Dead soldier -enemy-2": "1027px",
#         "Enemy4": "1027px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank4": "758px",
#         "Wall3": "438px",
#         "Enemy3": "803px",
#         "Friend3": "59px",
#         "Tank5": "304px",
#         "Dead soldier -enemy-2": "787px",
#         "Enemy4": "788px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "436px",
#         "Wall1": "145px",
#         "Dead soldier -enemy-1": "426px",
#         "Enemy1": "439px",
#         "Friend1": "303px",
#         "Friend2": "59px",
#         "Enemy2": "428px",
#         "Tank3": "61px",
#         "Tank4": "751px",
#         "Wall3": "396px",
#         "Enemy3": "781px",
#         "Tank5": "291px",
#         "Dead soldier -enemy-2": "748px",
#         "Enemy4": "748px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 1 enemy, 1 friend, 37.7ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank3": "296px",
#         "Tank4": "1052px",
#         "Wall3": "672px",
#         "Enemy3": "1082px",
#         "Friend3": "303px",
#         "Tank5": "592px",
#         "Dead soldier -enemy-2": "1029px",
#         "Enemy4": "1027px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank4": "759px",
#         "Wall3": "432px",
#         "Enemy3": "802px",
#         "Friend3": "64px",
#         "Tank5": "303px",
#         "Dead soldier -enemy-2": "790px",
#         "Enemy4": "788px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "438px",
#         "Wall1": "140px",
#         "Dead soldier -enemy-1": "423px",
#         "Enemy1": "438px",
#         "Friend1": "303px",
#         "Friend2": "64px",
#         "Enemy2": "425px",
#         "Tank3": "66px",
#         "Tank4": "751px",
#         "Wall3": "388px",
#         "Enemy3": "780px",
#         "Tank5": "289px",
#         "Dead soldier -enemy-2": "748px",
#         "Enemy4": "745px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 2 enemys, 1 friend, 39.4ms
# Speed: 1.6ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank3": "296px",
#         "Tank4": "1053px",
#         "Wall3": "672px",
#         "Enemy3": "1084px",
#         "Friend3": "305px",
#         "Tank5": "593px",
#         "Dead soldier -enemy-2": "1030px",
#         "Enemy4": "1030px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank4": "760px",
#         "Wall3": "432px",
#         "Enemy3": "804px",
#         "Friend3": "72px",
#         "Tank5": "306px",
#         "Dead soldier -enemy-2": "791px",
#         "Enemy4": "791px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "440px",
#         "Wall1": "132px",
#         "Dead soldier -enemy-1": "418px",
#         "Enemy1": "438px",
#         "Friend1": "305px",
#         "Friend2": "72px",
#         "Enemy2": "420px",
#         "Tank3": "74px",
#         "Tank4": "751px",
#         "Wall3": "383px",
#         "Enemy3": "779px",
#         "Tank5": "290px",
#         "Dead soldier -enemy-2": "744px",
#         "Enemy4": "744px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 2 Tanks, 1 Wall, 2 enemys, 1 friend, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank3": "296px",
#         "Tank4": "1051px",
#         "Wall3": "679px",
#         "Enemy3": "1085px",
#         "Friend3": "306px",
#         "Tank5": "594px",
#         "Dead soldier -enemy-2": "1030px",
#         "Enemy4": "1034px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank4": "759px",
#         "Wall3": "444px",
#         "Enemy3": "807px",
#         "Friend3": "86px",
#         "Tank5": "309px",
#         "Dead soldier -enemy-2": "791px",
#         "Enemy4": "796px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "445px",
#         "Wall1": "120px",
#         "Dead soldier -enemy-1": "411px",
#         "Enemy1": "438px",
#         "Friend1": "306px",
#         "Friend2": "86px",
#         "Enemy2": "413px",
#         "Tank3": "88px",
#         "Tank4": "750px",
#         "Wall3": "386px",
#         "Enemy3": "779px",
#         "Tank5": "290px",
#         "Dead soldier -enemy-2": "737px",
#         "Enemy4": "742px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 38.2ms
# Speed: 1.6ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank3": "296px",
#         "Tank4": "1046px",
#         "Wall3": "681px",
#         "Enemy3": "1081px",
#         "Friend3": "306px",
#         "Tank5": "594px",
#         "Dead soldier -enemy-2": "1030px",
#         "Enemy4": "1034px",
#         "Friend4": "592px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank4": "754px",
#         "Wall3": "451px",
#         "Enemy3": "804px",
#         "Friend3": "101px",
#         "Tank5": "309px",
#         "Dead soldier -enemy-2": "791px",
#         "Enemy4": "798px",
#         "Friend4": "310px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "454px",
#         "Wall1": "108px",
#         "Dead soldier -enemy-1": "405px",
#         "Enemy1": "442px",
#         "Friend1": "306px",
#         "Friend2": "101px",
#         "Enemy2": "407px",
#         "Tank3": "103px",
#         "Tank4": "748px",
#         "Wall3": "385px",
#         "Enemy3": "775px",
#         "Tank5": "294px",
#         "Dead soldier -enemy-2": "733px",
#         "Enemy4": "738px",
#         "Friend4": "290px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "213px",
#         "Wall1": "256px",
#         "Dead soldier -enemy-1": "228px",
#         "Enemy1": "152px",
#         "Friend1": "592px",
#         "Friend2": "310px",
#         "Enemy2": "230px",
#         "Tank3": "309px",
#         "Tank4": "458px",
#         "Wall3": "214px",
#         "Enemy3": "494px",
#         "Friend3": "290px",
#         "Tank5": "15px",
#         "Dead soldier -enemy-2": "505px",
#         "Enemy4": "514px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 37.5ms
# Speed: 1.3ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank3": "296px",
#         "Tank4": "1040px",
#         "Wall3": "678px",
#         "Enemy3": "1079px",
#         "Friend3": "304px",
#         "Tank5": "594px",
#         "Dead soldier -enemy-2": "1030px",
#         "Enemy4": "1031px",
#         "Friend4": "586px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank4": "749px",
#         "Wall3": "449px",
#         "Enemy3": "803px",
#         "Friend3": "110px",
#         "Tank5": "309px",
#         "Dead soldier -enemy-2": "795px",
#         "Enemy4": "797px",
#         "Friend4": "306px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "461px",
#         "Wall1": "102px",
#         "Dead soldier -enemy-1": "403px",
#         "Enemy1": "446px",
#         "Friend1": "304px",
#         "Friend2": "110px",
#         "Enemy2": "405px",
#         "Tank3": "112px",
#         "Tank4": "746px",
#         "Wall3": "381px",
#         "Enemy3": "775px",
#         "Tank5": "298px",
#         "Dead soldier -enemy-2": "733px",
#         "Enemy4": "734px",
#         "Friend4": "287px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "225px",
#         "Wall1": "246px",
#         "Dead soldier -enemy-1": "220px",
#         "Enemy1": "159px",
#         "Friend1": "586px",
#         "Friend2": "306px",
#         "Enemy2": "223px",
#         "Tank3": "306px",
#         "Tank4": "459px",
#         "Wall3": "208px",
#         "Enemy3": "497px",
#         "Friend3": "287px",
#         "Tank5": "26px",
#         "Dead soldier -enemy-2": "509px",
#         "Enemy4": "512px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 2 enemys, 1 friend, 43.7ms
# Speed: 4.9ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank3": "296px",
#         "Tank4": "1030px",
#         "Wall3": "672px",
#         "Enemy3": "1071px",
#         "Friend3": "297px",
#         "Tank5": "579px",
#         "Dead soldier -enemy-2": "1025px",
#         "Enemy4": "1025px",
#         "Friend4": "586px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank4": "739px",
#         "Wall3": "446px",
#         "Enemy3": "796px",
#         "Friend3": "122px",
#         "Tank5": "302px",
#         "Dead soldier -enemy-2": "792px",
#         "Enemy4": "792px",
#         "Friend4": "306px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "477px",
#         "Wall1": "99px",
#         "Dead soldier -enemy-1": "407px",
#         "Enemy1": "458px",
#         "Friend1": "297px",
#         "Friend2": "122px",
#         "Enemy2": "409px",
#         "Tank3": "125px",
#         "Tank4": "747px",
#         "Wall3": "379px",
#         "Enemy3": "775px",
#         "Tank5": "291px",
#         "Dead soldier -enemy-2": "732px",
#         "Enemy4": "733px",
#         "Friend4": "299px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "225px",
#         "Wall1": "246px",
#         "Dead soldier -enemy-1": "220px",
#         "Enemy1": "159px",
#         "Friend1": "586px",
#         "Friend2": "306px",
#         "Enemy2": "223px",
#         "Tank3": "306px",
#         "Tank4": "448px",
#         "Wall3": "211px",
#         "Enemy3": "489px",
#         "Friend3": "299px",
#         "Tank5": "10px",
#         "Dead soldier -enemy-2": "508px",
#         "Enemy4": "509px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 1 Wall, 2 enemys, 1 friend, 38.3ms
# Speed: 1.5ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank3": "296px",
#         "Tank4": "1021px",
#         "Wall3": "667px",
#         "Enemy3": "1061px",
#         "Friend3": "288px",
#         "Tank5": "579px",
#         "Dead soldier -enemy-2": "1019px",
#         "Enemy4": "1018px",
#         "Friend4": "586px",
#         "Dead soldier -frd-2": "570px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank4": "730px",
#         "Wall3": "446px",
#         "Enemy3": "787px",
#         "Friend3": "127px",
#         "Tank5": "302px",
#         "Dead soldier -enemy-2": "788px",
#         "Enemy4": "787px",
#         "Friend4": "306px",
#         "Dead soldier -frd-2": "295px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "488px",
#         "Wall1": "105px",
#         "Dead soldier -enemy-1": "415px",
#         "Enemy1": "469px",
#         "Friend1": "288px",
#         "Friend2": "127px",
#         "Enemy2": "417px",
#         "Tank3": "129px",
#         "Tank4": "748px",
#         "Wall3": "383px",
#         "Enemy3": "775px",
#         "Tank5": "302px",
#         "Dead soldier -enemy-2": "735px",
#         "Enemy4": "734px",
#         "Friend4": "310px",
#         "Dead soldier -frd-2": "291px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "225px",
#         "Wall1": "246px",
#         "Dead soldier -enemy-1": "220px",
#         "Enemy1": "159px",
#         "Friend1": "586px",
#         "Friend2": "306px",
#         "Enemy2": "223px",
#         "Tank3": "306px",
#         "Tank4": "438px",
#         "Wall3": "220px",
#         "Enemy3": "480px",
#         "Friend3": "310px",
#         "Tank5": "10px",
#         "Dead soldier -enemy-2": "505px",
#         "Enemy4": "505px",
#         "Dead soldier -frd-2": "24px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 1 Wall, 2 enemys, 2 friends, 39.1ms
# Speed: 1.3ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank3": "296px",
#         "Tank4": "1016px",
#         "Wall3": "657px",
#         "Enemy3": "1056px",
#         "Friend3": "281px",
#         "Tank5": "579px",
#         "Dead soldier -enemy-2": "1016px",
#         "Enemy4": "1015px",
#         "Friend4": "566px",
#         "Dead soldier -frd-2": "568px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank3": "2px",
#         "Tank4": "726px",
#         "Wall3": "434px",
#         "Enemy3": "783px",
#         "Friend3": "135px",
#         "Tank5": "302px",
#         "Dead soldier -enemy-2": "785px",
#         "Enemy4": "784px",
#         "Friend4": "292px",
#         "Dead soldier -frd-2": "294px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "499px",
#         "Wall1": "108px",
#         "Dead soldier -enemy-1": "420px",
#         "Enemy1": "478px",
#         "Friend1": "281px",
#         "Friend2": "135px",
#         "Enemy2": "422px",
#         "Tank3": "137px",
#         "Tank4": "752px",
#         "Wall3": "377px",
#         "Enemy3": "778px",
#         "Tank5": "311px",
#         "Dead soldier -enemy-2": "736px",
#         "Enemy4": "736px",
#         "Friend4": "295px",
#         "Dead soldier -frd-2": "297px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "254px",
#         "Wall1": "218px",
#         "Dead soldier -enemy-1": "210px",
#         "Enemy1": "185px",
#         "Friend1": "566px",
#         "Friend2": "292px",
#         "Enemy2": "213px",
#         "Tank3": "292px",
#         "Tank4": "457px",
#         "Wall3": "192px",
#         "Enemy3": "492px",
#         "Friend3": "295px",
#         "Tank5": "19px",
#         "Dead soldier -enemy-2": "505px",
#         "Enemy4": "505px",
#         "Dead soldier -frd-2": "2px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead"
#     }
# }
#
# 0: 384x640 2 Tanks, 1 Wall, 2 enemys, 1 friend, 39.7ms
# Speed: 1.2ms preprocess, 39.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "726px",
#         "Wall1": "387px",
#         "Dead soldier -enemy-1": "701px",
#         "Enemy1": "742px",
#         "Friend2": "295px",
#         "Enemy2": "703px",
#         "Tank4": "1012px",
#         "Wall3": "655px",
#         "Enemy3": "1053px",
#         "Friend3": "278px",
#         "Tank5": "563px",
#         "Dead soldier -enemy-2": "1016px",
#         "Enemy4": "1013px",
#         "Friend4": "566px",
#         "Dead soldier -frd-2": "568px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "430px",
#         "Wall1": "203px",
#         "Dead soldier -enemy-1": "470px",
#         "Enemy1": "455px",
#         "Friend1": "295px",
#         "Enemy2": "473px",
#         "Tank4": "722px",
#         "Wall3": "434px",
#         "Enemy3": "780px",
#         "Friend3": "136px",
#         "Tank5": "291px",
#         "Dead soldier -enemy-2": "785px",
#         "Enemy4": "782px",
#         "Friend4": "292px",
#         "Dead soldier -frd-2": "294px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "502px",
#         "Wall1": "111px",
#         "Dead soldier -enemy-1": "424px",
#         "Enemy1": "482px",
#         "Friend1": "278px",
#         "Friend2": "136px",
#         "Enemy2": "425px",
#         "Tank4": "752px",
#         "Wall3": "378px",
#         "Enemy3": "779px",
#         "Tank5": "296px",
#         "Dead soldier -enemy-2": "740px",
#         "Enemy4": "737px",
#         "Friend4": "299px",
#         "Dead soldier -frd-2": "301px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "254px",
#         "Wall1": "218px",
#         "Dead soldier -enemy-1": "210px",
#         "Enemy1": "185px",
#         "Friend1": "566px",
#         "Friend2": "292px",
#         "Enemy2": "213px",
#         "Tank4": "453px",
#         "Wall3": "196px",
#         "Enemy3": "489px",
#         "Friend3": "299px",
#         "Tank5": "4px",
#         "Dead soldier -enemy-2": "505px",
#         "Enemy4": "503px",
#         "Dead soldier -frd-2": "2px",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 2 Dead soldier -enemy-s, 2 Tanks, 1 Wall, 2 enemys, 1 friend, 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Tank4": "753px",
#         "Wall3": "382px",
#         "Enemy3": "780px",
#         "Tank5": "295px",
#         "Dead soldier -enemy-2": "738px",
#         "Enemy4": "738px",
#         "Friend4": "302px",
#         "Dead soldier -frd-2": "304px",
#         "Dead soldier -enemy-3": "779px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank4": "451px",
#         "Wall3": "202px",
#         "Enemy3": "487px",
#         "Friend3": "302px",
#         "Tank5": "7px",
#         "Dead soldier -enemy-2": "501px",
#         "Enemy4": "501px",
#         "Dead soldier -frd-2": "2px",
#         "Dead soldier -enemy-3": "487px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 2 enemys, 1 friend, 45.5ms
# Speed: 1.5ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Tank4": "755px",
#         "Wall3": "382px",
#         "Enemy3": "783px",
#         "Tank5": "295px",
#         "Dead soldier -enemy-2": "743px",
#         "Enemy4": "744px",
#         "Friend4": "305px",
#         "Dead soldier -frd-2": "307px",
#         "Dead soldier -enemy-3": "783px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank4": "450px",
#         "Wall3": "195px",
#         "Enemy3": "486px",
#         "Friend3": "305px",
#         "Tank5": "11px",
#         "Dead soldier -enemy-2": "500px",
#         "Enemy4": "502px",
#         "Dead soldier -frd-2": "2px",
#         "Dead soldier -enemy-3": "487px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 2 enemys, 1 friend, 40.4ms
# Speed: 1.4ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Tank4": "759px",
#         "Wall3": "386px",
#         "Enemy3": "788px",
#         "Tank5": "297px",
#         "Dead soldier -enemy-2": "747px",
#         "Enemy4": "749px",
#         "Friend4": "309px",
#         "Dead soldier -frd-2": "311px",
#         "Dead soldier -enemy-3": "787px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank4": "451px",
#         "Wall3": "194px",
#         "Enemy3": "487px",
#         "Friend3": "309px",
#         "Tank5": "14px",
#         "Dead soldier -enemy-2": "499px",
#         "Enemy4": "502px",
#         "Dead soldier -frd-2": "2px",
#         "Dead soldier -enemy-3": "487px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 2 enemys, 1 friend, 66.7ms
# Speed: 1.4ms preprocess, 66.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Tank4": "762px",
#         "Wall3": "384px",
#         "Enemy3": "790px",
#         "Tank5": "296px",
#         "Dead soldier -enemy-2": "751px",
#         "Enemy4": "751px",
#         "Friend4": "310px",
#         "Dead soldier -frd-2": "312px",
#         "Dead soldier -enemy-3": "790px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank4": "453px",
#         "Wall3": "182px",
#         "Enemy3": "486px",
#         "Friend3": "310px",
#         "Tank5": "19px",
#         "Dead soldier -enemy-2": "498px",
#         "Enemy4": "499px",
#         "Dead soldier -frd-2": "2px",
#         "Dead soldier -enemy-3": "487px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 2 Tanks, 1 Wall, 2 enemys, 1 friend, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Tank4": "767px",
#         "Wall3": "386px",
#         "Enemy3": "795px",
#         "Tank5": "302px",
#         "Dead soldier -enemy-2": "757px",
#         "Enemy4": "755px",
#         "Friend4": "316px",
#         "Dead soldier -frd-2": "318px",
#         "Dead soldier -enemy-3": "796px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank4": "453px",
#         "Wall3": "175px",
#         "Enemy3": "484px",
#         "Friend3": "316px",
#         "Tank5": "24px",
#         "Dead soldier -enemy-2": "498px",
#         "Enemy4": "495px",
#         "Dead soldier -frd-2": "2px",
#         "Dead soldier -enemy-3": "487px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Tank4": "770px",
#         "Wall3": "392px",
#         "Enemy3": "798px",
#         "Tank5": "306px",
#         "Dead soldier -enemy-2": "765px",
#         "Enemy4": "760px",
#         "Friend4": "302px",
#         "Dead soldier -frd-2": "323px",
#         "Dead soldier -enemy-3": "802px",
#         "Wall4": "553px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank4": "468px",
#         "Wall3": "206px",
#         "Enemy3": "506px",
#         "Friend3": "302px",
#         "Tank5": "10px",
#         "Dead soldier -enemy-2": "532px",
#         "Enemy4": "527px",
#         "Dead soldier -frd-2": "36px",
#         "Dead soldier -enemy-3": "514px",
#         "Wall4": "319px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 2 enemys, 2 friends, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Tank4": "772px",
#         "Wall3": "402px",
#         "Enemy3": "800px",
#         "Tank5": "308px",
#         "Dead soldier -enemy-2": "761px",
#         "Enemy4": "761px",
#         "Friend4": "301px",
#         "Dead soldier -frd-2": "326px",
#         "Dead soldier -enemy-3": "806px",
#         "Wall4": "555px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank4": "471px",
#         "Wall3": "221px",
#         "Enemy3": "507px",
#         "Friend3": "301px",
#         "Tank5": "15px",
#         "Dead soldier -enemy-2": "524px",
#         "Enemy4": "524px",
#         "Dead soldier -frd-2": "41px",
#         "Dead soldier -enemy-3": "518px",
#         "Wall4": "330px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 1 enemy, 2 friends, 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Tank4": "775px",
#         "Wall3": "400px",
#         "Enemy3": "804px",
#         "Tank5": "302px",
#         "Dead soldier -enemy-2": "767px",
#         "Enemy4": "777px",
#         "Friend4": "302px",
#         "Dead soldier -frd-2": "334px",
#         "Dead soldier -enemy-3": "817px",
#         "Wall4": "547px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank4": "473px",
#         "Wall3": "216px",
#         "Enemy3": "511px",
#         "Friend3": "302px",
#         "Tank5": "0px",
#         "Dead soldier -enemy-2": "531px",
#         "Enemy4": "545px",
#         "Dead soldier -frd-2": "65px",
#         "Dead soldier -enemy-3": "531px",
#         "Wall4": "311px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 2 enemys, 2 friends, 64.6ms
# Speed: 1.4ms preprocess, 64.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Tank4": "779px",
#         "Wall3": "409px",
#         "Enemy3": "808px",
#         "Tank5": "308px",
#         "Dead soldier -enemy-2": "770px",
#         "Enemy4": "771px",
#         "Friend4": "304px",
#         "Dead soldier -frd-2": "345px",
#         "Dead soldier -enemy-3": "829px",
#         "Wall4": "559px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Friend2": "Dead",
#         "Enemy2": "Dead",
#         "Tank2": "Dead",
#         "Dead soldier -frd-1": "Dead",
#         "Wall2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank4": "475px",
#         "Wall3": "228px",
#         "Enemy3": "513px",
#         "Friend3": "304px",
#         "Tank5": "26px",
#         "Dead soldier -enemy-2": "531px",
#         "Enemy4": "532px",
#         "Dead soldier -frd-2": "90px",
#         "Dead soldier -enemy-3": "545px",
#         "Wall4": "328px",
#         "Tank1": "Dead",
#         "Wall1": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "
HTTP/1.1" 200 OK
# [mpjpeg @ 0x153d58ed0] Expected boundary '--' not found, instead found a line of 65 bytes
# INFO:     127.0.0.1:49207 - "GET /video_feed?t=1738659390714 HTTP/1.1" 200 OK
# [mpjpeg @ 0x153d58ed0] Expected boundary '--' not found, instead found a line of 18 bytes

# %%
from fastapi import FastAPI
from starlette.responses import StreamingResponse
import cv2
import math
import random
import json
from collections import defaultdict
from scipy.spatial import distance
from ultralytics import YOLO
import uvicorn
import nest_asyncio

nest_asyncio.apply()

app = FastAPI()

video_url = "http://192.168.69.91:8080/video"
cap = cv2.VideoCapture(video_url)

model = YOLO("../models/first_model.pt")
LABEL_COLORS = {}
allowed_pairs = {("tank", "friend"), ("enemy", "friend"), ("enemy", "wall"), ("friend", "wall")}

class ObjectTracker:
    def __init__(self):
        self.objects = {}
        self.type_counters = defaultdict(int)

    def get_unique_name(self, class_name):
        self.type_counters[class_name] += 1
        return f"{class_name.capitalize()}{self.type_counters[class_name]}"

    def track_object(self, center_x, center_y, class_name, frame_counter):
        for obj_id, obj_info in self.objects.items():
            if (obj_info['type'] == class_name and 
                distance.euclidean((obj_info['last_x'], obj_info['last_y']), (center_x, center_y)) < 50):
                obj_info.update({'last_x': center_x, 'last_y': center_y, 'last_seen': frame_counter, 'status': 'Active'})
                return obj_id

        unique_name = self.get_unique_name(class_name)
        self.objects[unique_name] = {'type': class_name, 'last_x': center_x, 'last_y': center_y, 'last_seen': frame_counter, 'status': 'Active'}
        return unique_name

    def clean_old_objects(self, frame_counter):
        for obj_id, obj_info in list(self.objects.items()):
            if frame_counter - obj_info['last_seen'] > 10:
                obj_info['status'] = 'Dead'

object_tracker = ObjectTracker()

def get_label_color(label):
    if label not in LABEL_COLORS:
        LABEL_COLORS[label] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label]

def generate_frames():
    frame_counter = 0
    while True:
        success, frame = cap.read()
        if not success:
            break

        frame_counter += 1
        centers = []
        results = model(frame)
        detections = results[0].boxes  

        for box in detections:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            label_id = int(box.cls[0])
            class_name = model.names[label_id].lower()
            center_x, center_y = (x1 + x2) // 2, (y1 + y2) // 2
            obj_id = object_tracker.track_object(center_x, center_y, class_name, frame_counter)

            color = get_label_color(label_id)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, obj_id, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            centers.append((center_x, center_y, class_name, obj_id))

        for i in range(len(centers)):
            for j in range(i + 1, len(centers)):
                p1_x, p1_y, label1, name1 = centers[i]
                p2_x, p2_y, label2, name2 = centers[j]
                if (label1, label2) in allowed_pairs or (label2, label1) in allowed_pairs:
                    distance_pixels = int(math.dist((p1_x, p1_y), (p2_x, p2_y)))
                    cv2.line(frame, (p1_x, p1_y), (p2_x, p2_y), (255, 255, 0), 2)
                    midpoint = ((p1_x + p2_x) // 2, (p1_y + p2_y) // 2)
                    cv2.putText(frame, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

        object_tracker.clean_old_objects(frame_counter)

        _, buffer = cv2.imencode(".jpg", frame)
        frame_bytes = buffer.tobytes()

        yield (b"--frame\r\n"
               b"Content-Type: image/jpeg\r\n\r\n" + frame_bytes + b"\r\n")

@app.get("/video_feed")
def video_feed():
    return StreamingResponse(generate_frames(), media_type="multipart/x-mixed-replace; boundary=frame")

if __name__ == "__main__":
    uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# INFO:     Started server process [37794]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:
3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 1 Tank, 1 friend, 37.5ms
# Speed: 1.3ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Dead soldier -frd-s, 1 Tank, 1 friend, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Dead soldier -frd-s, 1 Tank, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 1 Tank, 1 friend, 34.7ms
# Speed: 1.7ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 1 friend, 36.3ms
# Speed: 1.5ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Tanks, 1 friend, 37.2ms
# Speed: 1.3ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Tanks, 1 friend, 39.8ms
# Speed: 1.2ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 1 Tank, 35.5ms
# Speed: 1.4ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Dead soldier -frd-s, 1 Tank, 37.9ms
# Speed: 1.3ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 1 friend, 36.0ms
# Speed: 1.3ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 1 friend, 37.8ms
# Speed: 1.4ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 friend, 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 47.5ms
# Speed: 1.7ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.0ms
# Speed: 1.3ms preprocess, 36.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.8ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 39.2ms
# Speed: 1.3ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 36.7ms
# Speed: 1.4ms preprocess, 36.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 35.8ms
# Speed: 1.2ms preprocess, 35.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 36.3ms
# Speed: 1.6ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 39.0ms
# Speed: 1.3ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 36.9ms
# Speed: 1.4ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 friend, 39.7ms
# Speed: 1.6ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 friends, 37.0ms
# Speed: 1.5ms preprocess, 37.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 1 friend, 37.2ms
# Speed: 1.6ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Dead soldier -frd-s, 41.3ms
# Speed: 1.6ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 1 friend, 41.2ms
# Speed: 1.5ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 1 friend, 42.4ms
# Speed: 1.3ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 46.3ms
# Speed: 1.4ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 36.8ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 36.8ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 1 friend, 36.7ms
# Speed: 1.3ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 34.3ms
# Speed: 1.3ms preprocess, 34.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 1 friend, 37.3ms
# Speed: 1.3ms preprocess, 37.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 1 friend, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 34.4ms
# Speed: 1.3ms preprocess, 34.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 1 friend, 38.8ms
# Speed: 1.4ms preprocess, 38.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 37.4ms
# Speed: 1.3ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 39.3ms
# Speed: 1.3ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 37.8ms
# Speed: 1.3ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 1 Tank, 1 Wall, 1 friend, 41.0ms
# Speed: 1.5ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [mjpeg @ 0x17e93a4e0] overread 8
# 0: 384x640 1 Wall, 2 friends, 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 1 Wall, 3 friends, 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 1 Wall, 3 friends, 38.3ms
# Speed: 1.4ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# INFO:     127.0.0.1:58609 - "GET /video_feed?t=1738654026685 HTTP/1.1" 200 OK
#
# 0: 384x640 1 Wall, 1 enemy, 2 friends, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -frd-, 1 Wall, 1 friend, 51.4ms
# Speed: 2.7ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 48.3ms
# Speed: 2.3ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 1 Wall, 2 friends, 53.8ms
# Speed: 1.9ms preprocess, 53.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Wall, 2 friends, 52.0ms
# Speed: 1.9ms preprocess, 52.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 Dead soldier -frd-, 1 Wall, 2 friends, 47.5ms
# Speed: 2.0ms preprocess, 47.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Dead soldier -frd-s, 1 Wall, 2 friends, 49.9ms
# Speed: 1.4ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Wall, 1 friend, 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Dead soldier -frd-s, 1 Wall, 1 friend, 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 34.2ms
# Speed: 1.6ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 33.4ms
# Speed: 1.3ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 38.3ms
# Speed: 1.5ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 35.8ms
# Speed: 1.4ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Wall, 2 friends, 37.5ms
# Speed: 1.3ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 34.5ms
# Speed: 1.3ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 34.9ms
# Speed: 1.3ms preprocess, 34.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 40.7ms
# Speed: 1.2ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 36.4ms
# Speed: 1.3ms preprocess, 36.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Wall, 2 friends, 37.3ms
# Speed: 1.4ms preprocess, 37.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Wall, 2 friends, 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 34.6ms
# Speed: 1.3ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 36.1ms
# Speed: 1.4ms preprocess, 36.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Wall, 2 friends, 37.1ms
# Speed: 1.7ms preprocess, 37.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 36.3ms
# Speed: 1.5ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 36.7ms
# Speed: 1.4ms preprocess, 36.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 friends, 39.2ms
# Speed: 1.6ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Walls, 2 friends, 36.1ms
# Speed: 1.5ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Walls, 2 friends, 36.2ms
# Speed: 1.3ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Walls, 2 friends, 36.0ms
# Speed: 1.3ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 2 Walls, 2 friends, 38.3ms
# Speed: 1.3ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Walls, 2 friends, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 2 Walls, 2 friends, 34.3ms
# Speed: 1.2ms preprocess, 34.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Dead soldier -frd-s, 2 Walls, 1 friend, 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 2 Walls, 2 friends, 36.3ms
# Speed: 1.5ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 2 Walls, 2 friends, 33.6ms
# Speed: 1.2ms preprocess, 33.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Dead soldier -frd-s, 2 Walls, 2 friends, 36.8ms
# Speed: 1.5ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-,
0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 1.4ms preprocess, 38.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.4ms preprocess, 47.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.5ms preprocess, 46.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654050683 HTTP/1.1" 200 OK
#
# 0: 384x640 (no detections), 36.7ms
# Speed: 3.2ms preprocess, 36.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 2.0ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.3ms
# Speed: 1.7ms preprocess, 54.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.9ms
# Speed: 1.8ms preprocess, 45.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 2.4ms preprocess, 46.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 41.3ms
# Speed: 2.0ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.7ms
# Speed: 1.8ms preprocess, 42.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.4ms
# Speed: 1.3ms preprocess, 41.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.9ms
# Speed: 1.3ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 1.3ms preprocess, 41.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 1.7ms preprocess, 51.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.0ms
# Speed: 1.5ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.5ms
# Speed: 1.6ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.2ms
# Speed: 1.2ms preprocess, 37.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.4ms
# Speed: 1.3ms preprocess, 38.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# [http @ 0x60000398f300] Stream ends prematurely at 48786114, should be 18446744073709551615
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654053684 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654056685 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654059684 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654062685 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654065685 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654068684 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654071685 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654074807 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654077807 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654080807 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654083807 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654086807 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654089807 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654092808 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654095807 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654098807 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654101807 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654104808 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654107808 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654110685 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654113590 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654116589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654119589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654122589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654125589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654128589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654131590 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654134590 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654137590 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654140589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654143588 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654146589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654149589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654152589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654155589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654158588 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654161589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654164589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654167589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654170589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654173588 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654176589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654179589 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654182588 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654185710 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654188711 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654191710 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654194711 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654197711 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654200710 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654203711 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654206711 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654209710 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654212710 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654215710 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654218709 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654221710 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654224710 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654227588 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654230710 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:58617 - "GET /video_feed?t=1738654233710 HTTP/1.1" 200 OK

# %%
from fastapi import FastAPI
from starlette.responses import StreamingResponse
import cv2
import random
import math
import numpy as np
from ultralytics import YOLO
import uvicorn
import nest_asyncio
from collections import defaultdict

nest_asyncio.apply()

app = FastAPI()

video_url = "http://192.168.69.91:8080/video"
cap = cv2.VideoCapture(video_url)

model = YOLO("../models/first_model.pt")
LABEL_COLORS = {}
object_counters = defaultdict(int)

allowed_pairs = {
    ("tank", "friend"),
    ("enemy", "friend"),
    ("enemy", "wall"),
    ("friend", "wall")
}

def get_label_color(label):
    if label not in LABEL_COLORS:
        LABEL_COLORS[label] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label]

def generate_frames():
    while True:
        success, frame = cap.read()
        if not success:
            break

        results = model(frame)
        detections = results[0].boxes
        object_counters.clear()
        centers = []

        for box in detections:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            confidence = box.conf[0]
            label_id = int(box.cls[0])
            class_name = model.names[label_id]

            object_counters[class_name] += 1
            unique_label = f"{class_name} {object_counters[class_name]}"

            color = get_label_color(class_name)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            text = f"{unique_label} {confidence:.2f}"
            cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            centers.append((center_x, center_y, class_name.lower(), unique_label))
            cv2.circle(frame, (center_x, center_y), 5, color, -1)

            print(f"Detected: {unique_label}")

        for i in range(len(centers)):
            for j in range(i + 1, len(centers)):
                p1_x, p1_y, label1, name1 = centers[i]
                p2_x, p2_y, label2, name2 = centers[j]

                if (label1, label2) in allowed_pairs or (label2, label1) in allowed_pairs:
                    distance_pixels = int(math.dist((p1_x, p1_y), (p2_x, p2_y)))
                    cv2.line(frame, (p1_x, p1_y), (p2_x, p2_y), (255, 255, 0), 2)
                    midpoint = ((p1_x + p2_x) // 2, (p1_y + p2_y) // 2)
                    cv2.putText(frame, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

        _, buffer = cv2.imencode(".jpg", frame)
        frame_bytes = buffer.tobytes()

        yield (b"--frame\r\n"
               b"Content-Type: image/jpeg\r\n\r\n" + frame_bytes + b"\r\n")

@app.get("/video_feed")
def video_feed():
    return StreamingResponse(generate_frames(), media_type="multipart/x-mixed-replace; boundary=frame")

if __name__ == "__main__":
    uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# INFO:     Started server process [38945]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:61846 - "GET /video_feed?t=1738656133733 HTTP/1.1" 200 OK
#
# 0: 384x640 (no detections), 74.1ms
# Speed: 3.9ms preprocess, 74.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 2.0ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.3ms
# Speed: 7.0ms preprocess, 47.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.7ms
# Speed: 1.4ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.2ms
# Speed: 2.0ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.3ms
# Speed: 1.4ms preprocess, 37.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 2.7ms preprocess, 40.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.6ms
# Speed: 1.8ms preprocess, 111.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 2.8ms preprocess, 45.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# INFO:     127.0.0.1:61861 - "GET /video_feed?t=1738656136732 HTTP/1.1" 200 OK
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 4.4ms preprocess, 51.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.7ms
# Speed: 2.3ms preprocess, 43.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 1.4ms preprocess, 48.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 1.5ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.5ms
# Speed: 1.7ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.6ms
# Speed: 1.6ms preprocess, 46.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.1ms
# Speed: 1.8ms preprocess, 57.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.9ms
# Speed: 1.4ms preprocess, 55.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 2.4ms preprocess, 54.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# INFO:     127.0.0.1:61870 - "GET /video_feed?t=1738656139163 HTTP/1.1" 200 OK
#
# 0: 384x640 1 Dead soldier -enemy-, 62.4ms
# Speed: 9.6ms preprocess, 62.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 46.4ms
# Speed: 2.1ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected:
6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
# Detected: Dead soldier -enemy- 2
#
# 0: 384x640 2 Dead soldier -enemy-s, 1 Tank, 42.9ms
# Speed: 1.8ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
# Detected: Dead soldier -enemy- 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 43.2ms
# Speed: 1.7ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 51.2ms
# Speed: 1.6ms preprocess, 51.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 enemy, 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 38.2ms
# Speed: 1.3ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 38.5ms
# Speed: 1.7ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
#
# 0: 384x640 (no detections), 37.6ms
# Speed: 1.5ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.2ms
# Speed: 1.3ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 1.3ms preprocess, 39.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Wall, 1 enemy, 1 friend, 39.0ms
# Speed: 1.3ms preprocess, 39.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Dead soldier -frd- 1
# Detected: Wall 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Wall, 1 enemy, 1 friend, 38.5ms
# Speed: 1.8ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Wall, 1 enemy, 1 friend, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -frd-, 1 Wall, 2 enemys, 1 friend, 43.6ms
# Speed: 2.1ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 384x640 1 Dead soldier -frd-, 1 Wall, 2 enemys, 1 friend, 52.4ms
# Speed: 1.6ms preprocess, 52.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 384x640 1 Wall, 2 enemys, 1 friend, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 384x640 1 Dead soldier -frd-, 1 Wall, 2 enemys, 1 friend, 41.4ms
# Speed: 2.0ms preprocess, 41.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
# Detected: enemy 2
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 42.5ms
# Speed: 2.1ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 41.6ms
# Speed: 1.5ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Dead soldier -frd-, 1 Wall, 1 enemy, 1 friend, 43.8ms
# Speed: 1.6ms preprocess, 43.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: Dead soldier -frd- 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 40.0ms
# Speed: 1.4ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 44.6ms
# Speed: 1.5ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 45.6ms
# Speed: 1.4ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 48.4ms
# Speed: 1.8ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Dead soldier -frd-, 1 Wall, 1 enemy, 1 friend, 40.3ms
# Speed: 1.3ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 39.7ms
# Speed: 1.5ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 35.9ms
# Speed: 1.4ms preprocess, 35.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 36.4ms
# Speed: 1.4ms preprocess, 36.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 37.7ms
# Speed: 1.7ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 34.7ms
# Speed: 1.3ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Tank, 1 Wall, 1 enemy, 1 friend, 35.5ms
# Speed: 2.0ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Tank 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 47.4ms
# Speed: 1.6ms preprocess, 47.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 41.7ms
# Speed: 2.6ms preprocess, 41.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 40.4ms
# Speed: 1.7ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# INFO:     127.0.0.1:61928 - "GET /video_feed?t=1738656151005 HTTP/1.1" 200 OK
#
# 0: 384x640 1 Dead soldier -frd-, 1 Wall, 1 enemy, 1 friend, 49.6ms
# Speed: 1.9ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Dead soldier -frd- 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 48.5ms
# Speed: 2.3ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 46.5ms
# Speed: 3.1ms preprocess, 46.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 47.5ms
# Speed: 2.0ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 52.6ms
# Speed: 2.0ms preprocess, 52.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 41.8ms
# Speed: 1.3ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 41.1ms
# Speed: 2.8ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 41.2ms
# Speed: 1.9ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 37.3ms
# Speed: 1.5ms preprocess, 37.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 37.4ms
# Speed: 1.8ms preprocess, 37.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 38.7ms
# Speed: 1.6ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 35.5ms
# Speed: 1.9ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 36.0ms
# Speed: 1.4ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 36.4ms
# Speed: 1.7ms preprocess, 36.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 enemys, 1 friend, 37.0ms
# Speed: 1.3ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: enemy 2
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Wall, 2 enemys, 1 friend, 45.5ms
# Speed: 1.4ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: enemy 2
#
# 0: 384x640 1 Wall, 2 enemys, 1 friend, 58.0ms
# Speed: 11.1ms preprocess, 58.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: enemy 2
# Detected: friend 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 2 enemys, 1 friend, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: enemy 2
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Wall, 1 enemy, 1 friend, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Dead soldier -frd- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 39.7ms
# Speed: 1.3ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 40.0ms
# Speed: 1.3ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 48.4ms
# Speed: 2.7ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 47.4ms
# Speed: 1.5ms preprocess, 47.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
# Detected: Wall 1
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 39.0ms
# Speed: 1.9ms preprocess, 39.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: Wall 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 41.4ms
# Speed: 1.4ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 1 friend, 44.9ms
# Speed: 1.6ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Tank 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 1 friend, 38.9ms
# Speed: 2.0ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 1
# Detected: Tank 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 1 friend, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: enemy 1
# Detected: Wall 1
# Detected: Tank 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 1 friend, 48.6ms
# Speed: 1.4ms preprocess, 48.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 1 friend, 41.9ms
# Speed: 1.8ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: Wall 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 1 friend, 38.9ms
# Speed: 1.9ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 2 friends, 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Tank 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 2 friends, 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 1
# Detected: friend 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 2 friends, 46.0ms
# Speed: 1.5ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 1 enemy, 2 friends, 49.4ms
# Speed: 1.6ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 1
# Detected: friend 2
# Detected: Tank 2
#
# 0: 384x640 1 Dead soldier -enemy-, 2 Tanks, 1 Wall, 1 enemy, 2 friends, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: friend 2
# Detected: Tank 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 2 friends, 36.8ms
# Speed: 1.8ms preprocess, 36.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: enemy 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 1 Wall, 1 enemy, 2 friends, 37.1ms
# Speed: 4.1ms preprocess, 37.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 38.2ms
# Speed: 1.4ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 1
# Detected: friend 1
# Detected: friend 2
# Detected: Wall 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 41.8ms
# Speed: 1.8ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: enemy 1
# Detected: Wall 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: friend 2
# Detected: Wall 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 49.8ms
# Speed: 1.7ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: friend 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
# Detected: Wall 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
# Detected: Wall 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 36.6ms
# Speed: 1.9ms preprocess, 36.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 38.1ms
# Speed: 1.4ms preprocess, 38.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: enemy 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 45.4ms
# Speed: 2.0ms preprocess, 45.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: friend 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 2
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 36.8ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: enemy 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 35.8ms
# Speed: 1.7ms preprocess, 35.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 2
#
# INFO:     127.0.0.1:61941 - "GET /video_feed?t=1738656154006 HTTP/1.1" 200 OK
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends,
7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 2
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 40.8ms
# Speed: 1.9ms preprocess, 40.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: friend 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 49.9ms
# Speed: 1.9ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 39.0ms
# Speed: 1.9ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 2
# Detected: Dead soldier -enemy- 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 38.2ms
# Speed: 1.3ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 45.3ms
# Speed: 1.9ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 50.7ms
# Speed: 1.6ms preprocess, 50.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 2
# Detected: friend 2
# Detected: enemy 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 39.8ms
# Speed: 1.8ms preprocess, 39.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 2
# Detected: friend 1
# Detected: enemy 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 40.0ms
# Speed: 2.0ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: enemy 1
# Detected: friend 2
# Detected: Wall 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 48.4ms
# Speed: 1.4ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: Wall 2
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 42.1ms
# Speed: 1.5ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Wall 2
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 45.3ms
# Speed: 1.3ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 59.5ms
# Speed: 1.9ms preprocess, 59.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 2
# Detected: Wall 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 38.7ms
# Speed: 1.3ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 2
# Detected: Wall 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 44.4ms
# Speed: 3.0ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: friend 2
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: Wall 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 49.1ms
# Speed: 1.3ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
# Detected: Wall 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 52.3ms
# Speed: 2.1ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 46.9ms
# Speed: 1.8ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 47.4ms
# Speed: 1.3ms preprocess, 47.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: friend 2
# Detected: Wall 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 43.4ms
# Speed: 1.8ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: friend 1
# Detected: enemy 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 54.8ms
# Speed: 1.4ms preprocess, 54.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 1
# Detected: Wall 2
# Detected: friend 1
# Detected: friend 2
# Detected: enemy 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 53.9ms
# Speed: 3.3ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: Tank 1
# Detected: friend 1
# Detected: Wall 1
# Detected: friend 2
# Detected: Wall 2
# Detected: enemy 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: Wall 1
# Detected: Tank 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 2
# Detected: friend 2
# Detected: enemy 1
# INFO:     127.0.0.1:61954 - "GET /video_feed?t=1738656157006 HTTP/1.1" 200 OK
#
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 50.0ms
# Speed: 4.2ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: Wall 1
# Detected: Tank 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
# Detected: enemy 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 53.2ms
# Speed: 2.1ms preprocess, 53.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: Wall 2
# Detected: Dead soldier -enemy- 1
# Detected: friend 2
# Detected: enemy 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: Tank 1
# Detected: friend 1
# Detected: Dead soldier -enemy- 1
# Detected: Wall 2
# Detected: enemy 1
# Detected: friend 2
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 2 friends, 51.5ms
# ...
# Detected: friend 1
# Detected: enemy 1
# Detected: Wall 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 59.9ms
# Speed: 1.8ms preprocess, 59.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: enemy 1
# Detected: Wall 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 48.6ms
# Speed: 1.7ms preprocess, 48.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Wall 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Wall 1
# INFO:     127.0.0.1:63493 - "GET /video_feed?t=1738656538937 HTTP/1.1" 200 OK
#
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 50.6ms
# Speed: 1.5ms preprocess, 50.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Wall 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 55.4ms
# Speed: 2.0ms preprocess, 55.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Wall 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 51.4ms
# Speed: 2.4ms preprocess, 51.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: enemy 1
# Detected: friend 1
# Detected: Wall 1
#
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: enemy 1
# Detected: Wall 1
# 0: 384x640 1 Dead soldier -enemy-, 1 Wall, 1 enemy, 1 friend, 52.0ms
# Speed: 2.4ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Dead soldier -enemy- 1
# Detected: friend 1
# Detected: enemy 1
# Detected: Wall 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 52.3ms
# Speed: 1.6ms preprocess, 52.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 Wall, 1 enemy, 1 friend, 61.2ms
# Speed: 1.5ms preprocess, 61.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Wall 1
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 enemy, 1 friend, 47.1ms
# Speed: 1.4ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 (no detections), 48.2ms
# Speed: 1.5ms preprocess, 48.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.5ms
# Speed: 1.3ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Tank, 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
#
# 0: 384x640 1 Tank, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
#
# 0: 384x640 1 Tank, 45.3ms
# Speed: 1.3ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
#
# 0: 384x640 1 Dead soldier -frd-, 2 Tanks, 39.6ms
# Speed: 2.0ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
# Detected: Dead soldier -frd- 1
#
# 0: 384x640 2 Tanks, 51.0ms
# Speed: 2.4ms preprocess, 51.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 2 Tanks, 54.0ms
# Speed: 1.4ms preprocess, 54.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 2 Tanks, 46.2ms
# Speed: 1.3ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 2 Tanks, 48.6ms
# Speed: 2.2ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 2 Tanks, 45.1ms
# Speed: 1.3ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 2 Tanks, 47.3ms
# Speed: 1.4ms preprocess, 47.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 2 Tanks, 50.3ms
# Speed: 1.5ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 2 Tanks, 1 Wall, 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Wall 1
# Detected: Tank 2
#
# 0: 384x640 2 Tanks, 51.0ms
# Speed: 1.7ms preprocess, 51.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 2 Tanks, 60.2ms
# Speed: 1.9ms preprocess, 60.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 1 Tank, 49.4ms
# Speed: 1.4ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
#
# 0: 384x640 2 Tanks, 47.0ms
# Speed: 1.4ms preprocess, 47.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 1 Tank, 48.5ms
# Speed: 1.8ms preprocess, 48.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
#
# 0: 384x640 1 Tank, 50.8ms
# Speed: 1.4ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
#
# 0: 384x640 2 Tanks, 45.4ms
# Speed: 1.9ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
# Detected: Tank 2
#
# 0: 384x640 1 Tank, 49.4ms
# Speed: 2.8ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
#
# 0: 384x640 1 Tank, 45.1ms
# Speed: 2.1ms preprocess, 45.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: Tank 1
#
# 0: 384x640 1 enemy, 1 friend, 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 61.2ms
# Speed: 1.7ms preprocess, 61.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 45.9ms
# Speed: 1.9ms preprocess, 45.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 46.8ms
# Speed: 1.9ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 48.8ms
# Speed: 1.9ms preprocess, 48.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 48.1ms
# Speed: 1.8ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 48.0ms
# Speed: 1.3ms preprocess, 48.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 47.2ms
# Speed: 1.4ms preprocess, 47.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 50.6ms
# Speed: 1.4ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 57.5ms
# Speed: 1.7ms preprocess, 57.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 50.2ms
# Speed: 2.6ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# INFO:     127.0.0.1:63495 - "GET /video_feed?t=1738656541932 HTTP/1.1" 200 OK
#
# 0: 384x640 1 enemy, 1 friend, 49.2ms
# Speed: 2.8ms preprocess, 49.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 61.8ms
# Speed: 2.6ms preprocess, 61.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 64.0ms
# Speed: 2.2ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 59.2ms
# Speed: 2.0ms preprocess, 59.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 62.3ms
# Speed: 2.6ms preprocess, 62.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
# 0: 384x640 1 enemy, 1 friend, 59.2ms
# Speed: 2.5ms preprocess, 59.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 68.0ms
# Speed: 1.9ms preprocess, 68.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 54.4ms
# Speed: 1.9ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 49.8ms
# Speed: 1.3ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 48.3ms
# Speed: 1.4ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 61.9ms
# Speed: 1.3ms preprocess, 61.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 50.5ms
# Speed: 1.5ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 49.5ms
# Speed: 1.5ms preprocess, 49.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 44.2ms
# Speed: 1.9ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 39.2ms
# Speed: 1.3ms preprocess, 39.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 49.6ms
# Speed: 1.4ms preprocess, 49.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 49.9ms
# Speed: 1.3ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 46.8ms
# Speed: 1.4ms preprocess, 46.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 49.6ms
# Speed: 1.4ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 enemy, 1 friend, 46.8ms
# Speed: 2.4ms preprocess, 46.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 enemy, 1 friend, 46.8ms
# Speed: 2.0ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 enemy, 1 friend, 47.2ms
# Speed: 2.4ms preprocess, 47.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 55.7ms
# Speed: 1.7ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 enemy, 1 friend, 46.4ms
# Speed: 1.5ms preprocess, 46.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 enemy, 1 friend, 46.0ms
# Speed: 1.3ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 49.2ms
# Speed: 1.3ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 50.5ms
# Speed: 1.7ms preprocess, 50.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 46.8ms
# Speed: 2.2ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 59.8ms
# Speed: 1.5ms preprocess, 59.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 49.9ms
# Speed: 1.4ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 48.0ms
# Speed: 1.4ms preprocess, 48.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 42.1ms
# Speed: 1.8ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 50.1ms
# Speed: 1.9ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 47.4ms
# Speed: 1.5ms preprocess, 47.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: friend 1
# Detected: enemy 1
#
# 0: 384x640 1 enemy, 1 friend, 45.4ms
# Speed: 1.7ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 enemy, 1 friend, 51.2ms
# Speed: 1.6ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 enemy, 1 friend, 47.9ms
# Speed: 1.9ms preprocess, 47.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 enemy, 1 friend, 63.6ms
# Speed: 1.8ms preprocess, 63.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected: enemy 1
# Detected: friend 1
#
# 0: 384x640 1 enemy, 1 friend, 44.1ms

# %%
# Out:
# Requirement already satisfied: starlette in /Users/vishwajithp/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (0.38.5)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/vishwajithp/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from starlette) (4.2.0)
# Requirement already satisfied: idna>=2.8 in /Users/vishwajithp/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from anyio<5,>=3.4.0->starlette) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/vishwajithp/anaconda3/envs/TensorFlow/lib/python3.11/site-packages (from anyio<5,>=3.4.0->starlette) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
