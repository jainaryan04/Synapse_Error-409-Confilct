# %%
import cv2
import math
import random
import json
from collections import defaultdict
from scipy.spatial import distance
from ultralytics import YOLO  

model = YOLO('../models/first_model.pt')  

video_path = 'http://192.168.69.91:8080/video'
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"

LABEL_COLORS = {}

def get_label_color(label):
    if label not in LABEL_COLORS:
        LABEL_COLORS[label] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label]

allowed_pairs = {
    ("tank", "friend"),
    ("enemy", "friend"),
    ("enemy", "wall"),
    ("friend", "wall")
}

centers = []

class ObjectTracker:
    def __init__(self):
        self.objects = {}
        self.next_id = 1
        self.type_counters = defaultdict(int)
    
    def get_unique_name(self, class_name_lower):
        self.type_counters[class_name_lower] += 1
        return f"{class_name_lower.capitalize()}{self.type_counters[class_name_lower]}"
    
    def track_object(self, center_x, center_y, class_name_lower, frame_counter):
        for obj_id, obj_info in self.objects.items():
            if (obj_info['type'] == class_name_lower and 
                distance.euclidean((obj_info['last_x'], obj_info['last_y']), (center_x, center_y)) < 50):
                obj_info.update({
                    'last_x': center_x,
                    'last_y': center_y,
                    'last_seen': frame_counter,
                    'status': 'Active'
                })
                return obj_id
        
        unique_name = self.get_unique_name(class_name_lower)
        new_id = unique_name
        
        self.objects[new_id] = {
            'type': class_name_lower,
            'last_x': center_x,
            'last_y': center_y,
            'last_seen': frame_counter,
            'status': 'Active'
        }
        
        return new_id

    def clean_old_objects(self, frame_counter):
        for obj_id, obj_info in list(self.objects.items()):
            if frame_counter - obj_info['last_seen'] > 10:
                obj_info['status'] = 'Dead'

    def calculate_distances(self, frame_counter):
        distance_data = {}
        active_objects = [
            (obj_id, info['last_x'], info['last_y']) 
            for obj_id, info in self.objects.items() 
            if info['status'] == 'Active'
        ]
        
        for friend_id, friend_x, friend_y in [
            obj for obj in active_objects 
            if self.objects[obj[0]]['type'] == 'friend'
        ]:
            friend_distances = {}
            
            for other_id, other_x, other_y in active_objects:
                if other_id == friend_id:
                    continue
                
                dist_pixels = int(math.dist((friend_x, friend_y), (other_x, other_y)))
                friend_distances[other_id] = f"{dist_pixels}px"
            
            dead_objects = [
                obj_id for obj_id, info in self.objects.items() 
                if info['status'] == 'Dead'
            ]
            
            for dead_id in dead_objects:
                friend_distances[dead_id] = "Dead"
            
            distance_data[friend_id] = friend_distances if friend_distances else "lonely"
        
        return distance_data

object_tracker = ObjectTracker()

frame_counter = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Video processing completed.")
        break

    frame_counter += 1
    centers = []

    results = model(frame)
    detections = results[0].boxes  

    for box in detections:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            label_id = int(box.cls[0])
            class_name = model.names[label_id].lower()
            center_x, center_y = (x1 + x2) // 2, (y1 + y2) // 2
            obj_id = object_tracker.track_object(center_x, center_y, class_name, frame_counter)

            color = get_label_color(label_id)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, obj_id, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            centers.append((center_x, center_y, class_name, obj_id))

    for i in range(len(centers)):
            for j in range(i + 1, len(centers)):
                p1_x, p1_y, label1, name1 = centers[i]
                p2_x, p2_y, label2, name2 = centers[j]
                if (label1, label2) in allowed_pairs or (label2, label1) in allowed_pairs:
                    distance_pixels = int(math.dist((p1_x, p1_y), (p2_x, p2_y)))
                    cv2.line(frame, (p1_x, p1_y), (p2_x, p2_y), (255, 255, 0), 2)
                    midpoint = ((p1_x + p2_x) // 2, (p1_y + p2_y) // 2)
                    cv2.putText(frame, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)


    object_tracker.clean_old_objects(frame_counter)

    distance_data = object_tracker.calculate_distances(frame_counter)
    print(json.dumps(distance_data, indent=4))

    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Tank, 2 Walls, 1 enemy, 1 friend, 36.0ms
# Speed: 1.8ms preprocess, 36.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "845px",
#         "Enemy1": "777px",
#         "Wall1": "364px",
#         "Wall2": "602px"
#     }
# }
#
# 0: 384x640 2 Tanks, 1 Wall, 1 enemy, 1 friend, 44.4ms
# Speed: 1.5ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "841px",
#         "Enemy1": "778px",
#         "Wall1": "365px",
#         "Wall2": "622px",
#         "Tank2": "607px"
#     }
# }
#
# 0: 384x640 2 Tanks, 1 Wall, 2 enemys, 1 friend, 44.5ms
# Speed: 1.5ms preprocess, 44.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "842px",
#         "Enemy1": "776px",
#         "Wall1": "382px",
#         "Wall2": "618px",
#         "Tank2": "636px",
#         "Tank3": "366px",
#         "Enemy2": "945px"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 48.5ms
# Speed: 1.4ms preprocess, 48.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "841px",
#         "Enemy1": "775px",
#         "Wall1": "392px",
#         "Wall2": "628px",
#         "Tank2": "653px",
#         "Tank3": "376px",
#         "Enemy2": "957px",
#         "Friend2": "615px",
#         "Wall3": "366px"
#     },
#     "Friend2": {
#         "Tank1": "867px",
#         "Enemy1": "991px",
#         "Friend1": "615px",
#         "Wall1": "708px",
#         "Wall2": "388px",
#         "Tank2": "399px",
#         "Tank3": "722px",
#         "Enemy2": "746px",
#         "Wall3": "732px"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "840px",
#         "Enemy1": "776px",
#         "Wall1": "403px",
#         "Wall2": "635px",
#         "Tank2": "669px",
#         "Tank3": "386px",
#         "Enemy2": "967px",
#         "Friend2": "622px",
#         "Wall3": "365px"
#     },
#     "Friend2": {
#         "Tank1": "871px",
#         "Enemy1": "996px",
#         "Friend1": "622px",
#         "Wall1": "708px",
#         "Wall2": "389px",
#         "Tank2": "403px",
#         "Tank3": "721px",
#         "Enemy2": "753px",
#         "Wall3": "739px"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 45.0ms
# Speed: 3.0ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "840px",
#         "Enemy1": "778px",
#         "Wall1": "417px",
#         "Wall2": "640px",
#         "Tank2": "686px",
#         "Tank3": "399px",
#         "Enemy2": "963px",
#         "Friend2": "623px",
#         "Wall3": "367px"
#     },
#     "Friend2": {
#         "Tank1": "875px",
#         "Enemy1": "1000px",
#         "Friend1": "623px",
#         "Wall1": "704px",
#         "Wall2": "393px",
#         "Tank2": "410px",
#         "Tank3": "716px",
#         "Enemy2": "748px",
#         "Wall3": "743px"
#     }
# }
#
# 0: 384x640 1 Tank, 1 Wall, 2 enemys, 2 friends, 46.4ms
# Speed: 1.3ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "843px",
#         "Enemy1": "780px",
#         "Wall1": "434px",
#         "Wall2": "655px",
#         "Tank2": "715px",
#         "Tank3": "414px",
#         "Enemy2": "968px",
#         "Friend2": "639px",
#         "Wall3": "380px"
#     },
#     "Friend2": {
#         "Tank1": "880px",
#         "Enemy1": "1010px",
#         "Friend1": "639px",
#         "Wall1": "699px",
#         "Wall2": "395px",
#         "Tank2": "414px",
#         "Tank3": "711px",
#         "Enemy2": "749px",
#         "Wall3": "737px"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "841px",
#         "Enemy1": "779px",
#         "Wall1": "444px",
#         "Wall2": "663px",
#         "Tank2": "730px",
#         "Tank3": "424px",
#         "Enemy2": "973px",
#         "Friend2": "647px",
#         "Wall3": "367px"
#     },
#     "Friend2": {
#         "Tank1": "883px",
#         "Enemy1": "1016px",
#         "Friend1": "647px",
#         "Wall1": "699px",
#         "Wall2": "394px",
#         "Tank2": "420px",
#         "Tank3": "710px",
#         "Enemy2": "752px",
#         "Wall3": "763px"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 39.8ms
# Speed: 1.3ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "844px",
#         "Enemy1": "782px",
#         "Wall1": "456px",
#         "Wall2": "666px",
#         "Tank2": "741px",
#         "Tank3": "436px",
#         "Enemy2": "977px",
#         "Friend2": "648px",
#         "Wall3": "370px"
#     },
#     "Friend2": {
#         "Tank1": "887px",
#         "Enemy1": "1021px",
#         "Friend1": "648px",
#         "Wall1": "700px",
#         "Wall2": "397px",
#         "Tank2": "426px",
#         "Tank3": "711px",
#         "Enemy2": "757px",
#         "Wall3": "767px"
#     }
# }
# 2025-02-04 15:41:28.684 python[47988:1235031] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-04 15:41:28.684 python[47988:1235031] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "844px",
#         "Enemy1": "782px",
#         "Wall1": "467px",
#         "Wall2": "672px",
#         "Tank2": "752px",
#         "Tank3": "447px",
#         "Enemy2": "976px",
#         "Friend2": "652px",
#         "Wall3": "371px"
#     },
#     "Friend2": {
#         "Tank1": "890px",
#         "Enemy1": "1022px",
#         "Friend1": "652px",
#         "Wall1": "701px",
#         "Wall2": "397px",
#         "Tank2": "432px",
#         "Tank3": "712px",
#         "Enemy2": "754px",
#         "Wall3": "773px"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "842px",
#         "Enemy1": "779px",
#         "Wall1": "475px",
#         "Wall2": "674px",
#         "Tank2": "760px",
#         "Tank3": "454px",
#         "Enemy2": "977px",
#         "Friend2": "656px",
#         "Wall3": "370px"
#     },
#     "Friend2": {
#         "Tank1": "889px",
#         "Enemy1": "1022px",
#         "Friend1": "656px",
#         "Wall1": "702px",
#         "Wall2": "396px",
#         "Tank2": "434px",
#         "Tank3": "713px",
#         "Enemy2": "754px",
#         "Wall3": "774px"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.0ms
# Speed: 1.4ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "840px",
#         "Enemy1": "783px",
#         "Wall1": "485px",
#         "Wall2": "678px",
#         "Tank2": "768px",
#         "Tank3": "464px",
#         "Enemy2": "977px",
#         "Friend2": "657px",
#         "Wall3": "373px"
#     },
#     "Friend2": {
#         "Tank1": "887px",
#         "Enemy1": "1025px",
#         "Friend1": "657px",
#         "Wall1": "704px",
#         "Wall2": "399px",
#         "Tank2": "439px",
#         "Tank3": "715px",
#         "Enemy2": "755px",
#         "Wall3": "777px"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 42.4ms
# Speed: 1.5ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "839px",
#         "Enemy1": "781px",
#         "Wall2": "681px",
#         "Tank3": "469px",
#         "Enemy2": "981px",
#         "Friend2": "660px",
#         "Wall3": "369px",
#         "Wall1": "Dead",
#         "Tank2": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "889px",
#         "Enemy1": "1025px",
#         "Friend1": "660px",
#         "Wall2": "400px",
#         "Tank3": "716px",
#         "Enemy2": "758px",
#         "Wall3": "778px",
#         "Wall1": "Dead",
#         "Tank2": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.9ms
# Speed: 2.0ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "839px",
#         "Enemy1": "778px",
#         "Wall2": "680px",
#         "Enemy2": "983px",
#         "Friend2": "660px",
#         "Wall3": "368px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1026px",
#         "Friend1": "660px",
#         "Wall2": "400px",
#         "Enemy2": "761px",
#         "Wall3": "780px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 35.7ms
# Speed: 2.2ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "840px",
#         "Enemy1": "777px",
#         "Wall2": "681px",
#         "Enemy2": "984px",
#         "Friend2": "662px",
#         "Wall3": "367px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "893px",
#         "Enemy1": "1026px",
#         "Friend1": "662px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "781px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 36.8ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "843px",
#         "Enemy1": "779px",
#         "Wall2": "680px",
#         "Enemy2": "991px",
#         "Friend2": "659px",
#         "Wall3": "370px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "892px",
#         "Enemy1": "1025px",
#         "Friend1": "659px",
#         "Wall2": "401px",
#         "Enemy2": "763px",
#         "Wall3": "780px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 62.5ms
# Speed: 6.9ms preprocess, 62.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "842px",
#         "Enemy1": "780px",
#         "Wall2": "675px",
#         "Enemy2": "989px",
#         "Friend2": "655px",
#         "Wall3": "367px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1025px",
#         "Friend1": "655px",
#         "Wall2": "401px",
#         "Enemy2": "764px",
#         "Wall3": "775px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 42.4ms
# Speed: 1.2ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "841px",
#         "Enemy1": "777px",
#         "Wall2": "675px",
#         "Enemy2": "987px",
#         "Friend2": "654px",
#         "Wall3": "366px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "887px",
#         "Enemy1": "1018px",
#         "Friend1": "654px",
#         "Wall2": "397px",
#         "Enemy2": "761px",
#         "Wall3": "771px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "839px",
#         "Enemy1": "776px",
#         "Wall2": "677px",
#         "Enemy2": "984px",
#         "Friend2": "654px",
#         "Wall3": "369px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "889px",
#         "Enemy1": "1019px",
#         "Friend1": "654px",
#         "Wall2": "398px",
#         "Enemy2": "759px",
#         "Wall3": "774px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.5ms
# Speed: 1.3ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "837px",
#         "Enemy1": "775px",
#         "Wall2": "677px",
#         "Enemy2": "982px",
#         "Friend2": "655px",
#         "Wall3": "368px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "888px",
#         "Enemy1": "1019px",
#         "Friend1": "655px",
#         "Wall2": "399px",
#         "Enemy2": "758px",
#         "Wall3": "775px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 37.3ms
# Speed: 1.5ms preprocess, 37.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall4": "323px",
#         "Tank4": "767px",
#         "Enemy3": "911px",
#         "Wall5": "629px",
#         "Friend3": "617px",
#         "Friend4": "65px",
#         "Enemy4": "724px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall4": "793px",
#         "Tank4": "857px",
#         "Enemy3": "705px",
#         "Wall5": "358px",
#         "Friend3": "67px",
#         "Friend4": "700px",
#         "Enemy4": "1009px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "921px",
#         "Enemy1": "1038px",
#         "Friend1": "617px",
#         "Wall2": "445px",
#         "Enemy2": "814px",
#         "Friend2": "67px",
#         "Wall3": "768px",
#         "Wall4": "778px",
#         "Tank4": "883px",
#         "Enemy3": "754px",
#         "Wall5": "397px",
#         "Friend4": "656px",
#         "Enemy4": "1020px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "896px",
#         "Enemy1": "826px",
#         "Friend1": "65px",
#         "Wall2": "740px",
#         "Enemy2": "1046px",
#         "Friend2": "700px",
#         "Wall3": "417px",
#         "Wall4": "367px",
#         "Tank4": "828px",
#         "Enemy3": "977px",
#         "Wall5": "692px",
#         "Friend3": "656px",
#         "Enemy4": "773px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 34.1ms
# Speed: 1.3ms preprocess, 34.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall4": "321px",
#         "Tank4": "762px",
#         "Enemy3": "908px",
#         "Wall5": "628px",
#         "Friend3": "615px",
#         "Friend4": "69px",
#         "Enemy4": "721px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall4": "794px",
#         "Tank4": "853px",
#         "Enemy3": "703px",
#         "Wall5": "356px",
#         "Friend3": "70px",
#         "Friend4": "703px",
#         "Enemy4": "1007px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "922px",
#         "Enemy1": "1038px",
#         "Friend1": "615px",
#         "Wall2": "446px",
#         "Enemy2": "815px",
#         "Friend2": "70px",
#         "Wall3": "767px",
#         "Wall4": "778px",
#         "Tank4": "880px",
#         "Enemy3": "754px",
#         "Wall5": "397px",
#         "Friend4": "656px",
#         "Enemy4": "1018px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "900px",
#         "Enemy1": "829px",
#         "Friend1": "69px",
#         "Wall2": "743px",
#         "Enemy2": "1050px",
#         "Friend2": "703px",
#         "Wall3": "420px",
#         "Wall4": "368px",
#         "Tank4": "826px",
#         "Enemy3": "978px",
#         "Wall5": "694px",
#         "Friend3": "656px",
#         "Enemy4": "773px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 39.9ms
# Speed: 1.2ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall4": "319px",
#         "Tank4": "761px",
#         "Enemy3": "906px",
#         "Wall5": "626px",
#         "Friend3": "615px",
#         "Friend4": "72px",
#         "Enemy4": "720px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall4": "794px",
#         "Tank4": "853px",
#         "Enemy3": "700px",
#         "Wall5": "355px",
#         "Friend3": "72px",
#         "Friend4": "704px",
#         "Enemy4": "1008px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "924px",
#         "Enemy1": "1040px",
#         "Friend1": "615px",
#         "Wall2": "449px",
#         "Enemy2": "818px",
#         "Friend2": "72px",
#         "Wall3": "769px",
#         "Wall4": "779px",
#         "Tank4": "882px",
#         "Enemy3": "754px",
#         "Wall5": "398px",
#         "Friend4": "657px",
#         "Enemy4": "1021px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "903px",
#         "Enemy1": "832px",
#         "Friend1": "72px",
#         "Wall2": "746px",
#         "Enemy2": "1053px",
#         "Friend2": "704px",
#         "Wall3": "423px",
#         "Wall4": "368px",
#         "Tank4": "828px",
#         "Enemy3": "978px",
#         "Wall5": "695px",
#         "Friend3": "657px",
#         "Enemy4": "775px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 40.0ms
# Speed: 1.3ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall4": "316px",
#         "Tank4": "760px",
#         "Enemy3": "904px",
#         "Wall5": "624px",
#         "Friend3": "614px",
#         "Friend4": "76px",
#         "Enemy4": "715px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall4": "795px",
#         "Tank4": "853px",
#         "Enemy3": "699px",
#         "Wall5": "354px",
#         "Friend3": "75px",
#         "Friend4": "706px",
#         "Enemy4": "1006px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "927px",
#         "Enemy1": "1042px",
#         "Friend1": "614px",
#         "Wall2": "452px",
#         "Enemy2": "821px",
#         "Friend2": "75px",
#         "Wall3": "769px",
#         "Wall4": "780px",
#         "Tank4": "884px",
#         "Enemy3": "756px",
#         "Wall5": "399px",
#         "Friend4": "658px",
#         "Enemy4": "1019px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "907px",
#         "Enemy1": "836px",
#         "Friend1": "76px",
#         "Wall2": "750px",
#         "Enemy2": "1057px",
#         "Friend2": "706px",
#         "Wall3": "427px",
#         "Wall4": "369px",
#         "Tank4": "832px",
#         "Enemy3": "981px",
#         "Wall5": "697px",
#         "Friend3": "658px",
#         "Enemy4": "774px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 36.9ms
# Speed: 1.2ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall4": "315px",
#         "Tank4": "761px",
#         "Enemy3": "908px",
#         "Wall5": "624px",
#         "Friend3": "615px",
#         "Friend4": "79px",
#         "Enemy4": "713px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall4": "795px",
#         "Tank4": "854px",
#         "Enemy3": "701px",
#         "Wall5": "352px",
#         "Friend3": "77px",
#         "Friend4": "707px",
#         "Enemy4": "1004px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "930px",
#         "Enemy1": "1045px",
#         "Friend1": "615px",
#         "Wall2": "455px",
#         "Enemy2": "824px",
#         "Friend2": "77px",
#         "Wall3": "772px",
#         "Wall4": "782px",
#         "Tank4": "888px",
#         "Enemy3": "761px",
#         "Wall5": "401px",
#         "Friend4": "659px",
#         "Enemy4": "1020px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "910px",
#         "Enemy1": "839px",
#         "Friend1": "79px",
#         "Wall2": "752px",
#         "Enemy2": "1060px",
#         "Friend2": "707px",
#         "Wall3": "430px",
#         "Wall4": "370px",
#         "Tank4": "835px",
#         "Enemy3": "987px",
#         "Wall5": "699px",
#         "Friend3": "659px",
#         "Enemy4": "775px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 37.6ms
# Speed: 1.2ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall4": "310px",
#         "Tank4": "759px",
#         "Enemy3": "909px",
#         "Wall5": "619px",
#         "Friend3": "620px",
#         "Friend4": "89px",
#         "Enemy4": "715px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall4": "797px",
#         "Tank4": "851px",
#         "Enemy3": "697px",
#         "Wall5": "343px",
#         "Friend3": "88px",
#         "Friend4": "711px",
#         "Enemy4": "1007px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "944px",
#         "Enemy1": "1058px",
#         "Friend1": "620px",
#         "Wall2": "470px",
#         "Enemy2": "839px",
#         "Friend2": "88px",
#         "Wall3": "782px",
#         "Wall4": "793px",
#         "Tank4": "899px",
#         "Enemy3": "772px",
#         "Wall5": "406px",
#         "Friend4": "666px",
#         "Enemy4": "1037px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "920px",
#         "Enemy1": "849px",
#         "Friend1": "89px",
#         "Wall2": "761px",
#         "Enemy2": "1070px",
#         "Friend2": "711px",
#         "Wall3": "440px",
#         "Wall4": "374px",
#         "Tank4": "844px",
#         "Enemy3": "998px",
#         "Wall5": "702px",
#         "Friend3": "666px",
#         "Enemy4": "786px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall4": "309px",
#         "Tank4": "754px",
#         "Enemy3": "906px",
#         "Wall5": "617px",
#         "Friend3": "619px",
#         "Friend4": "94px",
#         "Enemy4": "712px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall4": "799px",
#         "Tank4": "848px",
#         "Enemy3": "694px",
#         "Wall5": "340px",
#         "Friend3": "91px",
#         "Friend4": "717px",
#         "Enemy4": "1005px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "946px",
#         "Enemy1": "1060px",
#         "Friend1": "619px",
#         "Wall2": "472px",
#         "Enemy2": "842px",
#         "Friend2": "91px",
#         "Wall3": "783px",
#         "Wall4": "795px",
#         "Tank4": "898px",
#         "Enemy3": "772px",
#         "Wall5": "406px",
#         "Friend4": "670px",
#         "Enemy4": "1036px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "925px",
#         "Enemy1": "852px",
#         "Friend1": "94px",
#         "Wall2": "766px",
#         "Enemy2": "1075px",
#         "Friend2": "717px",
#         "Wall3": "443px",
#         "Wall4": "375px",
#         "Tank4": "843px",
#         "Enemy3": "1000px",
#         "Wall5": "705px",
#         "Friend3": "670px",
#         "Enemy4": "786px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.7ms
# Speed: 1.2ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall4": "309px",
#         "Tank4": "752px",
#         "Enemy3": "904px",
#         "Wall5": "613px",
#         "Friend3": "619px",
#         "Friend4": "98px",
#         "Enemy4": "711px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall4": "800px",
#         "Tank4": "846px",
#         "Enemy3": "692px",
#         "Wall5": "338px",
#         "Friend3": "97px",
#         "Friend4": "719px",
#         "Enemy4": "1005px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "951px",
#         "Enemy1": "1064px",
#         "Friend1": "619px",
#         "Wall2": "478px",
#         "Enemy2": "847px",
#         "Friend2": "97px",
#         "Wall3": "785px",
#         "Wall4": "797px",
#         "Tank4": "901px",
#         "Enemy3": "776px",
#         "Wall5": "408px",
#         "Friend4": "671px",
#         "Enemy4": "1039px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "928px",
#         "Enemy1": "855px",
#         "Friend1": "98px",
#         "Wall2": "770px",
#         "Enemy2": "1079px",
#         "Friend2": "719px",
#         "Wall3": "446px",
#         "Wall4": "377px",
#         "Tank4": "845px",
#         "Enemy3": "1002px",
#         "Wall5": "705px",
#         "Friend3": "671px",
#         "Enemy4": "788px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 34.4ms
# Speed: 1.3ms preprocess, 34.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall4": "307px",
#         "Tank4": "749px",
#         "Enemy3": "899px",
#         "Wall5": "610px",
#         "Friend3": "617px",
#         "Friend4": "103px",
#         "Enemy4": "709px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall4": "801px",
#         "Tank4": "847px",
#         "Enemy3": "689px",
#         "Wall5": "334px",
#         "Friend3": "102px",
#         "Friend4": "725px",
#         "Enemy4": "1005px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "955px",
#         "Enemy1": "1066px",
#         "Friend1": "617px",
#         "Wall2": "483px",
#         "Enemy2": "852px",
#         "Friend2": "102px",
#         "Wall3": "786px",
#         "Wall4": "798px",
#         "Tank4": "905px",
#         "Enemy3": "777px",
#         "Wall5": "408px",
#         "Friend4": "674px",
#         "Enemy4": "1042px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "932px",
#         "Enemy1": "858px",
#         "Friend1": "103px",
#         "Wall2": "776px",
#         "Enemy2": "1084px",
#         "Friend2": "725px",
#         "Wall3": "449px",
#         "Wall4": "376px",
#         "Tank4": "846px",
#         "Enemy3": "1003px",
#         "Wall5": "707px",
#         "Friend3": "674px",
#         "Enemy4": "788px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 45.3ms
# Speed: 1.6ms preprocess, 45.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend1": {
#         "Tank1": "835px",
#         "Enemy1": "774px",
#         "Wall2": "676px",
#         "Enemy2": "980px",
#         "Friend2": "656px",
#         "Wall3": "367px",
#         "Wall4": "306px",
#         "Tank4": "744px",
#         "Enemy3": "895px",
#         "Wall5": "605px",
#         "Friend3": "615px",
#         "Friend4": "111px",
#         "Enemy4": "709px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend2": {
#         "Tank1": "891px",
#         "Enemy1": "1023px",
#         "Friend1": "656px",
#         "Wall2": "401px",
#         "Enemy2": "762px",
#         "Wall3": "777px",
#         "Wall4": "806px",
#         "Tank4": "846px",
#         "Enemy3": "684px",
#         "Wall5": "332px",
#         "Friend3": "108px",
#         "Friend4": "730px",
#         "Enemy4": "1008px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend3": {
#         "Tank1": "958px",
#         "Enemy1": "1068px",
#         "Friend1": "615px",
#         "Wall2": "487px",
#         "Enemy2": "857px",
#         "Friend2": "108px",
#         "Wall3": "786px",
#         "Wall4": "802px",
#         "Tank4": "906px",
#         "Enemy3": "776px",
#         "Wall5": "409px",
#         "Friend4": "675px",
#         "Enemy4": "1045px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     },
#     "Friend4": {
#         "Tank1": "940px",
#         "Enemy1": "865px",
#         "Friend1": "111px",
#         "Wall2": "783px",
#         "Enemy2": "1092px",
#         "Friend2": "730px",
#         "Wall3": "456px",
#         "Wall4": "381px",
#         "Tank4": "849px",
#         "Enemy3": "1006px",
#         "Wall5": "710px",
#         "Friend3": "675px",
#         "Enemy4": "794px",
#         "Wall1": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 52.1ms
# Speed: 1.2ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall4": "793px",
#         "Tank4": "938px",
#         "Enemy3": "805px",
#         "Wall5": "420px",
#         "Friend4": "655px",
#         "Enemy4": "1045px",
#         "Wall6": "832px",
#         "Enemy5": "1083px",
#         "Friend5": "699px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend4": {
#         "Wall4": "381px",
#         "Tank4": "850px",
#         "Enemy3": "999px",
#         "Wall5": "694px",
#         "Friend3": "655px",
#         "Enemy4": "794px",
#         "Wall6": "378px",
#         "Enemy5": "803px",
#         "Friend5": "51px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend5": {
#         "Wall4": "404px",
#         "Tank4": "886px",
#         "Enemy3": "1046px",
#         "Wall5": "745px",
#         "Friend3": "699px",
#         "Friend4": "51px",
#         "Enemy4": "820px",
#         "Wall6": "395px",
#         "Enemy5": "826px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 43.7ms
# Speed: 1.6ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall4": "792px",
#         "Tank4": "939px",
#         "Enemy3": "806px",
#         "Wall5": "421px",
#         "Friend4": "654px",
#         "Enemy4": "1044px",
#         "Wall6": "836px",
#         "Enemy5": "1087px",
#         "Friend5": "701px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend4": {
#         "Wall4": "381px",
#         "Tank4": "850px",
#         "Enemy3": "1000px",
#         "Wall5": "694px",
#         "Friend3": "654px",
#         "Enemy4": "794px",
#         "Wall6": "380px",
#         "Enemy5": "807px",
#         "Friend5": "53px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend5": {
#         "Wall4": "405px",
#         "Tank4": "888px",
#         "Enemy3": "1049px",
#         "Wall5": "747px",
#         "Friend3": "701px",
#         "Friend4": "53px",
#         "Enemy4": "821px",
#         "Wall6": "397px",
#         "Enemy5": "830px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 59.7ms
# Speed: 1.3ms preprocess, 59.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall4": "792px",
#         "Tank4": "944px",
#         "Enemy3": "809px",
#         "Wall5": "424px",
#         "Friend4": "653px",
#         "Enemy4": "1045px",
#         "Wall6": "838px",
#         "Enemy5": "1093px",
#         "Friend5": "703px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend4": {
#         "Wall4": "381px",
#         "Tank4": "853px",
#         "Enemy3": "1000px",
#         "Wall5": "693px",
#         "Friend3": "653px",
#         "Enemy4": "794px",
#         "Wall6": "381px",
#         "Enemy5": "811px",
#         "Friend5": "56px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend5": {
#         "Wall4": "404px",
#         "Tank4": "890px",
#         "Enemy3": "1051px",
#         "Wall5": "749px",
#         "Friend3": "703px",
#         "Friend4": "56px",
#         "Enemy4": "820px",
#         "Wall6": "396px",
#         "Enemy5": "833px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 53.8ms
# Speed: 1.5ms preprocess, 53.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall4": "792px",
#         "Tank4": "950px",
#         "Enemy3": "813px",
#         "Wall5": "426px",
#         "Friend4": "653px",
#         "Enemy4": "1046px",
#         "Wall6": "844px",
#         "Enemy5": "1099px",
#         "Friend5": "706px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend4": {
#         "Wall4": "381px",
#         "Tank4": "856px",
#         "Enemy3": "1002px",
#         "Wall5": "693px",
#         "Friend3": "653px",
#         "Enemy4": "794px",
#         "Wall6": "386px",
#         "Enemy5": "816px",
#         "Friend5": "59px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend5": {
#         "Wall4": "405px",
#         "Tank4": "895px",
#         "Enemy3": "1055px",
#         "Wall5": "751px",
#         "Friend3": "706px",
#         "Friend4": "59px",
#         "Enemy4": "821px",
#         "Wall6": "401px",
#         "Enemy5": "838px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 45.3ms
# Speed: 1.8ms preprocess, 45.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall4": "793px",
#         "Tank4": "953px",
#         "Enemy3": "817px",
#         "Wall5": "425px",
#         "Friend4": "654px",
#         "Enemy4": "1046px",
#         "Wall6": "848px",
#         "Enemy5": "1104px",
#         "Friend5": "710px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend4": {
#         "Wall4": "381px",
#         "Tank4": "858px",
#         "Enemy3": "1006px",
#         "Wall5": "693px",
#         "Friend3": "654px",
#         "Enemy4": "794px",
#         "Wall6": "387px",
#         "Enemy5": "820px",
#         "Friend5": "62px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend5": {
#         "Wall4": "406px",
#         "Tank4": "899px",
#         "Enemy3": "1062px",
#         "Wall5": "754px",
#         "Friend3": "710px",
#         "Friend4": "62px",
#         "Enemy4": "822px",
#         "Wall6": "402px",
#         "Enemy5": "843px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 41.3ms
# Speed: 1.5ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall4": "792px",
#         "Tank4": "957px",
#         "Enemy3": "818px",
#         "Wall5": "427px",
#         "Friend4": "653px",
#         "Enemy4": "1045px",
#         "Wall6": "851px",
#         "Enemy5": "1107px",
#         "Friend5": "712px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend4": {
#         "Wall4": "381px",
#         "Tank4": "861px",
#         "Enemy3": "1007px",
#         "Wall5": "694px",
#         "Friend3": "653px",
#         "Enemy4": "794px",
#         "Wall6": "388px",
#         "Enemy5": "822px",
#         "Friend5": "65px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend5": {
#         "Wall4": "408px",
#         "Tank4": "904px",
#         "Enemy3": "1065px",
#         "Wall5": "758px",
#         "Friend3": "712px",
#         "Friend4": "65px",
#         "Enemy4": "824px",
#         "Wall6": "404px",
#         "Enemy5": "847px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall4": "793px",
#         "Tank4": "965px",
#         "Enemy3": "824px",
#         "Wall5": "431px",
#         "Friend4": "653px",
#         "Enemy4": "1048px",
#         "Wall6": "856px",
#         "Enemy5": "1116px",
#         "Friend5": "717px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend4": {
#         "Wall4": "381px",
#         "Tank4": "864px",
#         "Enemy3": "1008px",
#         "Wall5": "694px",
#         "Friend3": "653px",
#         "Enemy4": "794px",
#         "Wall6": "389px",
#         "Enemy5": "826px",
#         "Friend5": "71px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend5": {
#         "Wall4": "412px",
#         "Tank4": "911px",
#         "Enemy3": "1072px",
#         "Wall5": "765px",
#         "Friend3": "717px",
#         "Friend4": "71px",
#         "Enemy4": "828px",
#         "Wall6": "408px",
#         "Enemy5": "854px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 43.0ms
# Speed: 1.3ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall4": "841px",
#         "Tank4": "948px",
#         "Enemy3": "811px",
#         "Wall5": "429px",
#         "Friend4": "708px",
#         "Enemy4": "1096px",
#         "Wall6": "875px",
#         "Enemy5": "1130px",
#         "Friend5": "739px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend4": {
#         "Wall4": "400px",
#         "Tank4": "891px",
#         "Enemy3": "1052px",
#         "Wall5": "746px",
#         "Friend3": "708px",
#         "Enemy4": "835px",
#         "Wall6": "403px",
#         "Enemy5": "846px",
#         "Friend5": "31px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend5": {
#         "Wall4": "407px",
#         "Tank4": "909px",
#         "Enemy3": "1078px",
#         "Wall5": "776px",
#         "Friend3": "739px",
#         "Friend4": "31px",
#         "Enemy4": "845px",
#         "Wall6": "408px",
#         "Enemy5": "854px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 50.0ms
# Speed: 1.5ms preprocess, 50.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall4": "839px",
#         "Tank4": "946px",
#         "Enemy3": "808px",
#         "Wall5": "428px",
#         "Friend4": "706px",
#         "Enemy4": "1095px",
#         "Wall6": "873px",
#         "Enemy5": "1130px",
#         "Friend5": "734px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend4": {
#         "Wall4": "401px",
#         "Tank4": "892px",
#         "Enemy3": "1048px",
#         "Wall5": "746px",
#         "Friend3": "706px",
#         "Enemy4": "835px",
#         "Wall6": "407px",
#         "Enemy5": "850px",
#         "Friend5": "28px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead"
#     },
#     "Friend5": {
#         "Wall4": "404px",
#         "Tank4": "906px",
#         "Enemy3": "1069px",
#         "Wall5": "772px",
#         "Friend3": "734px",
#         "Friend4": "28px",
#         "Enemy4": "841px",
#         "Wall6": "408px",
#         "Enemy5": "854px",
#         "Tank1": "Dead",
# ...
#         "Wall13": "Dead",
#         "Wall14": "Dead",
#         "Friend10": "Dead",
#         "Tank8": "Dead",
#         "Enemy12": "Dead",
#         "Enemy13": "Dead",
#         "Friend11": "Dead",
#         "Tank9": "Dead",
#         "Friend12": "Dead",
#         "Wall15": "Dead",
#         "Dead soldier -enemy-5": "Dead",
#         "Tank10": "Dead",
#         "Enemy14": "Dead",
#         "Friend13": "Dead"
#     },
#     "Friend5": {
#         "Wall5": "747px",
#         "Friend3": "698px",
#         "Wall6": "396px",
#         "Tank11": "880px",
#         "Enemy15": "1048px",
#         "Enemy16": "826px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead",
#         "Wall4": "Dead",
#         "Tank4": "Dead",
#         "Enemy3": "Dead",
#         "Friend4": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Tank5": "Dead",
#         "Wall7": "Dead",
#         "Wall8": "Dead",
#         "Enemy6": "Dead",
#         "Enemy7": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Dead soldier -enemy-2": "Dead",
#         "Wall9": "Dead",
#         "Enemy8": "Dead",
#         "Tank6": "Dead",
#         "Enemy9": "Dead",
#         "Friend6": "Dead",
#         "Friend7": "Dead",
#         "Wall10": "Dead",
#         "Dead soldier -enemy-3": "Dead",
#         "Tank7": "Dead",
#         "Wall11": "Dead",
#         "Enemy10": "Dead",
#         "Friend8": "Dead",
#         "Friend9": "Dead",
#         "Enemy11": "Dead",
#         "Wall12": "Dead",
#         "Dead soldier -enemy-4": "Dead",
#         "Wall13": "Dead",
#         "Wall14": "Dead",
#         "Friend10": "Dead",
#         "Tank8": "Dead",
#         "Enemy12": "Dead",
#         "Enemy13": "Dead",
#         "Friend11": "Dead",
#         "Tank9": "Dead",
#         "Friend12": "Dead",
#         "Wall15": "Dead",
#         "Dead soldier -enemy-5": "Dead",
#         "Tank10": "Dead",
#         "Enemy14": "Dead",
#         "Friend13": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 46.9ms
# Speed: 1.3ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall5": "424px",
#         "Wall6": "838px",
#         "Friend5": "699px",
#         "Tank11": "942px",
#         "Enemy15": "813px",
#         "Enemy16": "1089px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead",
#         "Wall4": "Dead",
#         "Tank4": "Dead",
#         "Enemy3": "Dead",
#         "Friend4": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Tank5": "Dead",
#         "Wall7": "Dead",
#         "Wall8": "Dead",
#         "Enemy6": "Dead",
#         "Enemy7": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Dead soldier -enemy-2": "Dead",
#         "Wall9": "Dead",
#         "Enemy8": "Dead",
#         "Tank6": "Dead",
#         "Enemy9": "Dead",
#         "Friend6": "Dead",
#         "Friend7": "Dead",
#         "Wall10": "Dead",
#         "Dead soldier -enemy-3": "Dead",
#         "Tank7": "Dead",
#         "Wall11": "Dead",
#         "Enemy10": "Dead",
#         "Friend8": "Dead",
#         "Friend9": "Dead",
#         "Enemy11": "Dead",
#         "Wall12": "Dead",
#         "Dead soldier -enemy-4": "Dead",
#         "Wall13": "Dead",
#         "Wall14": "Dead",
#         "Friend10": "Dead",
#         "Tank8": "Dead",
#         "Enemy12": "Dead",
#         "Enemy13": "Dead",
#         "Friend11": "Dead",
#         "Tank9": "Dead",
#         "Friend12": "Dead",
#         "Wall15": "Dead",
#         "Dead soldier -enemy-5": "Dead",
#         "Tank10": "Dead",
#         "Enemy14": "Dead",
#         "Friend13": "Dead"
#     },
#     "Friend5": {
#         "Wall5": "752px",
#         "Friend3": "699px",
#         "Wall6": "396px",
#         "Tank11": "882px",
#         "Enemy15": "1051px",
#         "Enemy16": "828px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead",
#         "Wall4": "Dead",
#         "Tank4": "Dead",
#         "Enemy3": "Dead",
#         "Friend4": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Tank5": "Dead",
#         "Wall7": "Dead",
#         "Wall8": "Dead",
#         "Enemy6": "Dead",
#         "Enemy7": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Dead soldier -enemy-2": "Dead",
#         "Wall9": "Dead",
#         "Enemy8": "Dead",
#         "Tank6": "Dead",
#         "Enemy9": "Dead",
#         "Friend6": "Dead",
#         "Friend7": "Dead",
#         "Wall10": "Dead",
#         "Dead soldier -enemy-3": "Dead",
#         "Tank7": "Dead",
#         "Wall11": "Dead",
#         "Enemy10": "Dead",
#         "Friend8": "Dead",
#         "Friend9": "Dead",
#         "Enemy11": "Dead",
#         "Wall12": "Dead",
#         "Dead soldier -enemy-4": "Dead",
#         "Wall13": "Dead",
#         "Wall14": "Dead",
#         "Friend10": "Dead",
#         "Tank8": "Dead",
#         "Enemy12": "Dead",
#         "Enemy13": "Dead",
#         "Friend11": "Dead",
#         "Tank9": "Dead",
#         "Friend12": "Dead",
#         "Wall15": "Dead",
#         "Dead soldier -enemy-5": "Dead",
#         "Tank10": "Dead",
#         "Enemy14": "Dead",
#         "Friend13": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 39.0ms
# Speed: 1.6ms preprocess, 39.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall5": "426px",
#         "Wall6": "842px",
#         "Friend5": "702px",
#         "Tank11": "946px",
#         "Enemy15": "815px",
#         "Enemy16": "1095px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead",
#         "Wall4": "Dead",
#         "Tank4": "Dead",
#         "Enemy3": "Dead",
#         "Friend4": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Tank5": "Dead",
#         "Wall7": "Dead",
#         "Wall8": "Dead",
#         "Enemy6": "Dead",
#         "Enemy7": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Dead soldier -enemy-2": "Dead",
#         "Wall9": "Dead",
#         "Enemy8": "Dead",
#         "Tank6": "Dead",
#         "Enemy9": "Dead",
#         "Friend6": "Dead",
#         "Friend7": "Dead",
#         "Wall10": "Dead",
#         "Dead soldier -enemy-3": "Dead",
#         "Tank7": "Dead",
#         "Wall11": "Dead",
#         "Enemy10": "Dead",
#         "Friend8": "Dead",
#         "Friend9": "Dead",
#         "Enemy11": "Dead",
#         "Wall12": "Dead",
#         "Dead soldier -enemy-4": "Dead",
#         "Wall13": "Dead",
#         "Wall14": "Dead",
#         "Friend10": "Dead",
#         "Tank8": "Dead",
#         "Enemy12": "Dead",
#         "Enemy13": "Dead",
#         "Friend11": "Dead",
#         "Tank9": "Dead",
#         "Friend12": "Dead",
#         "Wall15": "Dead",
#         "Dead soldier -enemy-5": "Dead",
#         "Tank10": "Dead",
#         "Enemy14": "Dead",
#         "Friend13": "Dead"
#     },
#     "Friend5": {
#         "Wall5": "756px",
#         "Friend3": "702px",
#         "Wall6": "398px",
#         "Tank11": "885px",
#         "Enemy15": "1055px",
#         "Enemy16": "832px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead",
#         "Wall4": "Dead",
#         "Tank4": "Dead",
#         "Enemy3": "Dead",
#         "Friend4": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Tank5": "Dead",
#         "Wall7": "Dead",
#         "Wall8": "Dead",
#         "Enemy6": "Dead",
#         "Enemy7": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Dead soldier -enemy-2": "Dead",
#         "Wall9": "Dead",
#         "Enemy8": "Dead",
#         "Tank6": "Dead",
#         "Enemy9": "Dead",
#         "Friend6": "Dead",
#         "Friend7": "Dead",
#         "Wall10": "Dead",
#         "Dead soldier -enemy-3": "Dead",
#         "Tank7": "Dead",
#         "Wall11": "Dead",
#         "Enemy10": "Dead",
#         "Friend8": "Dead",
#         "Friend9": "Dead",
#         "Enemy11": "Dead",
#         "Wall12": "Dead",
#         "Dead soldier -enemy-4": "Dead",
#         "Wall13": "Dead",
#         "Wall14": "Dead",
#         "Friend10": "Dead",
#         "Tank8": "Dead",
#         "Enemy12": "Dead",
#         "Enemy13": "Dead",
#         "Friend11": "Dead",
#         "Tank9": "Dead",
#         "Friend12": "Dead",
#         "Wall15": "Dead",
#         "Dead soldier -enemy-5": "Dead",
#         "Tank10": "Dead",
#         "Enemy14": "Dead",
#         "Friend13": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 43.6ms
# Speed: 1.9ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall5": "426px",
#         "Wall6": "843px",
#         "Friend5": "702px",
#         "Tank11": "949px",
#         "Enemy15": "817px",
#         "Enemy16": "1096px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead",
#         "Wall4": "Dead",
#         "Tank4": "Dead",
#         "Enemy3": "Dead",
#         "Friend4": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Tank5": "Dead",
#         "Wall7": "Dead",
#         "Wall8": "Dead",
#         "Enemy6": "Dead",
#         "Enemy7": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Dead soldier -enemy-2": "Dead",
#         "Wall9": "Dead",
#         "Enemy8": "Dead",
#         "Tank6": "Dead",
#         "Enemy9": "Dead",
#         "Friend6": "Dead",
#         "Friend7": "Dead",
#         "Wall10": "Dead",
#         "Dead soldier -enemy-3": "Dead",
#         "Tank7": "Dead",
#         "Wall11": "Dead",
#         "Enemy10": "Dead",
#         "Friend8": "Dead",
#         "Friend9": "Dead",
#         "Enemy11": "Dead",
#         "Wall12": "Dead",
#         "Dead soldier -enemy-4": "Dead",
#         "Wall13": "Dead",
#         "Wall14": "Dead",
#         "Friend10": "Dead",
#         "Tank8": "Dead",
#         "Enemy12": "Dead",
#         "Enemy13": "Dead",
#         "Friend11": "Dead",
#         "Tank9": "Dead",
#         "Friend12": "Dead",
#         "Wall15": "Dead",
#         "Dead soldier -enemy-5": "Dead",
#         "Tank10": "Dead",
#         "Enemy14": "Dead",
#         "Friend13": "Dead"
#     },
#     "Friend5": {
#         "Wall5": "756px",
#         "Friend3": "702px",
#         "Wall6": "397px",
#         "Tank11": "889px",
#         "Enemy15": "1059px",
#         "Enemy16": "833px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead",
#         "Wall4": "Dead",
#         "Tank4": "Dead",
#         "Enemy3": "Dead",
#         "Friend4": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Tank5": "Dead",
#         "Wall7": "Dead",
#         "Wall8": "Dead",
#         "Enemy6": "Dead",
#         "Enemy7": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Dead soldier -enemy-2": "Dead",
#         "Wall9": "Dead",
#         "Enemy8": "Dead",
#         "Tank6": "Dead",
#         "Enemy9": "Dead",
#         "Friend6": "Dead",
#         "Friend7": "Dead",
#         "Wall10": "Dead",
#         "Dead soldier -enemy-3": "Dead",
#         "Tank7": "Dead",
#         "Wall11": "Dead",
#         "Enemy10": "Dead",
#         "Friend8": "Dead",
#         "Friend9": "Dead",
#         "Enemy11": "Dead",
#         "Wall12": "Dead",
#         "Dead soldier -enemy-4": "Dead",
#         "Wall13": "Dead",
#         "Wall14": "Dead",
#         "Friend10": "Dead",
#         "Tank8": "Dead",
#         "Enemy12": "Dead",
#         "Enemy13": "Dead",
#         "Friend11": "Dead",
#         "Tank9": "Dead",
#         "Friend12": "Dead",
#         "Wall15": "Dead",
#         "Dead soldier -enemy-5": "Dead",
#         "Tank10": "Dead",
#         "Enemy14": "Dead",
#         "Friend13": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# {
#     "Friend3": {
#         "Wall5": "427px",
#         "Wall6": "844px",
#         "Friend5": "703px",
#         "Tank11": "949px",
#         "Enemy15": "816px",
#         "Enemy16": "1096px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead",
#         "Wall4": "Dead",
#         "Tank4": "Dead",
#         "Enemy3": "Dead",
#         "Friend4": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Tank5": "Dead",
#         "Wall7": "Dead",
#         "Wall8": "Dead",
#         "Enemy6": "Dead",
#         "Enemy7": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Dead soldier -enemy-2": "Dead",
#         "Wall9": "Dead",
#         "Enemy8": "Dead",
#         "Tank6": "Dead",
#         "Enemy9": "Dead",
#         "Friend6": "Dead",
#         "Friend7": "Dead",
#         "Wall10": "Dead",
#         "Dead soldier -enemy-3": "Dead",
#         "Tank7": "Dead",
#         "Wall11": "Dead",
#         "Enemy10": "Dead",
#         "Friend8": "Dead",
#         "Friend9": "Dead",
#         "Enemy11": "Dead",
#         "Wall12": "Dead",
#         "Dead soldier -enemy-4": "Dead",
#         "Wall13": "Dead",
#         "Wall14": "Dead",
#         "Friend10": "Dead",
#         "Tank8": "Dead",
#         "Enemy12": "Dead",
#         "Enemy13": "Dead",
#         "Friend11": "Dead",
#         "Tank9": "Dead",
#         "Friend12": "Dead",
#         "Wall15": "Dead",
#         "Dead soldier -enemy-5": "Dead",
#         "Tank10": "Dead",
#         "Enemy14": "Dead",
#         "Friend13": "Dead"
#     },
#     "Friend5": {
#         "Wall5": "758px",
#         "Friend3": "703px",
#         "Wall6": "399px",
#         "Tank11": "890px",
#         "Enemy15": "1058px",
#         "Enemy16": "833px",
#         "Tank1": "Dead",
#         "Enemy1": "Dead",
#         "Friend1": "Dead",
#         "Wall1": "Dead",
#         "Wall2": "Dead",
#         "Tank2": "Dead",
#         "Tank3": "Dead",
#         "Enemy2": "Dead",
#         "Friend2": "Dead",
#         "Wall3": "Dead",
#         "Wall4": "Dead",
#         "Tank4": "Dead",
#         "Enemy3": "Dead",
#         "Friend4": "Dead",
#         "Enemy4": "Dead",
#         "Enemy5": "Dead",
#         "Tank5": "Dead",
#         "Wall7": "Dead",
#         "Wall8": "Dead",
#         "Enemy6": "Dead",
#         "Enemy7": "Dead",
#         "Dead soldier -enemy-1": "Dead",
#         "Dead soldier -enemy-2": "Dead",
#         "Wall9": "Dead",
#         "Enemy8": "Dead",
#         "Tank6": "Dead",
#         "Enemy9": "Dead",
#         "Friend6": "Dead",
#         "Friend7": "Dead",
#         "Wall10": "Dead",
#         "Dead soldier -enemy-3": "Dead",
#         "Tank7": "Dead",
#         "Wall11": "Dead",
#         "Enemy10": "Dead",
#         "Friend8": "Dead",
#         "Friend9": "Dead",
#         "Enemy11": "Dead",
#         "Wall12": "Dead",
#         "Dead soldier -enemy-4": "Dead",
#         "Wall13": "Dead",
#         "Wall14": "Dead",
#         "Friend10": "Dead",
#         "Tank8": "Dead",
#         "Enemy12": "Dead",
#         "Enemy13": "Dead",
#         "Friend11": "Dead",
#         "Tank9": "Dead",
#         "Friend12": "Dead",
#         "Wall15": "Dead",
#         "Dead soldier -enemy-5": "Dead",
#         "Tank10": "Dead",
#         "Enemy14": "Dead",
#         "Friend13": "Dead"
#     }
# }
#
# 0: 384x640 1 Tank, 2 Walls, 2 enemys, 2 friends, 43.6ms
# Speed: 1.3ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)

# %%
# JSON Correct. Object name not
import cv2
import math
import random
import json
from collections import defaultdict
from scipy.spatial import distance
from ultralytics import YOLO  

# Load the YOLO model
model = YOLO('../models/first_model.pt')  # Change to your model path

# Open the video file
video_path = '../test_vids/battlefield-1.mp4'
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"

# Store previous object locations for tracking
object_tracker = {}

# Maximum distance to consider an object as the same across frames
MAX_TRACKING_DISTANCE = 50

# Frame counter to remove old objects
frame_counter = 0
MAX_FRAMES_MISSING = 10  # If an object disappears for this many frames, we remove it

def calculate_distances(friends, other_objects):
    """
    Calculate distances between friends and all other objects
    
    Args:
    friends (list): List of (name, x, y) for friend objects
    other_objects (list): List of (name, x, y) for other objects
    
    Returns:
    dict: Distance data between friends and other objects
    """
    distance_data = {}
    
    # For each friend
    for friend_name, friend_x, friend_y in friends:
        friend_distances = {}
        
        # Calculate distance to each other object
        for obj_name, obj_x, obj_y in other_objects:
            # Avoid calculating distance to self
            if friend_name != obj_name:
                dist_pixels = int(math.dist((friend_x, friend_y), (obj_x, obj_y)))
                friend_distances[obj_name] = f"{dist_pixels}px"
        
        # If no other objects, mark friend lonely
        if not friend_distances:
            friend_distances = "lonely"
        
        distance_data[friend_name] = friend_distances
    
    return distance_data

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Video processing completed.")
        break

    frame_counter += 1

    # Perform object detection
    results = model(frame)
    detections = results[0].boxes  

    friends = []  # Track friends
    other_objects = []  # Track other objects

    # Draw bounding boxes, labels, and store centers
    for box in detections:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Extract box coordinates
        confidence = box.conf[0]  # Extract confidence score
        label_id = int(box.cls[0])  # Extract class label ID

        # Get the class name from the model
        class_name = model.names[label_id]  
        class_name_lower = class_name.lower()

        # Calculate the center point
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2

        # Try to match with existing tracked objects
        assigned_id = None
        for obj_id, (prev_x, prev_y, prev_label, last_seen) in object_tracker.items():
            if prev_label == class_name_lower and distance.euclidean((prev_x, prev_y), (center_x, center_y)) < MAX_TRACKING_DISTANCE:
                assigned_id = obj_id
                break

        # If no match found, assign a new ID
        if assigned_id is None:
            assigned_id = len(object_tracker) + 1

        # Create unique name
        unique_name = f"{class_name} {assigned_id}"

        # Store object for the next frame
        object_tracker[assigned_id] = (center_x, center_y, class_name_lower, frame_counter)

        # Separate friends from other objects
        if class_name_lower == 'friend':
            friends.append((unique_name, center_x, center_y))
        else:
            other_objects.append((unique_name, center_x, center_y))

    # Remove old objects that haven't been seen for a while
    object_tracker = {obj_id: data for obj_id, data in object_tracker.items() 
                      if frame_counter - data[3] < MAX_FRAMES_MISSING}

    # Calculate distances if friends exist
    if friends:
        distance_data = calculate_distances(friends, other_objects)
        
        # Print the current distance data
        print(json.dumps(distance_data, indent=4))

    # Display the frame (optional, can be removed)
    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.7ms
# Speed: 2.8ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "193px",
#         "Tank 2": "367px",
#         "Wall 3": "228px",
#         "enemy 5": "291px",
#         "Dead soldier -frd- 6": "352px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.5ms
# Speed: 1.2ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "193px",
#         "Tank 2": "368px",
#         "Wall 3": "228px",
#         "enemy 5": "292px",
#         "Dead soldier -frd- 6": "354px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 53.0ms
# Speed: 1.3ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "193px",
#         "Tank 2": "367px",
#         "Wall 3": "228px",
#         "enemy 5": "292px",
#         "Dead soldier -frd- 6": "355px",
#         "enemy 7": "314px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.6ms
# Speed: 1.5ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "368px",
#         "Wall 1": "193px",
#         "Wall 3": "227px",
#         "enemy 5": "293px",
#         "Dead soldier -frd- 6": "355px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.8ms
# Speed: 1.4ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "194px",
#         "Tank 2": "369px",
#         "Wall 3": "229px",
#         "Dead soldier -frd- 6": "355px",
#         "enemy 5": "292px",
#         "enemy 7": "316px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.6ms
# Speed: 1.4ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "194px",
#         "Tank 2": "369px",
#         "Wall 3": "229px",
#         "enemy 5": "292px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "316px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "369px",
#         "Wall 1": "195px",
#         "Wall 3": "230px",
#         "enemy 5": "293px",
#         "Dead soldier -frd- 6": "357px",
#         "enemy 7": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "369px",
#         "Wall 1": "195px",
#         "Wall 3": "230px",
#         "enemy 5": "292px",
#         "Dead soldier -frd- 6": "357px",
#         "enemy 7": "317px"
#     }
# }
# 2025-02-04 02:22:14.599 python[27501:543975] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-04 02:22:14.599 python[27501:543975] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 49.7ms
# Speed: 1.2ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "369px",
#         "Wall 1": "194px",
#         "Wall 3": "228px",
#         "enemy 5": "292px",
#         "Dead soldier -frd- 6": "345px",
#         "enemy 7": "316px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "369px",
#         "Wall 3": "230px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "343px",
#         "enemy 7": "318px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "368px",
#         "Wall 3": "228px",
#         "enemy 5": "293px",
#         "Dead soldier -frd- 6": "347px",
#         "enemy 7": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "369px",
#         "Wall 3": "231px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "346px",
#         "enemy 7": "318px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "370px",
#         "Wall 3": "232px",
#         "enemy 5": "296px",
#         "Dead soldier -frd- 6": "342px",
#         "enemy 7": "320px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.1ms
# Speed: 1.2ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "368px",
#         "Wall 3": "231px",
#         "enemy 5": "295px",
#         "Dead soldier -frd- 6": "346px",
#         "enemy 7": "319px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.3ms
# Speed: 1.8ms preprocess, 36.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "368px",
#         "Wall 3": "231px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "319px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.1ms
# Speed: 1.0ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "369px",
#         "Wall 3": "230px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "319px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.5ms
# Speed: 0.9ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "197px",
#         "Tank 2": "369px",
#         "Wall 3": "231px",
#         "enemy 5": "295px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "318px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "368px",
#         "Wall 3": "229px",
#         "enemy 5": "293px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "318px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 34.6ms
# Speed: 1.0ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "197px",
#         "Tank 2": "369px",
#         "Wall 3": "230px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.9ms
# Speed: 1.1ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "368px",
#         "Wall 3": "231px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 5": "294px",
#         "enemy 7": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "197px",
#         "Tank 2": "367px",
#         "Wall 3": "230px",
#         "enemy 5": "294px",
#         "Dead soldier -frd- 6": "356px",
#         "enemy 7": "316px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 52.7ms
# Speed: 3.0ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "367px",
#         "Wall 3": "229px",
#         "Dead soldier -frd- 6": "355px",
#         "enemy 5": "292px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "367px",
#         "Wall 3": "229px",
#         "Dead soldier -frd- 6": "355px",
#         "enemy 5": "292px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 34.0ms
# Speed: 1.1ms preprocess, 34.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "195px",
#         "Tank 2": "367px",
#         "Wall 3": "229px",
#         "Dead soldier -frd- 6": "354px",
#         "enemy 5": "293px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.8ms
# Speed: 1.1ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "367px",
#         "Wall 3": "230px",
#         "Dead soldier -frd- 6": "354px",
#         "enemy 5": "292px",
#         "enemy 7": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.0ms
# Speed: 1.2ms preprocess, 38.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "194px",
#         "Tank 2": "365px",
#         "Wall 3": "228px",
#         "Dead soldier -frd- 6": "352px",
#         "enemy 5": "291px",
#         "enemy 7": "313px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "194px",
#         "Tank 2": "364px",
#         "Wall 3": "228px",
#         "Dead soldier -frd- 6": "351px",
#         "enemy 5": "290px",
#         "enemy 7": "313px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.5ms
# Speed: 1.1ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "193px",
#         "Tank 2": "364px",
#         "Wall 3": "228px",
#         "Dead soldier -frd- 6": "352px",
#         "enemy 5": "290px",
#         "enemy 7": "312px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.8ms
# Speed: 1.1ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "193px",
#         "Tank 2": "364px",
#         "Wall 3": "227px",
#         "Dead soldier -frd- 6": "351px",
#         "enemy 5": "289px",
#         "enemy 7": "311px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.4ms
# Speed: 1.3ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "191px",
#         "Tank 2": "362px",
#         "Wall 3": "226px",
#         "Dead soldier -frd- 6": "350px",
#         "enemy 5": "288px",
#         "enemy 7": "310px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "190px",
#         "Tank 2": "360px",
#         "Wall 3": "225px",
#         "Dead soldier -frd- 6": "349px",
#         "enemy 5": "286px",
#         "enemy 7": "309px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 32.8ms
# Speed: 1.1ms preprocess, 32.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "189px",
#         "Tank 2": "360px",
#         "Wall 3": "224px",
#         "Dead soldier -frd- 6": "348px",
#         "enemy 5": "285px",
#         "enemy 7": "308px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.2ms
# Speed: 1.1ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "188px",
#         "Tank 2": "360px",
#         "Wall 3": "222px",
#         "Dead soldier -frd- 6": "347px",
#         "enemy 5": "284px",
#         "enemy 7": "307px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.7ms
# Speed: 1.1ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "188px",
#         "Tank 2": "360px",
#         "Wall 3": "222px",
#         "Dead soldier -frd- 6": "346px",
#         "enemy 5": "283px",
#         "enemy 7": "308px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 34.2ms
# Speed: 0.9ms preprocess, 34.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "187px",
#         "Tank 2": "359px",
#         "Wall 3": "221px",
#         "Dead soldier -frd- 6": "345px",
#         "enemy 5": "283px",
#         "enemy 7": "306px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "185px",
#         "Tank 2": "356px",
#         "Wall 3": "217px",
#         "Dead soldier -frd- 6": "341px",
#         "enemy 5": "279px",
#         "enemy 7": "303px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.0ms
# Speed: 1.0ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "182px",
#         "Tank 2": "353px",
#         "Wall 3": "215px",
#         "Dead soldier -frd- 6": "339px",
#         "enemy 5": "277px",
#         "enemy 7": "300px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "181px",
#         "Tank 2": "351px",
#         "Wall 3": "215px",
#         "Dead soldier -frd- 6": "338px",
#         "enemy 5": "275px",
#         "enemy 7": "299px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 37.2ms
# Speed: 1.1ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "180px",
#         "Tank 2": "350px",
#         "Wall 3": "214px",
#         "enemy 5": "274px",
#         "Dead soldier -frd- 6": "336px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.7ms
# Speed: 1.2ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "180px",
#         "Tank 2": "349px",
#         "Wall 3": "212px",
#         "enemy 5": "272px",
#         "Dead soldier -frd- 6": "333px",
#         "Dead soldier -enemy- 8": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.6ms
# Speed: 1.1ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "348px",
#         "Wall 1": "178px",
#         "Wall 3": "212px",
#         "enemy 5": "272px",
#         "Dead soldier -enemy- 8": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "348px",
#         "Wall 1": "177px",
#         "Wall 3": "212px",
#         "Dead soldier -enemy- 8": "317px",
#         "enemy 5": "272px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.5ms
# Speed: 1.3ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "177px",
#         "Tank 2": "347px",
#         "Wall 3": "210px",
#         "Dead soldier -enemy- 8": "315px",
#         "enemy 5": "270px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 43.8ms
# Speed: 1.2ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "345px",
#         "Wall 1": "176px",
#         "Wall 3": "208px",
#         "Dead soldier -enemy- 8": "313px",
#         "enemy 5": "269px",
#         "Dead soldier -frd- 6": "315px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "344px",
#         "Wall 1": "175px",
#         "Wall 3": "207px",
#         "Dead soldier -enemy- 8": "312px",
#         "enemy 5": "267px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 33.4ms
# Speed: 1.3ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "342px",
#         "Wall 1": "174px",
#         "Wall 3": "207px",
#         "Dead soldier -enemy- 8": "310px",
#         "enemy 5": "266px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "341px",
#         "Wall 1": "174px",
#         "Wall 3": "203px",
#         "Dead soldier -enemy- 8": "309px",
#         "enemy 5": "264px",
#         "Dead soldier -frd- 6": "311px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "341px",
#         "Wall 1": "174px",
#         "Wall 3": "202px",
#         "enemy 5": "262px",
#         "Dead soldier -enemy- 8": "307px",
#         "Dead soldier -frd- 6": "308px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "340px",
#         "Wall 1": "174px",
#         "Wall 3": "200px",
#         "enemy 5": "261px",
#         "Dead soldier -enemy- 8": "304px",
#         "Dead soldier -frd- 6": "317px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "174px",
#         "Tank 2": "339px",
#         "Wall 3": "199px",
#         "enemy 5": "260px",
#         "Dead soldier -enemy- 8": "303px",
#         "Dead soldier -frd- 6": "313px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 36.1ms
# Speed: 1.2ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "338px",
#         "Wall 1": "173px",
#         "Wall 3": "197px",
#         "enemy 5": "259px",
#         "Dead soldier -enemy- 8": "302px",
#         "Dead soldier -frd- 6": "316px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.8ms
# Speed: 1.1ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "172px",
#         "Tank 2": "337px",
#         "Wall 3": "196px",
#         "enemy 5": "258px",
#         "Dead soldier -enemy- 8": "300px",
#         "Dead soldier -frd- 6": "316px",
#         "enemy 8": "279px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 37.6ms
# Speed: 1.1ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "170px",
#         "Tank 2": "336px",
#         "Wall 3": "196px",
#         "enemy 5": "257px",
#         "Dead soldier -frd- 6": "317px",
#         "Dead soldier -enemy- 8": "315px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "334px",
#         "Wall 1": "168px",
#         "Wall 3": "197px",
#         "enemy 5": "256px",
#         "Dead soldier -frd- 6": "317px",
#         "enemy 8": "277px",
#         "Dead soldier -enemy- 8": "301px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -enemy-s, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "167px",
#         "Tank 2": "332px",
#         "Wall 3": "195px",
#         "enemy 5": "253px",
#         "Dead soldier -frd- 6": "315px",
#         "Dead soldier -enemy- 8": "302px",
#         "enemy 8": "275px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "329px",
#         "Wall 1": "165px",
#         "Wall 3": "193px",
#         "enemy 5": "251px",
#         "Dead soldier -frd- 6": "312px",
#         "enemy 8": "273px",
#         "Dead soldier -enemy- 8": "313px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.7ms
# Speed: 1.2ms preprocess, 36.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "327px",
#         "Wall 1": "163px",
#         "Wall 3": "191px",
#         "enemy 5": "248px",
#         "Dead soldier -frd- 6": "309px",
#         "Dead soldier -enemy- 8": "306px",
#         "enemy 8": "270px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "326px",
#         "Wall 1": "162px",
#         "Wall 3": "191px",
#         "enemy 5": "247px",
#         "Dead soldier -frd- 6": "307px",
#         "enemy 8": "269px",
#         "Dead soldier -enemy- 8": "307px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "324px",
#         "Wall 1": "160px",
#         "Wall 3": "189px",
#         "enemy 5": "245px",
#         "Dead soldier -frd- 6": "305px",
#         "enemy 8": "268px",
#         "Dead soldier -enemy- 8": "305px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "322px",
#         "Wall 1": "161px",
#         "Wall 3": "187px",
#         "enemy 5": "243px",
#         "Dead soldier -enemy- 8": "304px",
#         "Dead soldier -frd- 6": "304px",
#         "enemy 8": "266px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.2ms
# Speed: 1.1ms preprocess, 35.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "322px",
#         "Wall 3": "185px",
#         "enemy 5": "243px",
#         "Wall 1": "160px",
#         "Dead soldier -frd- 6": "302px",
#         "enemy 8": "266px",
#         "Dead soldier -enemy- 8": "303px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.7ms
# Speed: 1.1ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "322px",
#         "Wall 3": "183px",
#         "enemy 5": "242px",
#         "Wall 1": "161px",
#         "enemy 8": "264px",
#         "Dead soldier -enemy- 8": "302px",
#         "Dead soldier -frd- 6": "301px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 65.7ms
# Speed: 1.5ms preprocess, 65.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 3": "183px",
#         "Tank 2": "321px",
#         "enemy 5": "241px",
#         "Wall 1": "161px",
#         "enemy 8": "263px",
#         "Dead soldier -frd- 6": "302px",
#         "Dead soldier -enemy- 8": "302px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "321px",
#         "Wall 3": "182px",
#         "enemy 5": "241px",
#         "Wall 1": "161px",
#         "Dead soldier -frd- 6": "301px",
#         "enemy 8": "262px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.0ms
# Speed: 1.2ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "321px",
#         "enemy 5": "239px",
#         "Wall 3": "177px",
#         "Wall 1": "161px",
#         "Dead soldier -frd- 6": "299px",
#         "enemy 8": "261px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "322px",
#         "Wall 3": "175px",
#         "Wall 1": "164px",
#         "enemy 5": "239px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 8": "260px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "322px",
#         "Wall 3": "174px",
#         "Wall 1": "164px",
#         "enemy 5": "239px",
#         "Dead soldier -frd- 6": "297px",
#         "enemy 8": "259px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "323px",
#         "Wall 3": "173px",
#         "Wall 1": "166px",
#         "enemy 5": "239px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 8": "258px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.6ms
# Speed: 1.1ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "324px",
#         "Wall 3": "171px",
#         "Wall 1": "167px",
#         "enemy 5": "239px",
#         "Dead soldier -frd- 6": "296px",
#         "enemy 8": "257px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.2ms
# Speed: 1.2ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "325px",
#         "Wall 3": "169px",
#         "Wall 1": "170px",
#         "Dead soldier -frd- 6": "296px",
#         "enemy 5": "240px",
#         "enemy 8": "257px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 81.8ms
# Speed: 6.0ms preprocess, 81.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "329px",
#         "Wall 3": "167px",
#         "Wall 1": "175px",
#         "Dead soldier -frd- 6": "297px",
#         "enemy 5": "241px",
#         "enemy 8": "257px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 42.6ms
# Speed: 1.2ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "332px",
#         "Wall 1": "180px",
#         "Wall 3": "164px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 5": "244px",
#         "enemy 8": "256px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.2ms
# Speed: 1.1ms preprocess, 36.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "331px",
#         "Wall 1": "180px",
#         "Wall 3": "160px",
#         "Dead soldier -frd- 6": "296px",
#         "enemy 5": "242px",
#         "enemy 8": "254px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 33.7ms
# Speed: 1.2ms preprocess, 33.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "334px",
#         "Wall 1": "182px",
#         "Wall 3": "162px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 5": "244px",
#         "enemy 8": "255px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "337px",
#         "Wall 1": "187px",
#         "Wall 3": "158px",
#         "Dead soldier -frd- 6": "299px",
#         "enemy 5": "247px",
#         "enemy 8": "255px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.8ms
# Speed: 1.3ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "337px",
#         "Wall 1": "189px",
#         "Wall 3": "156px",
#         "Dead soldier -frd- 6": "297px",
#         "enemy 5": "246px",
#         "enemy 8": "254px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "337px",
#         "Wall 1": "189px",
#         "Wall 3": "156px",
#         "Dead soldier -frd- 6": "297px",
#         "enemy 5": "246px",
#         "enemy 8": "253px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.2ms
# Speed: 5.5ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "340px",
#         "Wall 1": "192px",
#         "Wall 3": "156px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 5": "248px",
#         "enemy 8": "254px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.0ms
# Speed: 1.2ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "342px",
#         "Wall 1": "195px",
#         "Wall 3": "153px",
#         "Dead soldier -frd- 6": "299px",
#         "enemy 5": "248px",
#         "enemy 8": "254px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.6ms
# Speed: 1.2ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "343px",
#         "Wall 1": "196px",
#         "Wall 3": "153px",
#         "enemy 5": "250px",
#         "Dead soldier -frd- 6": "298px",
#         "enemy 8": "255px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.5ms
# Speed: 1.2ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "343px",
#         "Wall 1": "194px",
#         "Wall 3": "152px",
#         "Dead soldier -frd- 6": "297px",
#         "enemy 5": "249px",
#         "enemy 8": "254px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.5ms
# Speed: 1.2ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "343px",
#         "Wall 1": "194px",
#         "Dead soldier -frd- 6": "296px",
#         "Wall 3": "150px",
#         "enemy 5": "248px",
#         "enemy 8": "253px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.8ms
# Speed: 1.2ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "342px",
#         "Wall 1": "194px",
#         "Dead soldier -frd- 6": "295px",
#         "Wall 3": "149px",
#         "enemy 5": "247px",
#         "enemy 8": "252px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.2ms
# Speed: 1.3ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "196px",
#         "Tank 2": "343px",
#         "Dead soldier -frd- 6": "296px",
#         "Wall 3": "148px",
#         "enemy 5": "247px",
#         "enemy 8": "251px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.1ms
# Speed: 12.4ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "198px",
#         "Tank 2": "344px",
#         "Dead soldier -frd- 6": "295px",
#         "Wall 3": "146px",
#         "enemy 5": "247px",
#         "enemy 8": "251px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.6ms
# Speed: 1.1ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "199px",
#         "Tank 2": "346px",
#         "Wall 3": "144px",
#         "Dead soldier -frd- 6": "296px",
#         "enemy 5": "248px",
#         "enemy 8": "252px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Wall 1": "199px",
#         "Tank 2": "347px",
#         "Wall 3": "143px",
#         "Dead soldier -frd- 6": "295px",
#         "enemy 5": "248px",
#         "enemy 8": "250px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "348px",
#         "Wall 1": "201px",
#         "Wall 3": "142px",
#         "Dead soldier -frd- 6": "276px",
#         "enemy 5": "250px",
#         "enemy 8": "251px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 1": "204px",
#         "Wall 3": "141px",
#         "Dead soldier -frd- 6": "278px",
#         "enemy 5": "252px",
#         "enemy 8": "253px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 59.1ms
# Speed: 1.0ms preprocess, 59.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "354px",
#         "Wall 1": "209px",
#         "Wall 3": "139px",
#         "Dead soldier -frd- 6": "279px",
#         "enemy 5": "254px",
#         "enemy 8": "252px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.0ms
# Speed: 1.2ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "355px",
#         "Wall 1": "210px",
#         "Wall 3": "137px",
#         "Dead soldier -frd- 6": "277px",
#         "enemy 5": "253px",
#         "enemy 8": "251px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.1ms
# Speed: 1.2ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "353px",
#         "Wall 1": "210px",
#         "Wall 3": "135px",
#         "enemy 5": "252px",
#         "Dead soldier -frd- 6": "276px",
#         "enemy 8": "249px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.1ms
# Speed: 1.3ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "355px",
#         "Wall 1": "212px",
#         "Wall 3": "135px",
#         "enemy 5": "253px",
#         "Dead soldier -frd- 6": "277px",
#         "enemy 8": "250px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "356px",
#         "Wall 1": "213px",
#         "Wall 3": "133px",
#         "Dead soldier -frd- 6": "277px",
#         "enemy 5": "253px",
#         "enemy 8": "249px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 61.7ms
# Speed: 1.2ms preprocess, 61.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "355px",
#         "Wall 1": "214px",
#         "Wall 3": "132px",
#         "Dead soldier -frd- 6": "277px",
#         "enemy 5": "254px",
#         "enemy 8": "248px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "354px",
#         "Wall 3": "131px",
#         "Wall 1": "214px",
#         "Dead soldier -frd- 6": "274px",
#         "enemy 5": "252px",
#         "enemy 8": "248px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 35.4ms
# Speed: 1.1ms preprocess, 35.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "355px",
#         "Wall 3": "129px",
#         "Wall 1": "215px",
#         "Dead soldier -frd- 6": "276px",
#         "enemy 5": "253px",
#         "enemy 8": "246px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 1 enemy, 1 friend, 38.0ms
# Speed: 1.1ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "353px",
#         "Wall 3": "128px",
#         "Wall 1": "213px",
#         "Dead soldier -frd- 6": "274px",
#         "enemy 5": "252px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "353px",
#         "Wall 3": "127px",
#         "Dead soldier -frd- 6": "291px",
#         "enemy 5": "251px",
#         "Wall 1": "212px",
#         "enemy 8": "244px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.6ms
# Speed: 1.3ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "350px",
#         "Wall 3": "125px",
#         "Dead soldier -frd- 6": "289px",
#         "Wall 1": "210px",
#         "enemy 5": "249px",
#         "enemy 8": "243px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.5ms
# Speed: 4.3ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "348px",
#         "Wall 3": "124px",
#         "Dead soldier -frd- 6": "271px",
#         "Wall 1": "208px",
#         "enemy 5": "246px",
#         "enemy 8": "240px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "124px",
#         "Dead soldier -frd- 6": "276px",
#         "Wall 1": "211px",
#         "enemy 5": "249px",
#         "enemy 8": "243px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.1ms
# Speed: 1.1ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "352px",
#         "Wall 3": "124px",
#         "enemy 5": "249px",
#         "Wall 1": "212px",
#         "Dead soldier -frd- 6": "281px",
#         "enemy 8": "242px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "352px",
#         "Wall 3": "121px",
#         "enemy 5": "249px",
#         "Wall 1": "212px",
#         "Dead soldier -frd- 6": "278px",
#         "enemy 8": "240px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "121px",
#         "enemy 5": "248px",
#         "Wall 1": "212px",
#         "Dead soldier -frd- 6": "287px",
#         "enemy 8": "240px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 57.8ms
# Speed: 1.0ms preprocess, 57.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "120px",
#         "enemy 5": "249px",
#         "Wall 1": "213px",
#         "Dead soldier -frd- 6": "273px",
#         "enemy 8": "240px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 37.8ms
# Speed: 1.2ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "352px",
#         "Wall 3": "120px",
#         "enemy 5": "251px",
#         "Dead soldier -frd- 6": "270px",
#         "Wall 1": "215px",
#         "enemy 8": "240px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "119px",
#         "Dead soldier -frd- 6": "273px",
#         "enemy 5": "250px",
#         "Wall 1": "215px",
#         "enemy 8": "239px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.2ms
# Speed: 1.1ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "117px",
#         "Dead soldier -frd- 6": "269px",
#         "enemy 5": "249px",
#         "Wall 1": "216px",
#         "enemy 8": "238px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "358px",
#         "Wall 3": "118px",
#         "enemy 5": "255px",
#         "Dead soldier -frd- 6": "274px",
#         "Wall 1": "224px",
#         "enemy 8": "241px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "361px",
#         "Wall 3": "117px",
#         "enemy 5": "258px",
#         "Wall 1": "226px",
#         "Dead soldier -frd- 6": "272px",
#         "enemy 8": "243px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 45.6ms
# Speed: 10.2ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "360px",
#         "Wall 3": "118px",
#         "enemy 5": "258px",
#         "Wall 1": "226px",
#         "Dead soldier -frd- 6": "272px",
#         "enemy 8": "243px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.7ms
# Speed: 1.3ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "358px",
#         "Wall 3": "115px",
#         "enemy 5": "256px",
#         "Dead soldier -frd- 6": "273px",
#         "enemy 8": "240px",
#         "Wall 1": "223px"
#     }
# }
#
# 0: 640x384 2 Dead soldier -frd-s, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "349px",
#         "Wall 3": "111px",
#         "enemy 5": "246px",
#         "Dead soldier -frd- 6": "269px",
#         "enemy 8": "233px",
#         "Wall 1": "214px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "345px",
#         "Wall 3": "110px",
#         "enemy 5": "243px",
#         "Dead soldier -frd- 6": "279px",
#         "enemy 8": "232px",
#         "Wall 1": "211px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 41.3ms
# Speed: 1.0ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "346px",
#         "Wall 3": "110px",
#         "enemy 5": "244px",
#         "enemy 8": "232px",
#         "Dead soldier -frd- 6": "279px",
#         "Wall 1": "212px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 51.9ms
# Speed: 4.6ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "351px",
#         "Wall 3": "112px",
#         "enemy 5": "249px",
#         "Dead soldier -frd- 6": "283px",
#         "enemy 8": "236px",
#         "Wall 1": "217px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "356px",
#         "Wall 3": "112px",
#         "enemy 5": "253px",
#         "enemy 8": "238px",
#         "Dead soldier -frd- 6": "287px",
#         "Wall 1": "222px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.8ms
# Speed: 1.1ms preprocess, 39.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "353px",
#         "Wall 3": "110px",
#         "enemy 5": "251px",
#         "Dead soldier -frd- 6": "285px",
#         "enemy 8": "235px",
#         "Wall 1": "221px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "347px",
#         "Wall 3": "108px",
#         "enemy 5": "246px",
#         "Dead soldier -frd- 6": "280px",
#         "enemy 8": "231px",
#         "Wall 1": "215px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 60.6ms
# Speed: 1.3ms preprocess, 60.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "345px",
#         "Wall 3": "106px",
#         "enemy 5": "243px",
#         "Dead soldier -frd- 6": "278px",
#         "Wall 1": "213px",
#         "enemy 8": "229px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "344px",
#         "Wall 3": "105px",
#         "enemy 5": "243px",
#         "Dead soldier -frd- 6": "277px",
#         "Wall 1": "213px",
#         "enemy 8": "228px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 41.2ms
# Speed: 1.2ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Dead soldier -frd-, 1 Tank, 2 Walls, 2 enemys, 1 friend, 39.2ms
# Speed: 1.2ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 4": {
#         "Tank 2": "348px",
# ...
#         "Dead soldier -enemy- 6": "328px",
#         "enemy 5": "346px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "144px",
#         "Tank 2": "185px",
#         "Dead soldier -enemy- 6": "328px",
#         "Dead soldier -frd- 6": "209px",
#         "Wall 3": "292px",
#         "enemy 5": "345px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 53.9ms
# Speed: 1.4ms preprocess, 53.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "143px",
#         "Tank 2": "185px",
#         "Dead soldier -enemy- 6": "327px",
#         "Dead soldier -frd- 6": "209px",
#         "Wall 3": "291px",
#         "enemy 5": "343px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 51.0ms
# Speed: 1.3ms preprocess, 51.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "143px",
#         "Tank 2": "185px",
#         "Dead soldier -enemy- 6": "327px",
#         "Dead soldier -frd- 6": "209px",
#         "Wall 3": "292px",
#         "enemy 5": "345px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 47.3ms
# Speed: 1.1ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "141px",
#         "Tank 2": "184px",
#         "Wall 3": "290px",
#         "enemy 5": "344px",
#         "Dead soldier -frd- 6": "208px",
#         "Dead soldier -enemy- 6": "325px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "141px",
#         "Tank 2": "185px",
#         "Wall 3": "290px",
#         "Dead soldier -frd- 6": "208px",
#         "enemy 5": "344px",
#         "Dead soldier -enemy- 6": "325px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.8ms
# Speed: 1.3ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "142px",
#         "Tank 2": "184px",
#         "Dead soldier -frd- 6": "208px",
#         "Wall 3": "290px",
#         "Dead soldier -enemy- 6": "325px",
#         "enemy 5": "343px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "143px",
#         "Tank 2": "184px",
#         "Dead soldier -frd- 6": "207px",
#         "Wall 3": "290px",
#         "enemy 5": "342px",
#         "Dead soldier -enemy- 6": "325px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "143px",
#         "Tank 2": "184px",
#         "Dead soldier -frd- 6": "206px",
#         "Wall 3": "289px",
#         "Dead soldier -enemy- 6": "324px",
#         "enemy 5": "343px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "144px",
#         "Tank 2": "185px",
#         "Dead soldier -frd- 6": "207px",
#         "Dead soldier -enemy- 6": "326px",
#         "Wall 3": "289px",
#         "enemy 5": "344px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "143px",
#         "Tank 2": "184px",
#         "Dead soldier -enemy- 6": "324px",
#         "Dead soldier -frd- 6": "205px",
#         "Wall 3": "287px",
#         "enemy 5": "343px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 52.6ms
# Speed: 1.1ms preprocess, 52.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "142px",
#         "Dead soldier -enemy- 6": "323px",
#         "Tank 2": "183px",
#         "Dead soldier -frd- 6": "206px",
#         "Wall 3": "289px",
#         "enemy 5": "343px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 51.2ms
# Speed: 1.1ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "323px",
#         "Wall 1": "142px",
#         "Tank 2": "182px",
#         "Dead soldier -frd- 6": "205px",
#         "Wall 3": "289px",
#         "enemy 5": "342px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 56.0ms
# Speed: 1.1ms preprocess, 56.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "322px",
#         "Wall 1": "142px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "182px",
#         "Wall 3": "288px",
#         "enemy 5": "342px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 86.9ms
# Speed: 1.0ms preprocess, 86.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "322px",
#         "Dead soldier -frd- 6": "205px",
#         "Wall 1": "141px",
#         "Tank 2": "182px",
#         "Wall 3": "287px",
#         "enemy 5": "342px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "322px",
#         "Dead soldier -frd- 6": "205px",
#         "Wall 1": "142px",
#         "Tank 2": "182px",
#         "Wall 3": "288px",
#         "enemy 5": "342px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "322px",
#         "Dead soldier -frd- 6": "205px",
#         "Wall 1": "142px",
#         "Tank 2": "182px",
#         "Wall 3": "288px",
#         "enemy 5": "342px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "182px",
#         "Wall 3": "287px",
#         "enemy 5": "341px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 54.2ms
# Speed: 1.2ms preprocess, 54.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "341px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 101.9ms
# Speed: 1.4ms preprocess, 101.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "341px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "320px",
#         "Wall 1": "140px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "339px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "340px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 46.7ms
# Speed: 1.0ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "340px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 48.1ms
# Speed: 1.1ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "321px",
#         "Wall 1": "141px",
#         "Dead soldier -frd- 6": "203px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "340px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "320px",
#         "Wall 1": "140px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "182px",
#         "Wall 3": "285px",
#         "enemy 5": "339px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 57.2ms
# Speed: 1.1ms preprocess, 57.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Dead soldier -enemy- 6": "319px",
#         "Wall 1": "139px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "338px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 56.4ms
# Speed: 1.2ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -enemy- 6": "319px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "338px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 56.1ms
# Speed: 1.5ms preprocess, 56.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "319px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "339px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 51.0ms
# Speed: 1.2ms preprocess, 51.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "205px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "337px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 59.7ms
# Speed: 1.3ms preprocess, 59.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "319px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "337px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 75.8ms
# Speed: 1.3ms preprocess, 75.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -enemy- 6": "319px",
#         "Tank 2": "182px",
#         "Dead soldier -frd- 6": "203px",
#         "Wall 3": "282px",
#         "enemy 5": "338px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 54.8ms
# Speed: 1.7ms preprocess, 54.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Wall 3": "283px",
#         "enemy 5": "338px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 53.7ms
# Speed: 1.2ms preprocess, 53.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Wall 3": "284px",
#         "enemy 5": "338px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Dead soldier -enemy- 6": "318px",
#         "Wall 3": "284px",
#         "enemy 5": "335px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -frd- 6": "203px",
#         "Tank 2": "181px",
#         "Dead soldier -enemy- 6": "318px",
#         "Wall 3": "285px",
#         "enemy 5": "336px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 54.8ms
# Speed: 1.3ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "203px",
#         "Tank 2": "181px",
#         "Wall 3": "284px",
#         "enemy 5": "336px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 47.9ms
# Speed: 1.2ms preprocess, 47.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "140px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "202px",
#         "Tank 2": "181px",
#         "Wall 3": "284px",
#         "enemy 5": "336px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 52.8ms
# Speed: 1.2ms preprocess, 52.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "203px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "337px"
#     }
# }
#
# 0: 640x384 1 Dead soldier -enemy-, 1 Dead soldier -frd-, 1 Tank, 2 Walls, 1 enemy, 1 friend, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
# {
#     "friend 6": {
#         "Wall 1": "139px",
#         "Dead soldier -enemy- 6": "318px",
#         "Dead soldier -frd- 6": "204px",
#         "Tank 2": "181px",
#         "Wall 3": "285px",
#         "enemy 5": "337px"
#     }
# }
# Video processing completed.

# %%
import cv2
import math
import random
import json
from collections import defaultdict
from scipy.spatial import distance
from ultralytics import YOLO  

# Load the YOLO model
model = YOLO('../models/first_model.pt')  # Change to your model path

# Open the video file
video_path = '../test_vids/battlefield-1.mp4'
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"

# Define a dictionary to store unique colors for each label
LABEL_COLORS = {}

# Function to generate random colors for labels
def get_label_color(label_id):
    if label_id not in LABEL_COLORS:
        LABEL_COLORS[label_id] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label_id]

# Define the allowed object pairs for distance calculation
allowed_pairs = {
    ("tank", "friend"),
    ("enemy", "friend"),
    ("enemy", "wall"),
    ("friend", "wall")
}

# Store previous object locations for tracking
object_tracker = {}

# Maximum distance to consider an object as the same across frames
MAX_TRACKING_DISTANCE = 50

# Frame counter to remove old objects
frame_counter = 0
MAX_FRAMES_MISSING = 10  # If an object disappears for this many frames, we remove it

# Dictionary to store distance data
distance_data = {}

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Video processing completed.")
        break

    frame_counter += 1

    # Perform object detection
    results = model(frame)
    detections = results[0].boxes  

    new_objects = []  # Store new detections in this frame

    # Draw bounding boxes, labels, and store centers
    for box in detections:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Extract box coordinates
        confidence = box.conf[0]  # Extract confidence score
        label_id = int(box.cls[0])  # Extract class label ID

        # Get the class name from the model
        class_name = model.names[label_id]  
        class_name_lower = class_name.lower()

        # Calculate the center point
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2

        # Try to match with existing objects
        assigned_id = None
        for obj_id, (prev_x, prev_y, prev_label, last_seen) in object_tracker.items():
            if prev_label == class_name_lower and distance.euclidean((prev_x, prev_y), (center_x, center_y)) < MAX_TRACKING_DISTANCE:
                assigned_id = obj_id
                break

        # If no match found, assign a new ID
        if assigned_id is None:
            assigned_id = len(object_tracker) + 1

        # Store object for the next frame
        object_tracker[assigned_id] = (center_x, center_y, class_name_lower, frame_counter)
        unique_name = f"{class_name} {assigned_id}"  # E.g., "Friend 1", "Tank 2"

        # Debugging: Print detected object names
        print(f"Detected: {unique_name}")

        # Assign a unique color to this label
        color = get_label_color(label_id)

        # Draw bounding box
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

        # Draw the label and confidence score
        text = f'{unique_name} {confidence:.2f}'
        cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        # Draw the center point with the same label color
        cv2.circle(frame, (center_x, center_y), 5, color, -1)

        # Store for distance calculation
        new_objects.append((center_x, center_y, class_name_lower, unique_name))

    # Remove old objects that haven't been seen for a while (consider them "dead")
    object_tracker = {obj_id: data for obj_id, data in object_tracker.items() if frame_counter - data[3] < MAX_FRAMES_MISSING}

    # Calculate distances only for the allowed object pairs
    for i in range(len(new_objects)):
        for j in range(i + 1, len(new_objects)):
            p1_x, p1_y, label1, name1 = new_objects[i]
            p2_x, p2_y, label2, name2 = new_objects[j]

            # Check if the pair is in the allowed set (both converted to lowercase)
            if (label1, label2) in allowed_pairs or (label2, label1) in allowed_pairs:
                distance_pixels = int(math.dist((p1_x, p1_y), (p2_x, p2_y)))

                # Add the distance to the JSON-like dictionary, only if the objects are "alive"
                if label1 != label2:  # To avoid self-distances
                    if name1 not in distance_data:
                        distance_data[name1] = {}
                    distance_data[name1][name2] = f"{distance_pixels}px"

                # Draw line between allowed pairs
                cv2.line(frame, (p1_x, p1_y), (p2_x, p2_y), (255, 255, 0), 2)  # Yellow line

                # Display distance at the midpoint of the line
                midpoint = ((p1_x + p2_x) // 2, (p1_y + p2_y) // 2)
                cv2.putText(frame, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

    # Print the current distance data (for debugging purposes)
    print(json.dumps(distance_data, indent=4))

    # Display the frame
    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture
cap.release()
cv2.destroyAllWindows()

# %%
#only with distance between labels
import cv2
import math
import random
from ultralytics import YOLO  

# Load the YOLO model
model = YOLO('../models/first_model.pt')  # Change to your model path

# Open the video file
video_path = '../test_vids/battlefield-1.mp4'
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"

# Define a dictionary to store unique colors for each label
LABEL_COLORS = {}

# Function to generate random colors for labels
def get_label_color(label_id):
    if label_id not in LABEL_COLORS:
        LABEL_COLORS[label_id] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return LABEL_COLORS[label_id]

# Define the allowed object pairs for distance calculation
allowed_pairs = {
    ("tank", "friend"),
    ("enemy", "friend"),
    ("enemy", "wall"),
    ("friend", "wall")
}

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Video processing completed.")
        break

    # Perform object detection
    results = model(frame)
    detections = results[0].boxes  

    centers = []  # Store center points of detected objects along with their labels

    # Draw bounding boxes, labels, and store centers
    for box in detections:
        x1, y1, x2, y2 = map(int, box.xyxy[0])  # Extract box coordinates
        confidence = box.conf[0]  # Extract confidence score
        label_id = int(box.cls[0])  # Extract class label ID

        # Get the class name from the model
        class_name = model.names[label_id]  # Keep original detected name
        class_name_lower = class_name.lower()  # Convert to lowercase for matching

        # Debugging: Print detected object names
        print(f"Detected: {class_name}")

        # Assign a unique color to this label
        color = get_label_color(label_id)

        # Draw bounding box
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

        # Draw the label and confidence score
        text = f'{class_name} {confidence:.2f}'
        cv2.putText(frame, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        # Calculate the center point
        center_x = (x1 + x2) // 2
        center_y = (y1 + y2) // 2
        centers.append((center_x, center_y, class_name_lower))  # Store lowercase name

        # Draw the center point with the same label color
        cv2.circle(frame, (center_x, center_y), 5, color, -1)

    # Calculate distances only for the allowed object pairs
    for i in range(len(centers)):
        for j in range(i + 1, len(centers)):
            p1_x, p1_y, label1 = centers[i]
            p2_x, p2_y, label2 = centers[j]

            # Check if the pair is in the allowed set (both converted to lowercase)
            if (label1, label2) in allowed_pairs or (label2, label1) in allowed_pairs:
                distance_pixels = int(math.dist((p1_x, p1_y), (p2_x, p2_y)))

                # Draw line between allowed pairs
                cv2.line(frame, (p1_x, p1_y), (p2_x, p2_y), (255, 255, 0), 2)  # Yellow line

                # Display distance at the midpoint of the line
                midpoint = ((p1_x + p2_x) // 2, (p1_y + p2_y) // 2)
                cv2.putText(frame, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

    # Display the frame
    cv2.imshow('Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture
cap.release()
cv2.destroyAllWindows()
