# %%
from ultralytics import YOLO
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from IPython.display import Image,display
from IPython import display

# %%
import cv2
import math
from ultralytics import YOLO  # Use YOLO model from the ultralytics package

# Load video
cap = cv2.VideoCapture("../test_vids/people_Walking.mp4")
assert cap.isOpened(), "Error reading video file"

# Get video properties
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Load the YOLO model (ensure to load the correct model file)
model = YOLO("../models/yolo11n.pt")  # Change the path to your model

# Store points for distance calculation
selected_points = []

# Mouse callback function
def mouse_callback(event, x, y, flags, param):
    global selected_points

    if event == cv2.EVENT_LBUTTONDOWN:  # Left-click to select points
        if len(selected_points) < 2:
            selected_points.append((x, y))
            print(f"Point selected: {x}, {y}")
        if len(selected_points) == 2:
            print("Two points selected. Distance will be calculated.")

    elif event == cv2.EVENT_RBUTTONDOWN:  # Right-click to reset
        selected_points.clear()  # Clear the selected points list
        print("Selection reset.")

# Set up OpenCV window and mouse callback
cv2.namedWindow("Distance Calculation")
cv2.setMouseCallback("Distance Calculation", mouse_callback)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video processing completed.")
        break

    # Run object detection using YOLO
    results = model(im0)  # Pass the frame to the model to detect objects

    # Process detected results
    if results is not None:
        # Extract bounding boxes (x1, y1, x2, y2) for each detected object
        boxes = results[0].boxes.xyxy.cpu().numpy()  # Extract bounding box coordinates
        labels = results[0].boxes.cls.cpu().numpy()  # Extract labels of detected objects (e.g., person)

        centers = []

        # Draw bounding boxes and calculate centers
        for box in boxes:
            x1, y1, x2, y2 = map(int, box)
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2
            centers.append((center_x, center_y))

            # Draw bounding box and center point
            cv2.rectangle(im0, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green bounding box
            cv2.circle(im0, (center_x, center_y), 5, (0, 0, 255), -1)  # Red dot for center

        # Calculate distances between each pair of centers
        for i in range(len(centers)):
            for j in range(i + 1, len(centers)):
                p1 = centers[i]
                p2 = centers[j]
                distance_pixels = int(math.dist(p1, p2))  # Calculate Euclidean distance between centers

                # Draw line between centers
                cv2.line(im0, p1, p2, (255, 0, 0), 2)  # Blue line between centers

                # Display distance at the midpoint of the line
                midpoint = ((p1[0] + p2[0]) // 2, (p1[1] + p2[1]) // 2)
                cv2.putText(im0, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

    # Show the frame with bounding boxes, centers, and distance calculations
    cv2.imshow("Distance Calculation", im0)

    # Quit on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 18 persons, 63.7ms
# Speed: 4.1ms preprocess, 63.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 47.7ms
# Speed: 1.8ms preprocess, 47.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 42.9ms
# Speed: 1.4ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 51.3ms
# Speed: 1.9ms preprocess, 51.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 53.3ms
# Speed: 1.9ms preprocess, 53.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 46.7ms
# Speed: 1.4ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 2025-02-04 00:10:43.658 python[18719:372173] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-04 00:10:43.658 python[18719:372173] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 384x640 17 persons, 48.0ms
# Speed: 1.3ms preprocess, 48.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 45.3ms
# Speed: 1.4ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 42.9ms
# Speed: 1.4ms preprocess, 42.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 47.0ms
# Speed: 1.4ms preprocess, 47.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 50.2ms
# Speed: 1.4ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 55.0ms
# Speed: 1.6ms preprocess, 55.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 53.0ms
# Speed: 1.5ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 50.6ms
# Speed: 1.8ms preprocess, 50.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 50.8ms
# Speed: 1.6ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 49.2ms
# Speed: 1.3ms preprocess, 49.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 47.3ms
# Speed: 1.5ms preprocess, 47.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 39.1ms
# Speed: 1.8ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 45.3ms
# Speed: 1.5ms preprocess, 45.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 45.8ms
# Speed: 1.5ms preprocess, 45.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.0ms
# Speed: 1.3ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 46.0ms
# Speed: 1.4ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.7ms
# Speed: 1.4ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 42.7ms
# Speed: 2.0ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 backpack, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 backpack, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 backpack, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.3ms
# Speed: 1.2ms preprocess, 40.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.4ms
# Speed: 1.4ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.9ms
# Speed: 1.1ms preprocess, 36.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 backpack, 40.5ms
# Speed: 1.7ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 37.0ms
# Speed: 1.4ms preprocess, 37.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 36.9ms
# Speed: 1.3ms preprocess, 36.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 36.3ms
# Speed: 1.5ms preprocess, 36.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 50.8ms
# Speed: 2.1ms preprocess, 50.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 47.2ms
# Speed: 1.6ms preprocess, 47.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 34.0ms
# Speed: 1.4ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 39.6ms
# Speed: 2.0ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 38.1ms
# Speed: 1.7ms preprocess, 38.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 37.8ms
# Speed: 1.3ms preprocess, 37.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 38.3ms
# Speed: 1.6ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.5ms
# Speed: 1.6ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 32.2ms
# Speed: 1.3ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 32.8ms
# Speed: 1.4ms preprocess, 32.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.7ms
# Speed: 1.2ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.2ms
# Speed: 1.3ms preprocess, 39.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 42.1ms
# Speed: 1.7ms preprocess, 42.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 40.6ms
# Speed: 1.3ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 43.6ms
# Speed: 1.4ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 42.1ms
# Speed: 1.9ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 47.0ms
# Speed: 1.9ms preprocess, 47.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 61.4ms
# Speed: 3.0ms preprocess, 61.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 64.7ms
# Speed: 3.5ms preprocess, 64.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 45.6ms
# Speed: 1.3ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 40.4ms
# Speed: 1.9ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 51.0ms
# Speed: 1.8ms preprocess, 51.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 64.7ms
# Speed: 1.4ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 75.3ms
# Speed: 1.6ms preprocess, 75.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 45.6ms
# Speed: 1.4ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.5ms
# Speed: 1.5ms preprocess, 40.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 39.3ms
# Speed: 1.3ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 44.7ms
# Speed: 1.4ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 41.2ms
# Speed: 1.7ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 49.2ms
# Speed: 1.7ms preprocess, 49.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 41.1ms
# Speed: 1.7ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 35.3ms
# Speed: 1.6ms preprocess, 35.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 44.6ms
# Speed: 1.8ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 44.3ms
# Speed: 2.0ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.7ms
# Speed: 1.4ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 41.3ms
# Speed: 1.7ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 41.3ms
# Speed: 1.6ms preprocess, 41.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 45.2ms
# Speed: 1.8ms preprocess, 45.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 54.2ms
# Speed: 1.5ms preprocess, 54.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 suitcase, 35.8ms
# Speed: 1.4ms preprocess, 35.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 38.8ms
# Speed: 1.6ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 40.4ms
# Speed: 1.7ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 43.0ms
# Speed: 1.9ms preprocess, 43.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 40.4ms
# Speed: 1.7ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 44.3ms
# Speed: 1.9ms preprocess, 44.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 42.5ms
# Speed: 1.8ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 40.8ms
# Speed: 1.4ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 46.4ms
# Speed: 1.5ms preprocess, 46.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 handbag, 35.0ms
# Speed: 1.3ms preprocess, 35.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 38.3ms
# Speed: 1.8ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 36.8ms
# Speed: 1.6ms preprocess, 36.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 36.0ms
# Speed: 1.3ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 39.2ms
# Speed: 1.2ms preprocess, 39.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 37.5ms
# Speed: 1.3ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 43.1ms
# Speed: 1.4ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 34.7ms
# Speed: 1.5ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 backpack, 60.0ms
# Speed: 1.8ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 55.3ms
# Speed: 1.5ms preprocess, 55.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 47.9ms
# Speed: 1.3ms preprocess, 47.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 62.1ms
# Speed: 2.2ms preprocess, 62.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 47.6ms
# Speed: 1.5ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 47.4ms
# Speed: 2.0ms preprocess, 47.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.1ms
# Speed: 1.4ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 61.2ms
# Speed: 1.4ms preprocess, 61.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 47.7ms
# Speed: 1.7ms preprocess, 47.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 47.1ms
# Speed: 3.0ms preprocess, 47.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 47.6ms
# Speed: 1.5ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 46.5ms
# Speed: 1.9ms preprocess, 46.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 handbag, 52.1ms
# Speed: 1.5ms preprocess, 52.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 59.2ms
# Speed: 1.8ms preprocess, 59.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 50.0ms
# Speed: 1.9ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 49.6ms
# Speed: 1.8ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 50.2ms
# Speed: 1.8ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 handbag, 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 46.2ms
# Speed: 1.6ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 48.6ms
# Speed: 1.3ms preprocess, 48.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 44.3ms
# Speed: 1.8ms preprocess, 44.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 62.7ms
# Speed: 1.6ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 54.3ms
# Speed: 1.6ms preprocess, 54.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 45.5ms
# Speed: 2.0ms preprocess, 45.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 47.9ms
# Speed: 1.9ms preprocess, 47.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 45.5ms
# Speed: 1.4ms preprocess, 45.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.3ms
# Speed: 1.8ms preprocess, 40.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 44.4ms
# Speed: 1.7ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 60.8ms
# Speed: 1.9ms preprocess, 60.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.8ms
# Speed: 1.4ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 handbag, 38.3ms
# Speed: 1.6ms preprocess, 38.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 handbag, 37.4ms
# Speed: 1.8ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 handbag, 36.1ms
# Speed: 1.7ms preprocess, 36.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 37.6ms
# Speed: 1.7ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 handbag, 35.1ms
# Speed: 1.7ms preprocess, 35.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 handbag, 35.5ms
# Speed: 1.1ms preprocess, 35.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 handbag, 39.7ms
# Speed: 1.4ms preprocess, 39.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 handbag, 39.2ms
# Speed: 1.9ms preprocess, 39.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 51.9ms
# Speed: 1.3ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 39.5ms
# Speed: 1.3ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 40.1ms
# Speed: 1.5ms preprocess, 40.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 40.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 37.5ms
# Speed: 1.2ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 48.5ms
# Speed: 1.6ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 48.2ms
# Speed: 2.0ms preprocess, 48.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 40.3ms
# Speed: 1.7ms preprocess, 40.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 38.5ms
# Speed: 1.7ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 36.6ms
# Speed: 1.4ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 37.3ms
# Speed: 1.3ms preprocess, 37.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 37.9ms
# Speed: 1.8ms preprocess, 37.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 33.5ms
# Speed: 1.2ms preprocess, 33.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 37.6ms
# Speed: 1.6ms preprocess, 37.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 47.5ms
# Speed: 1.6ms preprocess, 47.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.5ms
# Speed: 1.4ms preprocess, 39.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 43.0ms
# Speed: 1.3ms preprocess, 43.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.4ms
# Speed: 1.7ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 34.0ms
# Speed: 1.2ms preprocess, 34.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 36.4ms
# Speed: 1.7ms preprocess, 36.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 36.5ms
# Speed: 1.5ms preprocess, 36.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 37.4ms
# Speed: 1.5ms preprocess, 37.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 50.3ms
# Speed: 1.6ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 46.7ms
# Speed: 1.4ms preprocess, 46.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 40.7ms
# Speed: 1.3ms preprocess, 40.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 40.7ms
# Speed: 1.3ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 39.2ms
# Speed: 1.6ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.6ms
# Speed: 1.4ms preprocess, 37.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.1ms
# Speed: 1.7ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 39.1ms
# Speed: 1.2ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.4ms
# Speed: 1.5ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 36.6ms
# Speed: 1.6ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 43.1ms
# Speed: 1.4ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 46.4ms
# Speed: 1.6ms preprocess, 46.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 39.8ms
# Speed: 1.3ms preprocess, 39.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 40.2ms
# Speed: 1.2ms preprocess, 40.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 47.4ms
# Speed: 2.1ms preprocess, 47.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.0ms
# Speed: 1.5ms preprocess, 37.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 32.8ms
# Speed: 1.2ms preprocess, 32.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 45.9ms
# Speed: 1.7ms preprocess, 45.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 42.1ms
# Speed: 1.5ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.8ms
# Speed: 1.3ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 45.9ms
# Speed: 1.4ms preprocess, 45.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.6ms
# Speed: 1.7ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 42.4ms
# Speed: 1.2ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 47.9ms
# Speed: 1.4ms preprocess, 47.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 handbag, 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 47.8ms
# Speed: 1.4ms preprocess, 47.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 45.4ms
# Speed: 1.4ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 48.4ms
# Speed: 2.0ms preprocess, 48.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.4ms
# Speed: 1.3ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 55.8ms
# Speed: 1.9ms preprocess, 55.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 35.0ms
# Speed: 1.3ms preprocess, 35.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 46.2ms
# Speed: 1.3ms preprocess, 46.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.9ms
# Speed: 1.4ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.3ms
# Speed: 1.7ms preprocess, 40.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.3ms
# Speed: 1.7ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 48.8ms
# Speed: 2.0ms preprocess, 48.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 38.6ms
# Speed: 1.7ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 70.8ms
# Speed: 1.5ms preprocess, 70.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 46.8ms
# Speed: 1.5ms preprocess, 46.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.1ms
# Speed: 1.6ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 49.2ms
# Speed: 1.6ms preprocess, 49.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 44.7ms
# Speed: 1.6ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 41.8ms
# Speed: 1.9ms preprocess, 41.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 39.7ms
# Speed: 1.6ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.7ms
# Speed: 1.4ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 backpack, 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.7ms
# Speed: 1.3ms preprocess, 39.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 42.4ms
# Speed: 1.7ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 44.3ms
# Speed: 1.3ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 51.7ms
# Speed: 1.4ms preprocess, 51.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 handbag, 48.5ms
# Speed: 1.8ms preprocess, 48.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 handbag, 46.2ms
# Speed: 1.8ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 51.0ms
# Speed: 9.6ms preprocess, 51.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 46.5ms
# Speed: 1.6ms preprocess, 46.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 37.6ms
# Speed: 1.7ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 32.3ms
# Speed: 1.6ms preprocess, 32.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 35.4ms
# Speed: 1.6ms preprocess, 35.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 backpack, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 backpack, 2 handbags, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 handbag, 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 2 backpacks, 1 handbag, 44.2ms
# Speed: 1.9ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 backpacks, 1 handbag, 49.4ms
# Speed: 1.7ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 44.7ms
# Speed: 1.4ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 39.1ms
# Speed: 1.5ms preprocess, 39.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.8ms
# Speed: 1.7ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 handbag, 39.7ms
# Speed: 1.7ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 36.5ms
# Speed: 1.2ms preprocess, 36.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 72.9ms
# Speed: 1.3ms preprocess, 72.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 34.8ms
# Speed: 1.3ms preprocess, 34.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 36.0ms
# Speed: 1.7ms preprocess, 36.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 38.5ms
# Speed: 1.2ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 42.1ms
# Speed: 1.4ms preprocess, 42.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 43.6ms
# Speed: 1.8ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 40.1ms
# Speed: 1.7ms preprocess, 40.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.7ms
# Speed: 1.3ms preprocess, 41.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.7ms
# Speed: 1.4ms preprocess, 36.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 48.3ms
# Speed: 1.3ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 35.2ms
# Speed: 1.8ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.2ms
# Speed: 1.7ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.8ms
# Speed: 1.9ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 39.4ms
# Speed: 1.6ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 51.8ms
# Speed: 2.8ms preprocess, 51.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.3ms
# Speed: 1.5ms preprocess, 37.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 38.0ms
# Speed: 1.6ms preprocess, 38.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 40.5ms
# Speed: 1.3ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 39.9ms
# Speed: 1.3ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.3ms
# Speed: 1.5ms preprocess, 39.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 37.8ms
# Speed: 2.0ms preprocess, 37.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 38.4ms
# Speed: 1.5ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 suitcase, 38.0ms
# Speed: 2.1ms preprocess, 38.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
import cv2
import math
from ultralytics import solutions

# Load video
cap = cv2.VideoCapture("../test_vids/people_Walking.mp4")
assert cap.isOpened(), "Error reading video file"

# Get video properties
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Init YOLO distance calculation
distance = solutions.DistanceCalculation(model="../models/yolo11n.pt", show=True)

# Store points for distance calculation
selected_points = []

# Mouse callback function
def mouse_callback(event, x, y, flags, param):
    global selected_points

    if event == cv2.EVENT_LBUTTONDOWN:  # Left-click to select points
        if len(selected_points) < 2:
            selected_points.append((x, y))
            print(f"Point selected: {x}, {y}")
        if len(selected_points) == 2:
            print("Two points selected. Distance will be calculated.")

    elif event == cv2.EVENT_RBUTTONDOWN:  # Right-click to reset
        selected_points.clear()  # Clear the selected points list
        print("Selection reset.")

# Set up OpenCV window and mouse callback
cv2.namedWindow("Distance Calculation")
cv2.setMouseCallback("Distance Calculation", mouse_callback)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video processing completed.")
        break

    results = distance.calculate(im0)

    if results is not None:
        # Extract bounding boxes
        if hasattr(results, "boxes"):
            boxes = [list(map(int, box.xyxy[0])) for box in results.boxes]

            # Draw bounding boxes
            for box in boxes:
                x1, y1, x2, y2 = box
                cv2.rectangle(im0, (x1, y1), (x2, y2), (0, 255, 0), 2)

    # Draw selected points (red dots)
    for point in selected_points:
        cv2.circle(im0, point, 5, (0, 0, 255), -1)  # Red dot on selected points

    # Calculate and display distance if two points are selected
    if len(selected_points) == 2:
        p1, p2 = selected_points
        distance_pixels = int(math.dist(p1, p2))

        # Draw line between points
        cv2.line(im0, p1, p2, (255, 0, 0), 2)

        # Display distance
        midpoint = ((p1[0] + p2[0]) // 2, (p1[1] + p2[1]) // 2)
        cv2.putText(im0, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

    # Show the frame with bounding boxes and selected points
    cv2.imshow("Distance Calculation", im0)

    # Quit on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# Ultralytics Solutions: ✅ {'region': None, 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'model': '../models/yolo11n.pt', 'show': True}
#
# 0: 384x640 18 persons, 56.6ms
# Speed: 3.7ms preprocess, 56.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 46.4ms
# Speed: 1.6ms preprocess, 46.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.7ms
# Speed: 1.3ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 2025-02-03 15:02:58.957 python[11668:246318] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-03 15:02:58.957 python[11668:246318] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 384x640 19 persons, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.4ms
# Speed: 1.6ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 38.8ms
# Speed: 1.9ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.0ms
# Speed: 1.4ms preprocess, 36.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.4ms
# Speed: 1.8ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.7ms
# Speed: 1.6ms preprocess, 37.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.2ms
# Speed: 1.4ms preprocess, 39.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 44.6ms
# Speed: 1.4ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.2ms
# Speed: 1.4ms preprocess, 37.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.9ms
# Speed: 1.2ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 35.3ms
# Speed: 1.3ms preprocess, 35.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 34.3ms
# Speed: 1.3ms preprocess, 34.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.1ms
# Speed: 1.4ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.1ms
# Speed: 1.3ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.3ms
# Speed: 1.3ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 36.9ms
# Speed: 1.3ms preprocess, 36.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.6ms
# Speed: 1.4ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.8ms
# Speed: 1.2ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 38.3ms
# Speed: 1.4ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.9ms
# Speed: 1.3ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.5ms
# Speed: 1.4ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 32.6ms
# Speed: 1.3ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.6ms
# Speed: 1.3ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 39.2ms
# Speed: 1.4ms preprocess, 39.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 48.7ms
# Speed: 1.6ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 32.4ms
# Speed: 1.3ms preprocess, 32.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 38.7ms
# Speed: 1.5ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 42.8ms
# Speed: 1.3ms preprocess, 42.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 48.2ms
# Speed: 1.7ms preprocess, 48.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 backpack, 36.4ms
# Speed: 1.7ms preprocess, 36.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 backpacks, 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 backpack, 35.6ms
# Speed: 1.6ms preprocess, 35.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 backpack, 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 backpack, 41.4ms
# Speed: 1.3ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 backpack, 40.5ms
# Speed: 1.2ms preprocess, 40.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 backpack, 34.1ms
# Speed: 1.3ms preprocess, 34.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 backpack, 40.4ms
# Speed: 1.4ms preprocess, 40.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 41.3ms
# Speed: 1.5ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 39.7ms
# Speed: 1.3ms preprocess, 39.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 40.6ms
# Speed: 1.2ms preprocess, 40.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 2 backpacks, 40.1ms
# Speed: 1.6ms preprocess, 40.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 37.4ms
# Speed: 1.3ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 42.0ms
# Speed: 2.2ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 34.2ms
# Speed: 1.4ms preprocess, 34.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 36.3ms
# Speed: 1.3ms preprocess, 36.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 48.7ms
# Speed: 1.4ms preprocess, 48.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 41.0ms
# Speed: 1.2ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 39.6ms
# Speed: 1.6ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 39.8ms
# Speed: 1.2ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 37.1ms
# Speed: 1.4ms preprocess, 37.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 38.3ms
# Speed: 1.3ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 40.7ms
# Speed: 1.3ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 37.5ms
# Speed: 1.2ms preprocess, 37.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.2ms
# Speed: 1.3ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 45.3ms
# Speed: 1.2ms preprocess, 45.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 35.0ms
# Speed: 1.5ms preprocess, 35.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.7ms
# Speed: 1.3ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 33.1ms
# Speed: 1.4ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 34.8ms
# Speed: 1.6ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 36.6ms
# Speed: 1.5ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 37.7ms
# Speed: 1.2ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 39.3ms
# Speed: 1.5ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 52.4ms
# Speed: 1.2ms preprocess, 52.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 39.6ms
# Speed: 1.2ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 38.8ms
# Speed: 1.6ms preprocess, 38.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 39.5ms
# Speed: 1.4ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 46.2ms
# Speed: 1.4ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 42.5ms
# Speed: 1.8ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 37.3ms
# Speed: 1.5ms preprocess, 37.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 suitcase, 38.2ms
# Speed: 1.7ms preprocess, 38.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 34.6ms
# Speed: 1.3ms preprocess, 34.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 36.7ms
# Speed: 1.4ms preprocess, 36.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 38.7ms
# Speed: 1.5ms preprocess, 38.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 36.4ms
# Speed: 1.3ms preprocess, 36.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 36.3ms
# Speed: 1.7ms preprocess, 36.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 backpack, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 38.9ms
# Speed: 1.2ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 39.9ms
# Speed: 1.8ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 36.9ms
# Speed: 1.7ms preprocess, 36.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 suitcase, 43.8ms
# Speed: 1.6ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 suitcase, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 backpack, 1 suitcase, 43.0ms
# Speed: 1.3ms preprocess, 43.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 suitcase, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 39.2ms
# Speed: 1.3ms preprocess, 39.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 38.6ms
# Speed: 1.4ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 38.1ms
# Speed: 1.3ms preprocess, 38.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 47.0ms
# Speed: 1.7ms preprocess, 47.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 39.7ms
# Speed: 1.2ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 34.5ms
# Speed: 1.4ms preprocess, 34.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 37.2ms
# Speed: 1.5ms preprocess, 37.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 40.3ms
# Speed: 1.4ms preprocess, 40.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 38.3ms
# Speed: 1.8ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 41.3ms
# Speed: 1.7ms preprocess, 41.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 40.3ms
# Speed: 1.4ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 40.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
import cv2
import math
from ultralytics import solutions

# Load video
cap = cv2.VideoCapture("../test_vids/people_Walking.mp4")
assert cap.isOpened(), "Error reading video file"

# Get video properties
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Init YOLO distance calculation
distance = solutions.DistanceCalculation(model="../models/yolo11n.pt", show=True)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video processing completed.")
        break

    results = distance.calculate(im0)

    if results is not None:
        # Extract bounding boxes and calculate centers
        if hasattr(results, "boxes"):
            boxes = [list(map(int, box.xyxy[0])) for box in results.boxes]
            centers = []

            # Calculate the center for each bounding box
            for box in boxes:
                x1, y1, x2, y2 = box
                center_x = (x1 + x2) // 2
                center_y = (y1 + y2) // 2
                centers.append((center_x, center_y))

                # Draw bounding box and center
                cv2.rectangle(im0, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.circle(im0, (center_x, center_y), 5, (0, 0, 255), -1)  # Red dot for center

            # Calculate distances between each pair of centers
            for i in range(len(centers)):
                for j in range(i + 1, len(centers)):
                    p1 = centers[i]
                    p2 = centers[j]
                    distance_pixels = int(math.dist(p1, p2))

                    # Draw line between centers
                    cv2.line(im0, p1, p2, (255, 0, 0), 2)

                    # Display distance at the midpoint
                    midpoint = ((p1[0] + p2[0]) // 2, (p1[1] + p2[1]) // 2)
                    cv2.putText(im0, f"{distance_pixels}px", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2)

    # Show the frame with bounding boxes and center-to-center distances
    cv2.imshow("Distance Calculation", im0)

    # Quit on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
# Out:
# Ultralytics Solutions: ✅ {'region': None, 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'model': '../models/yolo11n.pt', 'show': True}
#
# 0: 384x640 18 persons, 53.7ms
# Speed: 3.9ms preprocess, 53.7ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 44.7ms
# Speed: 1.6ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.4ms
# Speed: 1.4ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 2025-02-03 13:16:55.790 python[9217:202520] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-03 13:16:55.790 python[9217:202520] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# 0: 384x640 19 persons, 38.2ms
# Speed: 1.3ms preprocess, 38.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 44.4ms
# Speed: 1.4ms preprocess, 44.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 45.3ms
# Speed: 1.5ms preprocess, 45.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.9ms
# Speed: 1.7ms preprocess, 39.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.7ms
# Speed: 1.5ms preprocess, 41.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.5ms
# Speed: 1.3ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 66.5ms
# Speed: 1.3ms preprocess, 66.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.4ms
# Speed: 1.6ms preprocess, 37.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.9ms
# Speed: 1.4ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.6ms
# Speed: 1.2ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 45.3ms
# Speed: 1.4ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 43.2ms
# Speed: 1.3ms preprocess, 43.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.8ms
# Speed: 1.4ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 38.3ms
# Speed: 1.3ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.5ms
# Speed: 1.2ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 53.4ms
# Speed: 1.4ms preprocess, 53.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.7ms
# Speed: 1.6ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 33.8ms
# Speed: 1.7ms preprocess, 33.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 45.0ms
# Speed: 1.3ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 38.6ms
# Speed: 1.4ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 42.8ms
# Speed: 1.3ms preprocess, 42.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 38.1ms
# Speed: 1.4ms preprocess, 38.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 82.0ms
# Speed: 1.8ms preprocess, 82.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 33.2ms
# Speed: 1.6ms preprocess, 33.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 backpack, 40.6ms
# Speed: 1.9ms preprocess, 40.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 backpacks, 36.1ms
# Speed: 1.4ms preprocess, 36.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 backpack, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 backpack, 40.3ms
# Speed: 1.4ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 backpack, 37.3ms
# Speed: 1.4ms preprocess, 37.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 backpack, 38.0ms
# Speed: 1.3ms preprocess, 38.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 backpack, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 backpack, 38.8ms
# Speed: 1.4ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 37.2ms
# Speed: 1.5ms preprocess, 37.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 40.8ms
# Speed: 2.1ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 36.7ms
# Speed: 1.7ms preprocess, 36.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 2 backpacks, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 backpack, 47.6ms
# Speed: 2.3ms preprocess, 47.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 45.9ms
# Speed: 1.9ms preprocess, 45.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 62.7ms
# Speed: 1.3ms preprocess, 62.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 44.3ms
# Speed: 1.6ms preprocess, 44.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 38.9ms
# Speed: 1.5ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 33.5ms
# Speed: 1.1ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 32.1ms
# Speed: 1.5ms preprocess, 32.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 37.6ms
# Speed: 1.3ms preprocess, 37.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 36.1ms
# Speed: 1.4ms preprocess, 36.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 39.6ms
# Speed: 1.6ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.5ms
# Speed: 1.6ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.3ms
# Speed: 1.4ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 71.0ms
# Speed: 2.4ms preprocess, 71.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 43.4ms
# Speed: 1.4ms preprocess, 43.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 59.7ms
# Speed: 1.7ms preprocess, 59.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 41.8ms
# Speed: 1.6ms preprocess, 41.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 55.6ms
# Speed: 1.9ms preprocess, 55.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 43.3ms
# Speed: 1.6ms preprocess, 43.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 43.6ms
# Speed: 1.4ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 46.5ms
# Speed: 1.1ms preprocess, 46.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 41.4ms
# Speed: 1.9ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 39.9ms
# Speed: 1.4ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 suitcase, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 39.2ms
# Speed: 1.5ms preprocess, 39.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 38.7ms
# Speed: 1.4ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 47.5ms
# Speed: 1.3ms preprocess, 47.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 36.6ms
# Speed: 1.5ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 37.6ms
# Speed: 1.6ms preprocess, 37.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 39.8ms
# Speed: 1.3ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 backpack, 39.4ms
# Speed: 1.5ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 38.9ms
# Speed: 1.4ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 36.5ms
# Speed: 1.5ms preprocess, 36.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 36.1ms
# Speed: 1.4ms preprocess, 36.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 suitcase, 42.5ms
# Speed: 1.3ms preprocess, 42.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 suitcase, 36.9ms
# Speed: 1.3ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 backpack, 1 suitcase, 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 backpack, 1 suitcase, 36.9ms
# Speed: 1.4ms preprocess, 36.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 37.9ms
# Speed: 1.5ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 37.4ms
# Speed: 1.4ms preprocess, 37.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 40.5ms
# Speed: 1.3ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 38.5ms
# Speed: 1.4ms preprocess, 38.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 40.3ms
# Speed: 1.4ms preprocess, 40.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 44.0ms
# Speed: 1.2ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 56.0ms
# Speed: 1.5ms preprocess, 56.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 36.7ms
# Speed: 1.3ms preprocess, 36.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 36.2ms
# Speed: 1.8ms preprocess, 36.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 39.9ms
# Speed: 1.3ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 39.6ms
# Speed: 1.2ms preprocess, 39.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 40.5ms
# Speed: 1.3ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 52.7ms
# Speed: 1.9ms preprocess, 52.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 38.1ms
# Speed: 1.5ms preprocess, 38.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 37.2ms
# Speed: 1.3ms preprocess, 37.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 40.8ms
# Speed: 1.7ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 36.0ms
# Speed: 1.3ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 69.9ms
# Speed: 1.4ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 33.5ms
# Speed: 1.4ms preprocess, 33.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 53.5ms
# Speed: 1.4ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 37.2ms
# Speed: 1.8ms preprocess, 37.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 45.3ms
# Speed: 1.9ms preprocess, 45.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 44.8ms
# Speed: 1.9ms preprocess, 44.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 48.2ms
# Speed: 9.1ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 44.0ms
# Speed: 1.5ms preprocess, 44.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 38.6ms
# Speed: 1.7ms preprocess, 38.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 42.4ms
# Speed: 1.7ms preprocess, 42.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 40.2ms
# Speed: 1.7ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 48.5ms
# Speed: 1.3ms preprocess, 48.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 46.6ms
# Speed: 1.4ms preprocess, 46.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 45.4ms
# Speed: 1.5ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 43.0ms
# Speed: 1.9ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 47.6ms
# Speed: 1.4ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 45.6ms
# Speed: 1.4ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 51.1ms
# Speed: 1.9ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 50.6ms
# Speed: 1.8ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.4ms
# Speed: 1.7ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.7ms
# Speed: 1.4ms preprocess, 37.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.5ms
# Speed: 1.6ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.7ms
# Speed: 1.3ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 43.7ms
# Speed: 1.4ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.2ms
# Speed: 1.6ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.9ms
# Speed: 1.4ms preprocess, 37.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.9ms
# Speed: 1.4ms preprocess, 36.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 handbag, 35.8ms
# Speed: 1.4ms preprocess, 35.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 37.8ms
# Speed: 1.3ms preprocess, 37.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 37.5ms
# Speed: 1.3ms preprocess, 37.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 37.6ms
# Speed: 1.3ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 handbag, 58.0ms
# Speed: 1.4ms preprocess, 58.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 handbag, 39.9ms
# Speed: 1.4ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 handbag, 41.7ms
# Speed: 1.6ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 46.2ms
# Speed: 1.4ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 40.7ms
# Speed: 1.2ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 38.1ms
# Speed: 1.1ms preprocess, 38.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 42.8ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 39.5ms
# Speed: 1.5ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 44.1ms
# Speed: 1.5ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 37.5ms
# Speed: 1.6ms preprocess, 37.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 36.5ms
# Speed: 1.2ms preprocess, 36.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 38.1ms
# Speed: 1.2ms preprocess, 38.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 38.1ms
# Speed: 1.3ms preprocess, 38.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 34.2ms
# Speed: 1.3ms preprocess, 34.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 41.1ms
# Speed: 1.3ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 38.0ms
# Speed: 1.2ms preprocess, 38.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 35.3ms
# Speed: 1.3ms preprocess, 35.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 30.0ms
# Speed: 1.5ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 30.4ms
# Speed: 1.5ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 31.3ms
# Speed: 1.3ms preprocess, 31.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 61.7ms
# Speed: 1.4ms preprocess, 61.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 38.5ms
# Speed: 1.6ms preprocess, 38.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 40.6ms
# Speed: 1.3ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 34.6ms
# Speed: 1.5ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 40.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 38.3ms
# Speed: 1.4ms preprocess, 38.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 47.8ms
# Speed: 1.5ms preprocess, 47.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 35.2ms
# Speed: 1.4ms preprocess, 35.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 35.2ms
# Speed: 1.4ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 35.8ms
# Speed: 1.6ms preprocess, 35.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 41.6ms
# Speed: 1.4ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 45.9ms
# Speed: 2.0ms preprocess, 45.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.1ms
# Speed: 1.7ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.7ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.5ms
# Speed: 1.2ms preprocess, 39.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 38.1ms
# Speed: 1.5ms preprocess, 38.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.7ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.6ms
# Speed: 1.3ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 35.9ms
# Speed: 1.3ms preprocess, 35.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.6ms
# Speed: 1.7ms preprocess, 38.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 40.7ms
# Speed: 1.6ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 61.5ms
# Speed: 1.5ms preprocess, 61.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.5ms
# Speed: 1.3ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 51.1ms
# Speed: 1.8ms preprocess, 51.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 47.4ms
# Speed: 1.6ms preprocess, 47.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 44.5ms
# Speed: 1.4ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.0ms
# Speed: 1.6ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.6ms
# Speed: 1.5ms preprocess, 37.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 34.8ms
# Speed: 1.2ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 61.5ms
# Speed: 1.6ms preprocess, 61.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.2ms
# Speed: 1.2ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 41.6ms
# Speed: 1.6ms preprocess, 41.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.8ms
# Speed: 1.4ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.5ms
# Speed: 1.8ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.3ms
# Speed: 1.7ms preprocess, 37.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.0ms
# Speed: 1.3ms preprocess, 40.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 47.8ms
# Speed: 1.3ms preprocess, 47.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 66.6ms
# Speed: 1.3ms preprocess, 66.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 38.8ms
# Speed: 1.3ms preprocess, 38.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 38.8ms
# Speed: 1.3ms preprocess, 38.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 35.3ms
# Speed: 1.6ms preprocess, 35.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 36.8ms
# Speed: 1.2ms preprocess, 36.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 37.8ms
# Speed: 1.4ms preprocess, 37.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.0ms
# Speed: 1.5ms preprocess, 38.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 37.4ms
# Speed: 1.2ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 34.6ms
# Speed: 1.6ms preprocess, 34.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.3ms
# Speed: 1.7ms preprocess, 40.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 41.9ms
# Speed: 1.4ms preprocess, 41.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.4ms
# Speed: 1.2ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.3ms
# Speed: 1.4ms preprocess, 40.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.4ms
# Speed: 1.6ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.3ms
# Speed: 1.5ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 41.2ms
# Speed: 1.5ms preprocess, 41.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 backpack, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 backpack, 38.6ms
# Speed: 1.7ms preprocess, 38.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 backpack, 37.2ms
# Speed: 1.9ms preprocess, 37.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 backpack, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 39.5ms
# Speed: 1.2ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 44.8ms
# Speed: 1.8ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 43.1ms
# Speed: 1.4ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.1ms
# Speed: 1.6ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 39.1ms
# Speed: 1.3ms preprocess, 39.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 backpack, 64.8ms
# Speed: 1.6ms preprocess, 64.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 36.9ms
# Speed: 1.3ms preprocess, 36.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.6ms
# Speed: 1.5ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 40.4ms
# Speed: 1.5ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 39.5ms
# Speed: 1.5ms preprocess, 39.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 46.2ms
# Speed: 1.5ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.6ms
# Speed: 1.5ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 39.5ms
# Speed: 1.2ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 38.9ms
# Speed: 1.5ms preprocess, 38.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 44.4ms
# Speed: 1.9ms preprocess, 44.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 38.5ms
# Speed: 1.7ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 44.6ms
# Speed: 1.9ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 40.2ms
# Speed: 1.7ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 umbrella, 40.3ms
# Speed: 1.4ms preprocess, 40.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 umbrella, 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 umbrella, 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 umbrella, 39.9ms
# Speed: 1.9ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 43.3ms
# Speed: 1.9ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 bench, 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.8ms
# Speed: 1.7ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 suitcase, 39.5ms
# Speed: 1.4ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 41.7ms
# Speed: 1.6ms preprocess, 41.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 48.3ms
# Speed: 1.7ms preprocess, 48.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 42.9ms
# Speed: 1.7ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.5ms
# Speed: 1.6ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 42.4ms
# Speed: 1.6ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 37.9ms
# Speed: 1.5ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 39.0ms
# Speed: 1.7ms preprocess, 39.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 65.7ms
# Speed: 1.5ms preprocess, 65.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 38.0ms
# Speed: 1.3ms preprocess, 38.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 40.2ms
# Speed: 1.6ms preprocess, 40.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 40.2ms
# Speed: 1.2ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 38.3ms
# Speed: 1.3ms preprocess, 38.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 39.1ms
# Speed: 1.5ms preprocess, 39.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 47.5ms
# Speed: 1.6ms preprocess, 47.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Video processing completed.
